# %% [markdown]
# # 3. Fitting models to data
#
# In this workbook we will import data and find the cosmological model that best fits that data.
#
# ### 3.1 First set up the packages and functions
# We need to know the distance modulus as a function of redshift.  Distance modulus is defined as
# \begin{equation} \mu(z) = 5 \log_{10}(D_L)\end{equation}
# where
# \begin{equation} D_L = R_0 S_k(\chi) (1+z) \end{equation}
# and $S_k(\chi)=\sin(\chi), \chi,\; {\rm or}\; \sinh(\chi)$ for closed, flat, and open universes respectively, and
# \begin{equation} R_0\chi = \frac{c}{H_0}\int_0^z \frac{dz}{E(z)}\end{equation}
# with $E(z)=H(z)/H_0$.
#
# Note that the absolute magnitude of the SNe is about -19.5, but it enters as an additive constant in the same way as $c/H_0$ and both have high uncertainty.  Therefore we *marginalise* over this offset and it doesn't matter what value of $H_0$ we use.
#
# #### Important: In the code below, replace ez = 1.0 with the actual function for E(z).

# %%
# First let's set up our packages
import numpy as np
from matplotlib import pyplot as plt
from scipy import integrate
import math
# And set some constants
c = 299792.458 # km/s (speed of light)
H0kmsmpc = 70.  # Hubble constant in km/s/Mpc
H0s = H0kmsmpc * 3.2408e-20 # H0 in inverse seconds is H0 in km/s/Mpc * (3.2408e-20 Mpc/km)

# Write a function for the integrand, i.e. $1/E(z)$,
def ezinv(z, om=0.3, orr=0.0, ol=0.7, w0=-1.0, wa=0.0):
    # ok = 1.-om-orr-ol
    power_for_ol = 3*(1+w0+(wa*(1-(1/(1+z)))))
    ez = np.sqrt((orr*(1+z)**4) + (om*(1+z)**3) + ((1.0-om-ol-orr)*(1+z)**2) + (ol*((1+z)**(power_for_ol))))
    return 1./ez

# The curvature correction function
def Sk(xx, ok):
    if ok < 0.0:
        dk = np.sin(np.sqrt(-ok)*xx)/np.sqrt(-ok)
    elif ok > 0.0:
        dk = np.sinh(np.sqrt(ok)*xx)/np.sqrt(ok)
    else:
        dk = xx
    return dk

# The distance modulus
def dist_mod(zs, om=0.3, orr=0.0, ol=0.7, w0=-1.0, wa=0.0):
    """ Calculate the distance modulus, correcting for curvature"""
    ok = 1.0 - om - orr - ol
    xx = np.array([integrate.quad(ezinv, 0, z, args=(om, orr, ol, w0, wa))[0] for z in zs])
    D = Sk(xx, ok)
    lum_dist = D * (1 + zs) 
    dist_mod = 5 * np.log10(lum_dist) # Distance modulus
    # Add an arbitrary constant that's approximately the log of c on Hubble constant minus absolute magnitude of -19.5
    # dist_mod = dist_mod + np.log(c/H0kmsmpc)-(-19.5)  # You can actually skip this step and it won't make a difference to our fitting
    return dist_mod

# The distance modulus
def dist_mod_test(zs, om=0.3, orr=0.0, ol=0.7, w0=-1.0, wa=0.0):
    """ Calculate the distance modulus, correcting for curvature"""
    ok = 1.0 - om - orr - ol
    keypoints = np.linspace(0.0,max(zs),100)
    xxkey = np.array([integrate.quad(ezinv, 0, z, args=(om, orr, ol, w0, wa))[0] for z in keypoints])
    xx = np.ones([len(zs)])
    for i, z in enumerate(zs):
        closeind = np.argmin(abs(z*np.ones([100]) - keypoints))
        closexxkey = xxkey[closeind]
        closez = keypoints[closeind] 
        if closez < z:
            g = ((xxkey[closeind+1] - closexxkey)/(keypoints[closeind+1] - closez)) 
            a = (closexxkey-(g*closez))
            xx[i] = g*z + a
        elif closez > z:
            g = ((closexxkey - xxkey[closeind-1] )/(closez - keypoints[closeind-1])) 
            a = (closexxkey-(g*closez))
            xx[i] = g*z + a
        else:
            xx[i] = closexxkey
    D = Sk(xx, ok)
    lum_dist = D * (1 + zs) 
    dist_mod = 5 * np.log10(lum_dist) # Distance modulus
    # Add an arbitrary constant that's approximately the log of c on Hubble constant minus absolute magnitude of -19.5
    # dist_mod = dist_mod + np.log(c/H0kmsmpc)-(-19.5)  # You can actually skip this step and it won't make a difference to our fitting
    return dist_mod

# %%
w0=-1.0
wa=0.0
3*(1+w0+(wa*(1-(1/(1+2)))))
# Out:
# 0.0

# %% [markdown]
# ### 3.2 Now read in the data
# I have generated some mock supernova data at random redshifts between $0.02<z<1.0$.  I then choose a cosmological model and calculate the distance modulus for each redshift in that model.  Then I give some uncertainty to the data points and scatter them randomly about the correct model by an amount corresponding to their uncertainty.
#
# I've generated 5 different models, all in files called DataX.txt, where X is a number from 0-4.
#
# There are five possible variables that I have specified in the models.  These are
# * Matter density: $\Omega_M$
# * Dark Energy density: $\Omega_\Lambda$
# * Radiation density: $\Omega_R$
# * Equation of state of dark energy: $w_0$
# * Change in the equation of state with scalefactor: $w_a$, where $w=w_0+w_a(1-a)$.
#
# You can test your code on Data00.txt and Data0.txt.  Both were generated using a model with $(\Omega_M,\Omega_{\Lambda})=(0.3,0.7)$ and all other parameters set to their standard values, namely $\Omega_R=0.0$, $w_0=-1.0$, $w_a=0.0$.  In addition Data00.txt has perfect data with no scatter and small uncertainties, so you should be able to recover exactly the correct model.
#
# Data sets 1-2 are models in which $\Omega_R=0.0$, $w_0=-1.0$, $w_a=0.0$ and only $\Omega_M$ and $\Omega_{\Lambda}$ change.
#
# Data sets 3-4 could be anything! (Within the realms of the five parameters described above.)
#
# Feel free to choose which data set you want to analyse for your project.

# %%
# Add a new function that reads in the data (data files should be in a directory called data)
def read_data(model_name):
    d = np.genfromtxt('data/'+model_name+'.txt',delimiter=',')
    zs = d[:,0]
    mu = d[:,1]
    muerr=d[:,2]
    return zs, mu, muerr

zs, mu, muerr = read_data('Data1')

# Plot it to see what it looks like, this is called a Hubble diagram
plt.errorbar(zs,mu,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
plt.xlim(0,1.0)
plt.xlabel('redshift')
plt.ylabel('magnitude')
plt.show()

# %% [markdown]
# ### 3.3 Calculate the theory corresponding to that data for a range of cosmological models
# Then overplot them on the Hubble diagram.  Here we're just testing some specific interesting examples.
# It's always important to visualise your data and check that the models and data are doing what you think they are!

# %%
mu_om00_ox00 = dist_mod(zs,om=0.0,ol=0.0)  # We're going to use this empty model as a benchmark to compare the others to
mu_om10_ox00 = dist_mod(zs,om=1.0,ol=0.0)
mu_om03_ox00 = dist_mod(zs,om=0.3,ol=0.0)
mu_om03_ox07 = dist_mod(zs,om=0.3,ol=0.7)
test = dist_mod_test(zs,om=0.3,ol=0.7)

# Plot it to see what it looks like, this is called a Hubble diagram
plt.errorbar(zs,mu,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
plt.plot(zs,mu_om00_ox00,':',color='black',label='(0.0, 0.0)')
plt.plot(zs,mu_om10_ox00,'-.',color='red',label='(1.0, 0.0)')
plt.plot(zs,mu_om03_ox00,'--',color='blue',label='(0.3, 0.0)')
plt.plot(zs,mu_om03_ox07,'-',color='green',label='(0.3, 0.7)')
plt.plot(zs,test,'-',color='yellow',label='test')
plt.xlim(0,1.0)
plt.xlabel('redshift')
plt.ylabel('magnitude')
plt.legend(frameon=False)
plt.show()

# Now plot a Hubble diagram relative to the empty model (i.e. subtract the empty model from all the data and models)
plt.errorbar(zs,mu-mu_om00_ox00,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
# plt.plot(zs,mu_om10_ox00-mu_om00_ox00,'-.',color='red',label='(1.0, 0.0)')
# plt.plot(zs,mu_om03_ox00-mu_om00_ox00,'--',color='blue',label='(0.3, 0.0)')
plt.plot(zs,mu_om03_ox07-mu_om00_ox00,'-',color='green',label='(0.3, 0.7)')
plt.plot(zs,test-mu_om00_ox00,'-',color='yellow',label='test')
plt.axhline(y=0.0,ls=':',color='black')
plt.xlim(0.0,1.0)
plt.xlabel('redshift')
plt.ylabel('magnitude normalised to (0,0)')
plt.legend(frameon=False)
plt.show()

# %% [markdown]
# ### 3.4 Normalise the theory
# You can see that there is a vertical offset between the different theory curves.
# We marginalise over this vertical offset, because we do not have enough information to constrain the vertical offset independently.
# In other words we use the data to determine what the vertical offset should be, but we do not care about what the answer is!
# (We are interested in the other parameters in the fit, but not that one.  The other parameters determine the *shape* of the curve.)
#
# The easiest way to normalise the curves is to take a weighted average of the difference between the data points and the theory in each case.

# %%
# Calculate mscript for each of these, which is the thing that determines the vertical normalisation 
mscr_om10_ox00 = np.sum((mu_om10_ox00-mu)/muerr**2)/np.sum(1./muerr**2)
mscr_om03_ox00 = np.sum((mu_om03_ox00-mu)/muerr**2)/np.sum(1./muerr**2)
mscr_om03_ox07 = np.sum((mu_om03_ox07-mu)/muerr**2)/np.sum(1./muerr**2)

print(mscr_om10_ox00,mscr_om03_ox00,mscr_om03_ox07)

mu_om10_ox00=mu_om10_ox00-mscr_om10_ox00
mu_om03_ox00=mu_om03_ox00-mscr_om03_ox00
mu_om03_ox07=mu_om03_ox07-mscr_om03_ox07

# Repeat the plot and see how it changes
# Plot it to see what it looks like, this is called a Hubble diagram
plt.errorbar(zs,mu,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
plt.plot(zs,mu_om10_ox00,'-.',color='red',label='(1.0, 0.0)')
plt.plot(zs,mu_om03_ox00,'--',color='blue',label='(0.3, 0.0)')
plt.plot(zs,mu_om03_ox07,'-',color='green',label='(0.3, 0.7)')
plt.xlim(0,1.0)
plt.xlabel('redshift')
plt.ylabel('magnitude')
plt.legend(frameon=False)
plt.show()

# Now plot a Hubble diagram relative to the empty model (i.e. subtract the empty model from all the data and models)
plt.errorbar(zs,mu-mu_om00_ox00,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
plt.plot(zs,mu_om10_ox00-mu_om00_ox00,'-.',color='red',label='(1.0, 0.0)')
plt.plot(zs,mu_om03_ox00-mu_om00_ox00,'--',color='blue',label='(0.3, 0.0)')
plt.plot(zs,mu_om03_ox07-mu_om00_ox00,'-',color='green',label='(0.3, 0.7)')
# plt.axhline(y=0.0,ls=':',color='black')
plt.xlim(0,1.0)
plt.xlabel('redshift')
plt.ylabel('magnitude normalised to (0,0)')
plt.legend(frameon=False)
plt.show()
# Out:
# -23.560674297134412 -23.390794679460754 -23.206256166105373

# %% [markdown]
# ## 3.5 Perform a fit to many models
# To find the best model that best matches the data use a $\chi^2$ test.

# %%
# Set up the arrays for the models you want to test, e.g. a range of Omega_m and Omega_Lambda models:
n = 21                         # Increase this for a finer grid
oms = np.linspace(0.0, 0.5, n)   # Array of matter densities
ols = np.linspace(0.0, 1.0, n)   # Array of cosmological constant values
chi2 = np.ones((n, n)) * np.inf  # Array to hold our chi2 values, set initially to super large values

# Calculate Chi2 for each model
for i, om in enumerate(oms):                                          # loop through matter densities
        for j, ol in enumerate(ols):                                  # loop through cosmological constant densities
            mu_model = dist_mod_test(zs, om=om, ol=ol)                     # calculate the distance modulus vs redshift for that model 
            mscr = np.sum((mu_model-mu)/muerr**2)/np.sum(1./muerr**2) # Calculate the vertical offset to apply
            mu_model_norm = mu_model-mscr                             # Apply the vertical offset
            chi2[i,j] = np.sum((mu_model_norm - mu) ** 2 / muerr**2)  # Calculate the chi2 and save it in a matrix
            
# Convert that to a likelihood and calculate the reduced chi2
likelihood = np.exp(-0.5 * (chi2-np.amin(chi2)))  # convert the chi^2 to a likelihood (np.amin(chi2) calculates the minimum of the chi^2 array)
chi2_reduced = chi2 / (len(mu)-2)                 # calculate the reduced chi^2, i.e. chi^2 per degree of freedom, where dof = number of data points minus number of parameters being fitted 

# Calculate the best fit values (where chi2 is minimum)
indbest = np.argmin(chi2)                 # Gives index of best fit but where the indices are just a single number
ibest   = np.unravel_index(indbest,[n,n]) # Converts the best fit index to the 2d version (i,j)
print( 'Best fit values are (om,ol)=(%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]] ) )
print( 'Reduced chi^2 for the best fit is %0.2f'%chi2_reduced[ibest[0],ibest[1]] )
print('likelihood = ',likelihood[ibest[0],ibest[1]])


# # Uncomment this code and comment the previous if doing a grid search with three parameters: om, orr, and ol.
# # Set up the arrays for the models you want to test, e.g. a range of Omega_m and Omega_Lambda models:
# n = 25                        # Increase this for a finer grid
# oms = np.linspace(0.0, 0.5, n)   # Array of matter densities
# ols = np.linspace(0.0, 1, n)   # Array of cosmological constant values
# orrs = np.linspace(0.0, 1.0, n)  # Array of radiation densities
# chi2 = np.ones((n, n, n)) * np.inf  # Array to hold our chi2 values, set initially to super large values

# # Calculate Chi2 for each model
# for i, om in enumerate(oms):                                          # loop through matter densities
#         for j, ol in enumerate(ols):
#                 for k, orr in enumerate(orrs):                              # loop through cosmological constant densities
#                     mu_model = dist_mod(zs, om=om, orr=orr, ol=ol)                     # calculate the distance modulus vs redshift for that model 
#                     mscr = np.sum((mu_model-mu)/muerr**2)/np.sum(1./muerr**2) # Calculate the vertical offset to apply
#                     mu_model_norm = mu_model-mscr                             # Apply the vertical offset
#                     chi2[i,j,k] = np.sum((mu_model_norm - mu) ** 2 / muerr**2)  # Calculate the chi2 and save it in a matrix
            
# # Convert that to a likelihood and calculate the reduced chi2
# # likelihood = np.exp(-0.5 * (chi2-np.amin(chi2)))  # convert the chi^2 to a likelihood (np.amin(chi2) calculates the minimum of the chi^2 array)
# chi2_reduced = chi2 / (len(mu)-3)                 # calculate the reduced chi^2, i.e. chi^2 per degree of freedom, where dof = number of data points minus number of parameters being fitted 

# # Calculate the best fit values (where chi2 is minimum)
# indbest = np.argmin(chi2)                 # Gives index of best fit but where the indices are just a single number
# ibest   = np.unravel_index(indbest,[n,n,n]) # Converts the best fit index to the 3d version (i,j,k)
# print( 'Best fit values are (om,ol,orr)=(%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], orrs[ibest[2]] ) )
# print( 'Reduced chi^2 for the best fit is %0.2f'%chi2_reduced[ibest[0],ibest[1],ibest[2]] )
# # print('likelihood = ',likelihood[ibest[0],ibest[1]])



# # Uncomment this code and comment the previous if doing a grid search with three parameters: om, ol, and wa
# # Set up the arrays for the models you want to test, e.g. a range of Omega_m and Omega_Lambda models:
# n = 25                        # Increase this for a finer grid
# oms = np.linspace(0.0, 0.5, n)   # Array of matter densities
# ols = np.linspace(0.0, 1.0, n)   # Array of cosmological constant values
# was = np.linspace(0.0, 1.0, n)  # Array of changes in equation of state
# chi2 = np.ones((n, n, n)) * np.inf  # Array to hold our chi2 values, set initially to super large values

# # Calculate Chi2 for each model
# for i, om in enumerate(oms):                                          # loop through matter densities
#         for j, ol in enumerate(ols):
#                 for k, wa in enumerate(was):                              # loop through cosmological constant densities
#                     mu_model = dist_mod(zs, om=om, wa=wa, ol=ol)                     # calculate the distance modulus vs redshift for that model 
#                     mscr = np.sum((mu_model-mu)/muerr**2)/np.sum(1./muerr**2) # Calculate the vertical offset to apply
#                     mu_model_norm = mu_model-mscr                             # Apply the vertical offset
#                     chi2[i,j,k] = np.sum((mu_model_norm - mu) ** 2 / muerr**2)  # Calculate the chi2 and save it in a matrix
            
# # Convert that to a likelihood and calculate the reduced chi2
# # likelihood = np.exp(-0.5 * (chi2-np.amin(chi2)))  # convert the chi^2 to a likelihood (np.amin(chi2) calculates the minimum of the chi^2 array)
# chi2_reduced = chi2 / (len(mu)-3)                 # calculate the reduced chi^2, i.e. chi^2 per degree of freedom, where dof = number of data points minus number of parameters being fitted 

# # Calculate the best fit values (where chi2 is minimum)
# indbest = np.argmin(chi2)                 # Gives index of best fit but where the indices are just a single number
# ibest   = np.unravel_index(indbest,[n,n,n]) # Converts the best fit index to the 3d version (i,j,k)
# print( 'Best fit values are (om,ol,wa)=(%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], was[ibest[2]] ) )
# print( 'Reduced chi^2 for the best fit is %0.2f'%chi2_reduced[ibest[0],ibest[1],ibest[2]] )
# # print('likelihood = ',likelihood[ibest[0],ibest[1]])


# ##### THIS WILL TAKE A LOOOOOOOONNNG TIME TO RUN.
# # Uncomment this code and comment the previous if doing a grid search with three parameters: om, ol, orr, wa, and w0
# # Set up the arrays for the models you want to test, e.g. a range of Omega_m and Omega_Lambda models:
# n = 10                        # Increase this for a finer grid
# oms = np.linspace(0.0, 0.4, n)   # Array of matter densities
# ols = np.linspace(0.0, 0.4, n)   # Array of cosmological constant values
# was = np.linspace(0.0, 0.5, n)  # Array of changes in equation of state
# orrs = np.linspace(0.0, 0.25, n) # array of radiation densities
# w0s = np.linspace(-1.5, -1.0, n)
# chi2 = np.ones((n, n, n, n, n)) * np.inf  # Array to hold our chi2 values, set initially to super large values

# # Calculate Chi2 for each model
# for i, om in enumerate(oms):    # loop through matter densities                                   
#         for j, ol in enumerate(ols):    # loop through cosmological constant densities
#                 for k, wa in enumerate(was):    # loop through changes in equation of state
#                                 for l, orr in enumerate(orrs):     # loop through radiation densities       
#                                                 for m, w0 in enumerate(w0s):                
#                                                         mu_model = dist_mod(zs, om=om, wa=wa, ol=ol, orr=orr, w0=w0)                     # calculate the distance modulus vs redshift for that model 
#                                                         mscr = np.sum((mu_model-mu)/muerr**2)/np.sum(1./muerr**2) # Calculate the vertical offset to apply
#                                                         mu_model_norm = mu_model-mscr                             # Apply the vertical offset
#                                                         chi2[i,j,k,l,m] = np.sum((mu_model_norm - mu) ** 2 / muerr**2)  # Calculate the chi2 and save it in a matrix
            
# # Convert that to a likelihood and calculate the reduced chi2
# # likelihood = np.exp(-0.5 * (chi2-np.amin(chi2)))  # convert the chi^2 to a likelihood (np.amin(chi2) calculates the minimum of the chi^2 array)
# chi2_reduced = chi2 / (len(mu)-5)                 # calculate the reduced chi^2, i.e. chi^2 per degree of freedom, where dof = number of data points minus number of parameters being fitted 

# # Calculate the best fit values (where chi2 is minimum)
# indbest = np.argmin(chi2)                 # Gives index of best fit but where the indices are just a single number
# ibest   = np.unravel_index(indbest,[n,n,n,n,n]) # Converts the best fit index to the 3d version (i,j,k)
# print( 'Best fit values are (om,ol,wa,orr,w0)=(%.3f,%.3f,%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], was[ibest[2]], orrs[ibest[3]], w0s[ibest[4]] ) )
# print( 'Reduced chi^2 for the best fit is %0.2f'%chi2_reduced[ibest[0],ibest[1],ibest[2],ibest[3],ibest[4]] )
# #For a good fit, the reduced Chi^2 should be close to 1.
# Out:
# Best fit values are (om,ol)=(0.150,0.700)
# Reduced chi^2 for the best fit is 1.12
# likelihood =  1.0

# %%
chi2
# Out:
# array([[319.29658381, 300.96776818, 283.973709  , 268.4816708 ,
#         254.68207448, 242.79254444, 233.06284573, 225.78095287,
#         221.28057249, 219.95055327, 222.24677537, 228.70733975,
#         239.97221323, 256.80898781, 280.14718294, 311.12473222,
#         351.15225943, 402.00404043, 465.95028475, 545.95584617,
#         645.99069857],
#        [336.40199505, 316.88975756, 298.58097637, 281.62602181,
#         266.19563704, 252.48440512, 240.71495628, 231.14311012,
#         224.06421001, 219.82099295, 218.81345892, 221.5113756 ,
#         228.47030367, 240.35239532, 257.95377284, 282.24115004,
#         314.40171487, 355.9125093 , 408.63929544, 474.98152047,
#         558.09226457],
#        [354.78751345, 334.19813207, 314.69311604, 296.40781376,
#         279.49553149, 264.1305109 , 250.51152386, 238.86624228,
#         229.45658917, 222.58534384, 218.60436664, 217.9249389 ,
#         221.03089989, 228.49553355, 241.00355973, 259.38019451,
#         284.63019086, 317.99128437, 361.00896273, 415.6437452 ,
#         484.4297782 ],
#        [374.37584159, 352.80735389, 332.21515251, 312.72121104,
#         294.46336173, 277.59785862, 262.3024571 , 248.78013784,
#         237.2636412 , 228.02102979, 221.36256846, 217.64930981,
#         217.30391348, 220.82442846, 228.8020615 , 241.94439292,
#         261.10616919, 287.33084618, 321.90773807, 366.45242117,
#         423.02287018],
#        [395.09493859, 372.63787554, 351.05896738, 330.46826508,
#         310.98985016, 292.76404631, 275.95006416, 260.72918368,
#         247.30860794, 235.92616309, 226.85607424, 220.41612256,
#         216.97659523, 216.97158961, 220.91344933, 229.41142775,
#         243.19614944, 263.15216953, 290.3620772 , 326.1674468 ,
#         372.25505234],
#        [416.87758393, 393.61562708, 371.14269312, 349.55819326,
#         328.97397457, 309.5162327 , 291.32778905, 274.5708176 ,
#         259.4301299 , 246.11715898, 234.87482513, 225.98352533,
#         219.76856816, 216.60948913, 216.95184122, 221.32228745,
#         230.34816362, 244.78319273, 265.54182352, 293.74591592,
#         330.78953337],
#        [439.66098473, 415.67155598, 392.39017113, 369.906737  ,
#         348.32220308, 327.75021953, 308.31910278, 290.17417821,
#         273.48058856, 258.42668133, 245.22812207, 234.13292528,
#         225.42765631, 219.4451425 , 216.5741517 , 217.27166604,
#         222.07862637, 231.64038727, 246.73367386, 268.30268304,
#         297.50832393],
#        [463.38642133, 438.7412134 , 414.73046622, 391.43558891,
#         368.94781432, 347.36963966, 326.81652726, 307.41892282,
#         289.32466321, 272.70186572, 257.74241703, 244.66621453,
#         233.72636057, 225.21557401, 219.47417384, 216.90011498,
#         217.96173667, 223.21414553, 233.32054228, 249.08038831,
#         271.46721592],
#        [487.99892688, 462.76438124, 438.09743053, 414.07188022,
#         390.77029165, 368.2852367 , 346.72077329, 326.19418873,
#         306.83807004, 288.80277622, 272.25940747, 257.40339417,
#         244.45886446, 233.68399858, 225.377646  , 219.88757485,
#         217.62085537, 219.0570681 , 224.76530235, 235.42631827,
#         251.86186367],
#        [513.44699705, 487.68473547, 462.42931115, 437.74772119,
#         413.71478189, 390.41422423, 367.93997716, 346.39767771,
#         325.90645651, 306.6010598 , 288.63438517, 272.18052962,
#         257.43847676, 244.63658783, 234.03811233, 225.94800459,
#         220.72143001, 218.77448235, 220.59783022, 226.77429717,
#         238.00180463],
#        [539.68232666, 513.44954145, 487.66839613, 462.39978791,
#         437.71161073, 413.67971414, 390.38902245, 367.9348466 ,
#         346.42442861, 325.97876904, 306.73479992, 288.84798331,
#         272.49543665, 257.87971619, 245.2334282 , 234.82489104,
#         226.9651438 , 222.01669789, 220.40457048, 222.63034132,
#         229.29026972],
#        [566.65957019, 540.00937775, 513.76069468, 487.96895029,
#         462.69584773, 438.0102055 , 413.98893621, 390.71818953,
#         368.29469246, 346.82732825, 326.43900532, 307.26888093,
#         289.47502144, 273.2376039 , 258.76279336, 246.28747097,
#         236.08504219, 228.47262905, 223.82005412, 222.56116922,
#         225.20828911],
#        [594.33612367, 567.31788539, 540.65564755, 514.39993614,
#         488.60691501, 463.33912646, 438.66634971, 414.66659979,
#         391.4272944 , 369.04662293, 347.63515979, 327.31777499,
#         308.23590816, 290.55029021, 274.44421994, 260.12753362,
#         247.84144679, 237.86450352, 230.51994406, 226.1849076 ,
#         225.30203414],
#        [622.67192583, 595.33153965, 568.30586435, 541.64102748,
#         515.38823457, 489.60442272, 464.35301595, 439.70480096,
#         415.73894657, 392.54419507, 370.22026036, 348.87947628,
#         328.64874917, 309.67188268, 292.11236093, 276.15669994,
#         262.01850849, 249.94344189, 240.21528842, 233.16350575,
#         229.17263091],
#        [651.62927633, 624.00944226, 596.66688486, 569.64378538,
#         542.98690969, 516.74818705, 490.98537669, 465.76283845,
#         441.15242651, 417.23453017, 394.09929047, 371.84802843,
#         350.59492945, 330.46903898, 311.61663934, 294.20409567,
#         278.42128334, 264.48574116, 252.64773746, 243.19649332,
#         236.46788537],
#        [681.17266955, 653.31313166, 625.69696179, 598.36280015,
#         571.35343666, 544.71632506, 518.50417335, 492.77562417,
#         467.59604154, 443.03842366, 419.18446613, 396.12580528,
#         373.96547817, 352.81964485, 332.81962948, 314.11435178,
#         296.87323877, 281.2897318 , 267.58553629, 256.01580494,
#         246.87550321],
#        [711.26864228, 683.2064096 , 655.35686268, 627.75546429,
#         600.44144336, 573.45825318, 546.8540963 , 520.68252761,
#         495.00314958, 469.88241638, 445.39456719, 421.62271377,
#         398.66011253, 376.61165894, 355.59565079, 335.74587861,
#         317.21411643, 300.17310519, 284.8201468 , 271.38145962,
#         260.11749088],
#        [741.88563392, 713.65518243, 685.60968902, 657.78176564,
#         630.2074519 , 602.92662507, 575.98346839, 549.42700794,
#         523.31172956, 497.69829046, 472.65434245, 448.25548806,
#         424.58639489, 401.74209981, 379.82954157, 358.96937008,
#         339.29809219, 320.97062956, 304.16338386, 289.07793075,
#         275.94549855],
#        [772.99385814, 744.62731562, 716.42071092, 688.40409873,
#         660.61066267, 633.07708346, 605.84395864, 578.95628235,
#         552.46399541, 526.42261793, 500.89397918, 475.94706263,
#         451.65898769, 428.11615474, 405.41558599, 383.66650218,
#         362.99218516, 343.53218852, 325.44497475, 308.91107824,
#         294.13692074],
#        [804.56518473, 776.0925002 , 747.75721557, 719.58709242,
#         691.61275747, 663.86803465, 636.39032279, 609.22102642,
#         582.40604851, 555.99635571, 530.0486289 , 504.62601416,
#         479.79899284, 455.64639329, 432.25657176, 409.72879642,
#         388.17487659, 367.72108933, 348.51046886, 330.70554153,
#         314.49161136],
#        [836.57303085, 808.02212999, 779.58836836, 751.29745219,
#         723.17771997, 695.2604432 , 667.58016783, 640.17510288,
#         613.08756405, 586.36448142, 560.05798242, 534.2260632 ,
#         508.93336447, 484.25207127, 460.26296027, 437.05662378,
#         414.73490621, 393.41259752, 373.21943923, 354.30251298,
#         336.82910048]])

# %%
# Use this cell if doing a grid search of two parameters. No 3-parameter version of this yet.
# Plot contours of 1, 2, and 3 sigma
plt.contour(oms,ols,np.transpose(chi2-np.amin(chi2)),cmap="winter",**{'levels':[2.30,6.18,11.83]})
plt.plot(oms[ibest[0]], ols[ibest[1]],'x',color='black',label='(om,ol)=(%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]]) )
plt.xlabel("$\Omega_m$", fontsize=12)
plt.ylabel("$\Omega_\Lambda$", fontsize=12)
# plt.plot([oms[0],oms[1]], [ols[0],ols[1]],'-',color='black',label='Step size indicator' ) # Delete this line after making step size smaller!
plt.legend(frameon=False)
#plt.savefig('plots/contours.png', bbox_inches="tight", transparent=True)
plt.show()
plt.close()

# %%
print(chi2-np.amin(chi2))
print(len(chi2))
print(np.sum(np.exp(-0.5 * (chi2))))
# Out:
# [[1.02722432e+02 8.43936165e+01 6.73995573e+01 5.19075191e+01
#   3.81079228e+01 2.62183927e+01 1.64886940e+01 9.20680118e+00
#   4.70642079e+00 3.37640157e+00 5.67262367e+00 1.21331880e+01
#   2.33980615e+01 4.02348361e+01 6.35730312e+01 9.45505805e+01
#   1.34578108e+02 1.85429889e+02 2.49376133e+02 3.29381694e+02
#   4.29416547e+02]
#  [1.19827843e+02 1.00315606e+02 8.20068247e+01 6.50518701e+01
#   4.96214853e+01 3.59102534e+01 2.41408046e+01 1.45689584e+01
#   7.49005831e+00 3.24684126e+00 2.23930722e+00 4.93722390e+00
#   1.18961520e+01 2.37782436e+01 4.13796211e+01 6.56669983e+01
#   9.78275632e+01 1.39338358e+02 1.92065144e+02 2.58407369e+02
#   3.41518113e+02]
#  [1.38213362e+02 1.17623980e+02 9.81189643e+01 7.98336621e+01
#   6.29213798e+01 4.75563592e+01 3.39373722e+01 2.22920906e+01
#   1.28824375e+01 6.01119214e+00 2.03021494e+00 1.35078720e+00
#   4.45674819e+00 1.19213819e+01 2.44294080e+01 4.28060428e+01
#   6.80560392e+01 1.01417133e+02 1.44434811e+02 1.99069594e+02
#   2.67855627e+02]
#  [1.57801690e+02 1.36233202e+02 1.15641001e+02 9.61470593e+01
#   7.78892100e+01 6.10237069e+01 4.57283054e+01 3.22059861e+01
#   2.06894895e+01 1.14468781e+01 4.78841676e+00 1.07515811e+00
#   7.29761783e-01 4.25027676e+00 1.22279098e+01 2.53702412e+01
#   4.45320175e+01 7.07566945e+01 1.05333586e+02 1.49878269e+02
#   2.06448718e+02]
#  [1.78520787e+02 1.56063724e+02 1.34484816e+02 1.13894113e+02
#   9.44156985e+01 7.61898946e+01 5.93759125e+01 4.41550320e+01
#   3.07344562e+01 1.93520114e+01 1.02819225e+01 3.84197086e+00
#   4.02443535e-01 3.97437912e-01 4.33929763e+00 1.28372761e+01
#   2.66219977e+01 4.65780178e+01 7.37879255e+01 1.09593295e+02
#   1.55680901e+02]
#  [2.00303432e+02 1.77041475e+02 1.54568541e+02 1.32984042e+02
#   1.12399823e+02 9.29420810e+01 7.47536374e+01 5.79966659e+01
#   4.28559782e+01 2.95430073e+01 1.83006734e+01 9.40937363e+00
#   3.19441646e+00 3.53374349e-02 3.77689519e-01 4.74813575e+00
#   1.37740119e+01 2.82090410e+01 4.89676718e+01 7.71717642e+01
#   1.14215382e+02]
#  [2.23086833e+02 1.99097404e+02 1.75816019e+02 1.53332585e+02
#   1.31748051e+02 1.11176068e+02 9.17449511e+01 7.36000265e+01
#   5.69064369e+01 4.18525296e+01 2.86539704e+01 1.75587736e+01
#   8.85350461e+00 2.87099080e+00 0.00000000e+00 6.97514346e-01
#   5.50447468e+00 1.50662356e+01 3.01595222e+01 5.17285313e+01
#   8.09341722e+01]
#  [2.46812270e+02 2.22167062e+02 1.98156315e+02 1.74861437e+02
#   1.52373663e+02 1.30795488e+02 1.10242376e+02 9.08447711e+01
#   7.27505115e+01 5.61277140e+01 4.11682653e+01 2.80920628e+01
#   1.71522089e+01 8.64142231e+00 2.90002215e+00 3.25963278e-01
#   1.38758498e+00 6.63999383e+00 1.67463906e+01 3.25062366e+01
#   5.48930642e+01]
#  [2.71424775e+02 2.46190230e+02 2.21523279e+02 1.97497729e+02
#   1.74196140e+02 1.51711085e+02 1.30146622e+02 1.09620037e+02
#   9.02639183e+01 7.22286245e+01 5.56852558e+01 4.08292425e+01
#   2.78847128e+01 1.71098469e+01 8.80349431e+00 3.31342315e+00
#   1.04670368e+00 2.48291641e+00 8.19115065e+00 1.88521666e+01
#   3.52877120e+01]
#  [2.96872845e+02 2.71110584e+02 2.45855159e+02 2.21173569e+02
#   1.97140630e+02 1.73840073e+02 1.51365825e+02 1.29823526e+02
#   1.09332305e+02 9.00269081e+01 7.20602335e+01 5.56063779e+01
#   4.08643251e+01 2.80624361e+01 1.74639606e+01 9.37385289e+00
#   4.14727831e+00 2.20033065e+00 4.02367852e+00 1.02001455e+01
#   2.14276529e+01]
#  [3.23108175e+02 2.96875390e+02 2.71094244e+02 2.45825636e+02
#   2.21137459e+02 1.97105562e+02 1.73814871e+02 1.51360695e+02
#   1.29850277e+02 1.09404617e+02 9.01606482e+01 7.22738316e+01
#   5.59212849e+01 4.13055645e+01 2.86592765e+01 1.82507393e+01
#   1.03909921e+01 5.44254619e+00 3.83041878e+00 6.05618962e+00
#   1.27161180e+01]
#  [3.50085418e+02 3.23435226e+02 2.97186543e+02 2.71394799e+02
#   2.46121696e+02 2.21436054e+02 1.97414785e+02 1.74144038e+02
#   1.51720541e+02 1.30253177e+02 1.09864854e+02 9.06947292e+01
#   7.29008697e+01 5.66634522e+01 4.21886417e+01 2.97133193e+01
#   1.95108905e+01 1.18984773e+01 7.24590243e+00 5.98701752e+00
#   8.63413741e+00]
#  [3.77761972e+02 3.50743734e+02 3.24081496e+02 2.97825784e+02
#   2.72032763e+02 2.46764975e+02 2.22092198e+02 1.98092448e+02
#   1.74853143e+02 1.52472471e+02 1.31061008e+02 1.10743623e+02
#   9.16617565e+01 7.39761385e+01 5.78700682e+01 4.35533819e+01
#   3.12672951e+01 2.12903518e+01 1.39457924e+01 9.61075590e+00
#   8.72788244e+00]
#  [4.06097774e+02 3.78757388e+02 3.51731713e+02 3.25066876e+02
#   2.98814083e+02 2.73030271e+02 2.47778864e+02 2.23130649e+02
#   1.99164795e+02 1.75970043e+02 1.53646109e+02 1.32305325e+02
#   1.12074597e+02 9.30977310e+01 7.55382092e+01 5.95825482e+01
#   4.54443568e+01 3.33692902e+01 2.36411367e+01 1.65893541e+01
#   1.25984792e+01]
#  [4.35055125e+02 4.07435291e+02 3.80092733e+02 3.53069634e+02
#   3.26412758e+02 3.00174035e+02 2.74411225e+02 2.49188687e+02
#   2.24578275e+02 2.00660378e+02 1.77525139e+02 1.55273877e+02
#   1.34020778e+02 1.13894887e+02 9.50424876e+01 7.76299440e+01
#   6.18471316e+01 4.79115895e+01 3.60735858e+01 2.66223416e+01
#   1.98937337e+01]
#  [4.64598518e+02 4.36738980e+02 4.09122810e+02 3.81788648e+02
#   3.54779285e+02 3.28142173e+02 3.01930022e+02 2.76201472e+02
#   2.51021890e+02 2.26464272e+02 2.02610314e+02 1.79551654e+02
#   1.57391326e+02 1.36245493e+02 1.16245478e+02 9.75402001e+01
#   8.02990871e+01 6.47155801e+01 5.10113846e+01 3.94416532e+01
#   3.03013515e+01]
#  [4.94694491e+02 4.66632258e+02 4.38782711e+02 4.11181313e+02
#   3.83867292e+02 3.56884101e+02 3.30279945e+02 3.04108376e+02
#   2.78428998e+02 2.53308265e+02 2.28820415e+02 2.05048562e+02
#   1.82085961e+02 1.60037507e+02 1.39021499e+02 1.19171727e+02
#   1.00639965e+02 8.35989535e+01 6.82459951e+01 5.48073079e+01
#   4.35433392e+01]
#  [5.25311482e+02 4.97081031e+02 4.69035537e+02 4.41207614e+02
#   4.13633300e+02 3.86352473e+02 3.59409317e+02 3.32852856e+02
#   3.06737578e+02 2.81124139e+02 2.56080191e+02 2.31681336e+02
#   2.08012243e+02 1.85167948e+02 1.63255390e+02 1.42395218e+02
#   1.22723940e+02 1.04396478e+02 8.75892322e+01 7.25037791e+01
#   5.93713469e+01]
#  [5.56419706e+02 5.28053164e+02 4.99846559e+02 4.71829947e+02
#   4.44036511e+02 4.16502932e+02 3.89269807e+02 3.62382131e+02
#   3.35889844e+02 3.09848466e+02 2.84319827e+02 2.59372911e+02
#   2.35084836e+02 2.11542003e+02 1.88841434e+02 1.67092350e+02
#   1.46418033e+02 1.26958037e+02 1.08870823e+02 9.23369265e+01
#   7.75627690e+01]
#  [5.87991033e+02 5.59518349e+02 5.31183064e+02 5.03012941e+02
#   4.75038606e+02 4.47293883e+02 4.19816171e+02 3.92646875e+02
#   3.65831897e+02 3.39422204e+02 3.13474477e+02 2.88051862e+02
#   2.63224841e+02 2.39072242e+02 2.15682420e+02 1.93154645e+02
#   1.71600725e+02 1.51146938e+02 1.31936317e+02 1.14131390e+02
#   9.79174597e+01]
#  [6.19998879e+02 5.91447978e+02 5.63014217e+02 5.34723300e+02
#   5.06603568e+02 4.78686292e+02 4.51006016e+02 4.23600951e+02
#   3.96513412e+02 3.69790330e+02 3.43483831e+02 3.17651912e+02
#   2.92359213e+02 2.67677920e+02 2.43688809e+02 2.20482472e+02
#   1.98160755e+02 1.76838446e+02 1.56645288e+02 1.37728361e+02
#   1.20254949e+02]]
# 21
# 1.2441120267222081e-46

# %%
# # Use this cell if doing a grid search of two parameters.
# mu_BestFit = dist_mod(zs,om=oms[ibest[0]],ol=ols[ibest[1]])
# mscr_BestFit = np.sum((mu_BestFit-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_BestFit=mu_BestFit-mscr_BestFit


# mu_om07_ox00 = dist_mod(zs,0.7, ol=0.0, orr=0.0)
# mscr_om07_ox00 = np.sum((mu_om07_ox00-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_om07_ox00=mu_om07_ox00-mscr_om07_ox00

# plt.errorbar(zs,mu-mu_om00_ox00,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
# # plt.plot(zs,mu_om10_ox00-mu_om00_ox00,'-.',color='red',label='(1.0, 0.0)')
# # plt.plot(zs,mu_om03_ox00-mu_om00_ox00,'--',color='blue',label='(0.3, 0.0)')
# # plt.plot(zs,mu_om03_ox07-mu_om00_ox00,'-',color='green',label='(0.3, 0.7)')
# plt.plot(zs,mu_om07_ox00-mu_om00_ox00,'--',color='green',label='(0.7, 0.0)')
# plt.plot(zs,mu_BestFit-mu_om00_ox00,'-',color='black',label='(om,ol)=(%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]] ))
# # plt.axhline(y=0.0,ls=':',color='black')
# plt.xlim(0,1.0)
# plt.xlabel('redshift')
# plt.ylabel('magnitude normalised to (0,0)')
# plt.legend(frameon=False)
# plt.show()



# # Uncomment this code and comment the previous if doing a grid search with three parameters: om, orr, and ol.
# mu_BestFit = dist_mod(zs,om=oms[ibest[0]], ol=ols[ibest[1]], orr=orrs[ibest[2]])
# mscr_BestFit = np.sum((mu_BestFit-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_BestFit=mu_BestFit-mscr_BestFit

# mu_om05_ox00 = dist_mod(zs,om=0.5, ol=0.0, orr=0.0)
# mscr_om05_ox00 = np.sum((mu_om05_ox00-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_om05_ox00=mu_om05_ox00-mscr_om05_ox00

# mu_test = dist_mod(zs,om=0.333, ol=0.292, orr=0.0)
# mscr_test = np.sum((mu_test-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_test=mu_test-mscr_test

# plt.errorbar(zs,mu-mu_om00_ox00,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
# # plt.plot(zs,mu_om10_ox00-mu_om00_ox00,'-.',color='red',label='(1.0, 0.0)')
# # plt.plot(zs,mu_om03_ox00-mu_om00_ox00,'--',color='blue',label='(0.3, 0.0)')
# # plt.plot(zs,mu_om05_ox00-mu_om00_ox00,'--',color='green',label='(0.5, 0.0)')
# plt.plot(zs,mu_test-mu_om00_ox00,'--',color='purple',label='(missing)')

# plt.plot(zs,mu_om03_ox07-mu_om00_ox00,'-',color='green',label='(0.3, 0.7)')
# plt.plot(zs,mu_BestFit-mu_om00_ox00,'-',color='black',label='(om, ol, orr)=(%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], orrs[ibest[2]] ))
# # plt.axhline(y=0.0,ls=':',color='black')
# plt.xlim(0,1.0)
# plt.xlabel('redshift')
# plt.ylabel('magnitude normalised to (0,0)')
# plt.legend(frameon=False)
# plt.show()


# # Uncomment this code and comment the previous if doing a grid search with three parameters: om, ol, and wa.
# mu_BestFit = dist_mod(zs,om=oms[ibest[0]], ol=ols[ibest[1]], wa=was[ibest[2]])
# mscr_BestFit = np.sum((mu_BestFit-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_BestFit=mu_BestFit-mscr_BestFit


# mu_om05_ox00 = dist_mod(zs,0.5, ol=0.0, orr=0.0)
# mscr_om05_ox00 = np.sum((mu_om05_ox00-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_om05_ox00=mu_om05_ox00-mscr_om05_ox00

# plt.errorbar(zs,mu-mu_om00_ox00,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
# # plt.plot(zs,mu_om10_ox00-mu_om00_ox00,'-.',color='red',label='(1.0, 0.0)')
# # plt.plot(zs,mu_om03_ox00-mu_om00_ox00,'--',color='blue',label='(0.3, 0.0)')
# # plt.plot(zs,mu_om05_ox00-mu_om00_ox00,'--',color='green',label='(0.5, 0.0)')

# plt.plot(zs,mu_om03_ox07-mu_om00_ox00,'-',color='green',label='(0.3, 0.7)')
# plt.plot(zs,mu_BestFit-mu_om00_ox00,'-',color='black',label='(om, ol, wa)=(%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], was[ibest[2]] ))
# # plt.axhline(y=0.0,ls=':',color='black')
# plt.xlim(0,1.0)
# plt.xlabel('redshift')
# plt.ylabel('magnitude normalised to (0,0)')
# plt.legend(frameon=False)
# plt.show()


# # Uncomment this code and comment the previous if doing a grid search with three parameters: om, ol, and wa.
# mu_BestFit = dist_mod(zs,om=oms[ibest[0]], ol=ols[ibest[1]], wa=was[ibest[2]], orr=orrs[ibest[3]], w0=w0s[ibest[4]])
# mscr_BestFit = np.sum((mu_BestFit-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_BestFit=mu_BestFit-mscr_BestFit


# # mu_om05_ox00 = dist_mod(zs,0.5, ol=0.0, orr=0.0)
# # mscr_om05_ox00 = np.sum((mu_om05_ox00-mu)/muerr**2)/np.sum(1./muerr**2)
# # mu_om05_ox00=mu_om05_ox00-mscr_om05_ox00

# plt.errorbar(zs,mu-mu_om00_ox00,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
# # plt.plot(zs,mu_om10_ox00-mu_om00_ox00,'-.',color='red',label='(1.0, 0.0)')
# # plt.plot(zs,mu_om03_ox00-mu_om00_ox00,'--',color='blue',label='(0.3, 0.0)')
# # plt.plot(zs,mu_om05_ox00-mu_om00_ox00,'--',color='green',label='(0.5, 0.0)')

# plt.plot(zs,mu_om03_ox07-mu_om00_ox00,'-',color='green',label='(0.3, 0.7)')
# plt.plot(zs,mu_BestFit-mu_om00_ox00,'-',color='black',label='(om, ol, wa, orr, w0)=(%.3f,%.3f,%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], was[ibest[2]], orrs[ibest[3]], w0s[ibest[4]] ))
# # plt.axhline(y=0.0,ls=':',color='black')
# plt.xlim(0,1.0)
# plt.xlabel('redshift')
# plt.ylabel('magnitude normalised to (0,0)')
# plt.legend(frameon=False)
# plt.show()

# %% [markdown]
# ### 3.6 Now fit the real data!!

# %% [markdown]
# The Dark Energy Survey recently released a set of 1635 new high-redshift supernovae, which they combined with 194 low-redshift supernovae to make the state-of-the-art supernova data set. You can read about it here: https://ui.adsabs.harvard.edu/abs/2024arXiv240102929D/abstract

# %% [markdown]
# The data are all available from here: https://github.com/des-science/DES-SN5YR Go into 4_DISTANCES_COVMAT and download the Hubble diagram from DES-SN5YR_HD.csv and the covariance matrix from STAT+SYS.txt.gz Use gunzip STAT+SYS.txt.gz to unzip it.
#
# Here's a snippet of code to read in the data:

# %%
import pandas as pd  # Pandas is a useful package to read in data files and select portions of the data
from matplotlib import pyplot as plt
import numpy as np

df = pd.read_csv('data/DES-SN5YR_HD.csv') # Pandas reads into a "data frame (we'll call it df)"
zHELs = df['zHEL'].to_numpy() # You can keep using it in Pandas format, but just turning it into numpy arrays so it matches what you did above. 
zHDs = df['zHD'].to_numpy()
mu = df['MU'].to_numpy()
muerr = df['MUERR_FINAL'].to_numpy()
nSN = len(zHDs)
print(nSN)

hubblediagram=plt.scatter(zHDs,mu,marker='.',c=muerr,alpha=0.4)
plt.xlabel('redshift')
plt.ylabel('distance modulus ($\mu$)')
cbar=plt.colorbar(hubblediagram)
cbar.set_label('$\mu$ uncertainty', rotation=270)
plt.ylim(35,45)
plt.show()

# Warning, with this many data points it's going to take a long time to do the fit!  Test with a small grid first!  
# And consider adding interpolation to determine luminosity distances instead of doing this many integrals.
# Out:
# 1829

# %%
# To do this properly, you really should use the covariance matrix, rather than just the diagonal errors. 
# It's optional for this project, but here's how you construct the covariance matrix from the file provided.

df2 = pd.read_csv('data/STAT+SYS.txt.gz', skiprows = 1, delim_whitespace=True,comment='#',names=['COV'], compression='gzip')
cov1d=df2['COV'].to_numpy()
cov2d=cov1d.reshape(len(mu),len(mu))  
muerr_diag = np.diag(muerr)**2
cov2d=cov2d+muerr_diag
acov = np.linalg.inv(cov2d)

# %%
n = 10                        # Increase this for a finer grid
oms = np.linspace(0.2, 0.4, n)   # Array of matter densities
ols = np.linspace(0.6, 0.8, n)   # Array of cosmological constant values
was = np.linspace(-1, 1, n)  # Array of changes in equation of state
orrs = np.linspace(0.0, 0.1, n) # array of radiation densities
w0s = np.linspace(-0.9, -0.4, n)
chi2 = np.ones((n, n, n, n, n)) * np.inf  # Array to hold our chi2 values, set initially to super large values



# Calculate Chi2 for each model
for i, om in enumerate(oms):    # loop through matter densities                                   
        for j, ol in enumerate(ols):    # loop through cosmological constant densities
                for k, wa in enumerate(was):    # loop through changes in equation of state
                                for l, orr in enumerate(orrs):     # loop through radiation densities       
                                                for m, w0 in enumerate(w0s):                
                                                        mu_model = dist_mod_test(zHDs, om=om, wa=wa, ol=ol, orr=orr, w0=w0)                     # calculate the distance modulus vs redshift for that model 
                                                        mscr = np.sum((mu_model-mu)/muerr**2)/np.sum(1./muerr**2) # Calculate the vertical offset to apply
                                                        # mu_model_norm = mu_model-mscr  # Apply the vertical offset
                                                        delta = np.array([mu_model - mscr - mu]) 
                                                        chi2[i,j,k,l,m]  = np.sum(delta @ acov @ np.transpose(delta)) # Calculate the chi2 and save it in a matrix




                                                       

# Convert that to a likelihood and calculate the reduced chi2
likelihood = np.exp(-0.5 * (chi2-np.amin(chi2)))  # convert the chi^2 to a likelihood (np.amin(chi2) calculates the minimum of the chi^2 array)
chi2_reduced = chi2 / (len(mu)-1-5)                 # calculate the reduced chi^2, i.e. chi^2 per degree of freedom, where dof = number of data points minus number of parameters being fitted 

# Calculate the best fit values (where chi2 is minimum)
indbest = np.argmin(chi2)                 # Gives index of best fit but where the indices are just a single number
ibest   = np.unravel_index(indbest,[n,n,n,n,n]) # Converts the best fit index to the 5d version
print( 'Best fit values are (om,ol,wa,orr,w0)=(%.3f,%.3f,%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], was[ibest[2]], orrs[ibest[3]], w0s[ibest[4]] ) )
print( 'Reduced chi^2 for the best fit is %0.2f'%chi2_reduced[ibest[0],ibest[1],ibest[2],ibest[3],ibest[4]] )
#For a good fit, the reduced Chi^2 should be close to 1.
# Out:
# Best fit values are (om,ol,wa,orr,w0)=(0.222,0.600,-1.000,0.089,-0.900)
# Reduced chi^2 for the best fit is 0.90

# %%
print(likelihood)
# Out:
# [[[[[3.85075921e-041 2.43692006e-038 1.37627331e-035 ...
#      8.34430450e-023 1.69800009e-020 2.73064932e-018]
#     [1.25807750e-034 4.41360388e-032 1.36892573e-029 ...
#      3.64122502e-018 3.87331740e-016 3.23425572e-014]
#     [6.69734176e-029 1.35322282e-026 2.39637958e-024 ...
#      3.42674252e-014 1.98764136e-012 8.99313258e-011]
#     ...
#     [4.42270166e-010 9.00200739e-009 1.54982048e-007 ...
#      1.17295345e-002 5.47659670e-002 1.94314919e-001]
#     [5.88745646e-008 8.16687533e-007 9.52697149e-006 ...
#      9.49577157e-002 2.91256792e-001 6.75947643e-001]
#     [2.72126946e-006 2.62648162e-005 2.12023037e-004 ...
#      3.10776738e-001 6.40737366e-001 9.95497766e-001]]
#
#    [[1.63727521e-035 8.79582968e-033 4.09676166e-030 ...
#      5.70556980e-018 7.69263447e-016 7.83676307e-014]
#     [1.32190363e-029 3.84829115e-027 9.62796585e-025 ...
#      5.33023987e-014 3.69492597e-012 1.92480961e-010]
#     [1.91921280e-024 3.15093984e-022 4.40966758e-020 ...
#      1.19762860e-010 4.45737403e-009 1.24030442e-007]
#     ...
#     [6.21420707e-008 9.44456356e-007 1.18323644e-005 ...
#      1.17362573e-001 3.30000219e-001 6.78869857e-001]
#     [3.45163438e-006 3.52695663e-005 2.95449361e-004 ...
#      3.63468468e-001 6.64473715e-001 8.85529396e-001]
#     [7.00642200e-005 4.91857595e-004 2.81610584e-003 ...
#      4.81691426e-001 5.86222226e-001 5.18305407e-001]]
#
#    [[4.98533193e-030 2.13271932e-027 7.64716816e-025 ...
#      1.59773536e-013 1.28725595e-011 7.44338157e-010]
#     [9.43410227e-025 2.14099695e-022 4.04025828e-020 ...
#      3.07881625e-010 1.25860071e-008 3.67850890e-007]
#     [3.55816741e-020 4.46506883e-018 4.62468191e-016 ...
#      1.59541947e-007 3.45835384e-006 5.34002871e-005]
#     ...
#     [4.66105253e-006 4.99981740e-005 4.29283843e-004 ...
#      3.89124529e-001 6.04925400e-001 6.59187490e-001]
#     [1.04799774e-004 7.46147593e-004 4.23068175e-003 ...
#      4.50776088e-001 4.51708885e-001 3.16410317e-001]
#     [9.08330120e-004 4.38991581e-003 1.68159513e-002 ...
#      2.36901597e-001 1.56759245e-001 7.23194103e-002]]
#
#    ...
#
#    [[1.18050834e-007 3.76611474e-006 7.72737523e-005 ...
#      1.11877636e-001 7.73533169e-002 2.65633338e-002]
#     [8.80972218e-006 1.40688909e-004 1.44613216e-003 ...
#      6.93726493e-002 2.46942629e-002 4.40312980e-003]
#     [2.28159275e-004 1.90625062e-003 1.02558861e-002 ...
#      2.01420413e-002 3.84284364e-003 3.70056815e-004]
#     ...
#     [3.55899733e-003 2.00430469e-003 7.26491330e-004 ...
#      2.25446007e-009 3.14223101e-011 2.27437256e-013]
#     [6.09573212e-004 2.18886397e-004 5.05663782e-005 ...
#      1.67652729e-011 1.50582268e-013 7.05383027e-016]
#     [5.38402152e-005 1.26352897e-005 1.90683056e-006 ...
#      7.62414055e-014 4.51775713e-016 1.40169598e-018]]
#
#    [[5.21089547e-005 6.53643872e-004 4.89051315e-003 ...
#      1.33009301e-002 2.00958166e-003 1.37278104e-004]
#     [7.76534929e-004 4.89615812e-003 1.84766117e-002 ...
#      1.79603225e-003 1.43055895e-004 5.21060064e-006]
#     [4.48752162e-003 1.48491240e-002 2.94932812e-002 ...
#      1.25422174e-004 5.46917414e-006 1.10184229e-007]
#     ...
#     [1.49087268e-004 3.34618036e-005 4.54890402e-006 ...
#      3.85827280e-014 1.32993483e-016 2.20315214e-019]
#     [9.29428559e-006 1.33029702e-006 1.15451882e-007 ...
#      1.08115007e-016 2.43005282e-019 2.64100140e-022]
#     [3.17274023e-007 2.96780285e-008 1.68484221e-009 ...
#      1.96004648e-019 2.93813432e-022 2.14166331e-025]]
#
#    [[2.40029637e-003 9.85513510e-003 2.22189809e-002 ...
#      3.96678850e-005 1.04435368e-006 1.12736103e-008]
#     [7.29673139e-003 1.52281015e-002 1.75605865e-002 ...
#      1.25419666e-006 1.79541214e-008 1.06863856e-010]
#     [9.57787131e-003 1.05910573e-002 6.50684881e-003 ...
#      2.24820856e-008 1.81191254e-010 6.14964766e-013]
#     ...
#     [7.15756603e-007 5.53953812e-008 2.42872486e-009 ...
#      2.42488787e-020 1.71899208e-023 5.39534736e-027]
#     [1.63483972e-008 8.10167097e-010 2.28067409e-011 ...
#      2.65615338e-023 1.24811593e-026 2.61727865e-030]
#     [2.16923317e-010 7.05069220e-012 1.30503887e-013 ...
#      1.98567135e-026 6.31792313e-030 9.03707621e-034]]]
#
#
#   [[[6.92320762e-048 1.14155529e-044 1.65897315e-041 ...
#      8.90850228e-027 4.18428667e-024 1.51580439e-021]
#     [1.16997649e-040 1.00341733e-037 7.51299520e-035 ...
#      1.28711364e-021 2.96742514e-019 5.24355568e-017]
#     [2.82141923e-034 1.31434097e-031 5.29838547e-029 ...
#      3.64116400e-017 4.32005746e-015 3.90541548e-013]
#     ...
#     [7.57945530e-013 2.81565957e-011 8.73201281e-010 ...
#      9.88720014e-004 7.49762307e-003 4.22737681e-002]
#     [2.63329505e-010 6.42133072e-009 1.29957287e-007 ...
#      1.60711156e-002 7.71522719e-002 2.74276499e-001]
#     [2.97996690e-008 4.88164726e-007 6.60066029e-006 ...
#      1.00760244e-001 3.14090601e-001 7.22274659e-001]]
#
#    [[2.08662115e-041 2.86626973e-038 3.36029614e-035 ...
#      3.51559471e-021 1.04598068e-018 2.28486535e-016]
#     [7.48387846e-035 5.22419798e-032 3.08539650e-029 ...
#      9.34562925e-017 1.34372190e-014 1.41179866e-012]
#     [4.28398639e-029 1.58982226e-026 4.95128562e-024 ...
#      5.49716586e-013 4.00857291e-011 2.12645049e-009]
#     ...
#     [3.28033214e-010 8.90593130e-009 1.96265509e-007 ...
#      2.48962827e-002 1.09262970e-001 3.42222265e-001]
#     [4.36665670e-008 7.67517749e-007 1.08908557e-005 ...
#      1.42205677e-001 3.91232315e-001 7.65676322e-001]
#     [2.00473588e-006 2.33679828e-005 2.18773774e-004 ...
#      3.33626505e-001 5.90524121e-001 7.41278109e-001]]
#
#    [[4.31846412e-035 4.60066062e-032 4.02925435e-029 ...
#      5.12030751e-016 8.61205341e-014 1.00536505e-011]
#     [3.11473188e-029 1.65075133e-026 7.13708578e-024 ...
#      2.42009135e-012 1.94448558e-010 1.08131058e-008]
#     [4.02782780e-024 1.11265986e-021 2.48948461e-019 ...
#      2.86667894e-009 1.15541883e-007 3.21412137e-006]
#     ...
#     [7.23039066e-008 1.34905572e-006 1.97887217e-005 ...
#      1.90045836e-001 4.40025510e-001 6.94324188e-001]
#     [3.57601839e-006 4.26431751e-005 3.97816375e-004 ...
#      3.73514706e-001 5.37924060e-001 5.26780436e-001]
#     [6.47303390e-005 5.05770091e-004 3.07731569e-003 ...
#      3.21538183e-001 2.95745446e-001 1.84575800e-001]]
#
#    ...
#
#    [[3.67332560e-009 2.19526573e-007 8.07788146e-006 ...
#      1.03908196e-001 9.44637557e-002 4.01942029e-002]
#     [5.04615481e-007 1.42937748e-005 2.49902225e-004 ...
#      8.40808497e-002 3.77716409e-002 8.02755662e-003]
#     [2.30366923e-005 3.24567157e-004 2.82795900e-003 ...
#      3.12729757e-002 7.24727101e-003 8.02284384e-004]
#     ...
#     [3.61881248e-003 2.80124912e-003 1.34787815e-003 ...
#      9.61302702e-009 1.39068992e-010 9.96759830e-013]
#     [9.03346896e-004 4.31292417e-004 1.28054908e-004 ...
#      8.42648304e-011 7.65474526e-013 3.46427040e-015]
#     [1.13616518e-004 3.43645175e-005 6.46591638e-006 ...
#      4.47029662e-013 2.61452404e-015 7.65710657e-018]]
#
#    [[5.19760648e-006 1.11196069e-004 1.35106454e-003 ...
#      1.83891041e-002 3.21047726e-003 2.37813229e-004]
#     [1.25850196e-004 1.28676915e-003 7.51220517e-003 ...
#      2.95909841e-003 2.62867439e-004 1.00440352e-005]
#     [1.14299451e-003 5.85277140e-003 1.71912054e-002 ...
#      2.43348310e-004 1.14486015e-005 2.34565898e-007]
#     ...
#     [2.42349199e-004 6.95629722e-005 1.16341641e-005 ...
#      1.46222981e-013 4.73803745e-016 7.01445053e-019]
#     [2.04750837e-005 3.63292368e-006 3.76374673e-007 ...
#      4.57027106e-016 9.43777340e-019 8.97105364e-022]
#     [9.30015829e-007 1.04731166e-007 6.89933857e-009 ...
#      9.17836527e-019 1.23702820e-021 7.72750152e-025]]
#
#    [[6.09033961e-004 3.83303073e-003 1.25479619e-002 ...
#      5.96844873e-005 1.58114532e-006 1.60637571e-008]
#     [2.68601077e-003 8.20944769e-003 1.31609047e-002 ...
#      2.08416665e-006 2.91421703e-008 1.58839848e-010]
#     [4.99127356e-003 7.74674466e-003 6.35355882e-003 ...
#      4.09892967e-008 3.13781462e-010 9.50429944e-013]
#     ...
#     [1.56656096e-006 1.42937105e-007 7.07960353e-009 ...
#      6.46394757e-020 3.87077047e-023 9.72691770e-027]
#     [4.53421508e-008 2.57409347e-009 7.96358495e-011 ...
#      7.53198304e-023 2.93140217e-026 4.83237390e-030]
#     [7.51847531e-010 2.72484806e-011 5.40082575e-013 ...
#      5.96594039e-026 1.54317878e-029 1.70544499e-033]]]
#
#
#   [[[2.27957228e-055 1.08343731e-051 4.47289449e-048 ...
#      3.36570924e-031 3.96728854e-028 3.50944147e-025]
#     [2.26174058e-047 5.20891482e-044 1.03217085e-040 ...
#      1.74370166e-025 9.41586735e-023 3.79438670e-020]
#     [2.76643808e-040 3.24309575e-037 3.24235176e-034 ...
#      1.59210796e-020 4.15299902e-018 8.04173242e-016]
#     ...
#     [4.59242075e-016 3.31933469e-014 1.97386234e-012 ...
#      4.45898221e-005 5.78553316e-004 5.45029691e-003]
#     [4.43129483e-013 2.01787955e-011 7.51586031e-010 ...
#      1.51298689e-003 1.19407655e-002 6.81703107e-002]
#     [1.29967286e-010 3.82625691e-009 9.16335982e-008 ...
#      1.88304324e-002 9.29621893e-002 3.30833277e-001]]
#
#    [[6.03404526e-048 2.33570859e-044 7.57789781e-041 ...
#      9.18448270e-025 6.51638621e-022 3.28744344e-019]
#     [1.07250501e-040 1.96497913e-037 2.99179681e-034 ...
#      7.41279971e-020 2.37559177e-017 5.39288887e-015]
#     [2.66908958e-034 2.43571959e-031 1.83254127e-028 ...
#      1.20955622e-015 1.84775901e-013 1.99226137e-011]
#     ...
#     [6.94512784e-013 3.58175640e-011 1.47404367e-009 ...
#      3.13792607e-003 2.25602089e-002 1.12671933e-001]
#     [2.33877318e-010 7.49374751e-009 1.90585136e-007 ...
#      3.41309753e-002 1.47902488e-001 4.44005172e-001]
#     [2.55181252e-008 5.21773253e-007 8.42590521e-006 ...
#      1.45961121e-001 3.92278570e-001 7.28472818e-001]]
#
#    [[1.04241308e-040 3.03385422e-037 7.09996078e-034 ...
#      8.21412995e-019 3.09524080e-016 7.80062112e-014]
#     [3.14408339e-034 4.24110228e-031 4.56693954e-028 ...
#      1.00224361e-014 1.69001700e-012 1.90290851e-010]
#     [1.51466262e-028 9.98024383e-026 5.21406772e-023 ...
#      2.84102810e-011 2.26314958e-009 1.20181126e-007]
#     ...
#     [5.07530243e-010 1.74639651e-008 4.63179138e-007 ...
#      6.07221927e-002 2.18859816e-001 5.21456125e-001]
#     [5.78304852e-008 1.22065669e-006 1.97660601e-005 ...
#      2.07712666e-001 4.48215782e-001 6.38349115e-001]
#     [2.28096641e-006 3.03599599e-005 3.08643989e-004 ...
#      2.99825917e-001 3.98715648e-001 3.49415661e-001]]
#
#    ...
#
#    [[7.22911118e-011 8.56873441e-009 5.96216486e-007 ...
#      8.34343987e-002 1.02591370e-001 5.54213276e-002]
#     [1.87841564e-008 9.95551040e-007 3.11092523e-005 ...
#      8.87561612e-002 5.16718424e-002 1.33925122e-002]
#     [1.54942916e-006 3.87029537e-005 5.72107590e-004 ...
#      4.25758558e-002 1.22876865e-002 1.59779051e-003]
#     ...
#     [2.69773195e-003 2.97940208e-003 1.97024151e-003 ...
#      3.69124250e-008 5.64811516e-010 4.07455483e-012]
#     [9.96229149e-004 6.55152833e-004 2.58355018e-004 ...
#      3.83005490e-010 3.58244668e-012 1.59078635e-014]
#     [1.80909288e-004 7.29244745e-005 1.76491424e-005 ...
#      2.37961195e-012 1.39723219e-014 3.91985291e-017]]
#
#    [[3.65442835e-007 1.39927258e-005 2.88523386e-004 ...
#      2.30317408e-002 4.74048647e-003 3.87078831e-004]
#     [1.46516797e-005 2.54173297e-004 2.39246067e-003 ...
#      4.43376140e-003 4.47660908e-004 1.82245393e-005]
#     [2.12786476e-004 1.75933803e-003 7.94508930e-003 ...
#      4.30927784e-004 2.22674192e-005 4.70848842e-007]
#     ...
#     [3.08248540e-004 1.16833620e-004 2.47552144e-005 ...
#      5.13148742e-013 1.58470536e-015 2.12061183e-018]
#     [3.56755263e-005 8.08894816e-006 1.02864193e-006 ...
#      1.79317371e-015 3.44698556e-018 2.89693480e-021]
#     [2.17788288e-006 3.03907090e-007 2.38548673e-008 ...
#      3.99802092e-018 4.90561814e-021 2.65351001e-024]]
#
#    [[1.18832992e-004 1.19232518e-003 5.87027796e-003 ...
#      8.36443849e-005 2.25825611e-006 2.18002441e-008]
#     [7.69900412e-004 3.57591725e-003 8.23805183e-003 ...
#      3.23173502e-006 4.46751877e-008 2.25025097e-010]
#     [2.04883871e-003 4.62167949e-003 5.22091676e-003 ...
#      6.98517491e-008 5.13790408e-010 1.40097852e-012]
#     ...
#     [2.82847824e-006 3.12468899e-007 1.79077261e-008 ...
#      1.62211443e-019 8.28050980e-023 1.67759864e-026]
#     [1.04516072e-007 6.97156489e-009 2.42503725e-010 ...
#      2.01311748e-022 6.54619288e-026 8.54006763e-030]
#     [2.18087337e-009 9.02832105e-011 1.95835490e-012 ...
#      1.69143036e-025 3.58667593e-029 3.08221194e-033]]]
#
#
#   ...
#
#
#   [[[4.61104131e-106 2.95274737e-099 1.45662605e-092 ...
#      3.01932081e-061 1.64270031e-055 5.49568470e-050]
#     [3.66660452e-093 6.89169667e-087 9.91488820e-081 ...
#      4.09816048e-052 6.41399600e-047 6.18750534e-042]
#     [1.30347042e-081 7.91448668e-076 3.65595711e-070 ...
#      4.87947034e-044 2.41748143e-039 7.39591329e-035]
#     ...
#     [4.83463311e-040 3.12269787e-036 1.49567652e-032 ...
#      1.86461657e-016 8.93170677e-014 2.65289482e-011]
#     [2.40945494e-034 7.45462326e-031 1.70304652e-027 ...
#      5.01848563e-013 1.13194810e-010 1.58356838e-008]
#     [2.33321056e-029 3.61847919e-026 4.12719610e-023 ...
#      3.62015911e-010 4.02675411e-008 2.77851331e-006]]
#
#    [[3.88693149e-092 1.65333852e-085 5.10448648e-079 ...
#      3.71893638e-049 8.28025964e-044 1.04412634e-038]
#     [1.65455331e-080 2.02990652e-074 1.80083610e-068 ...
#      2.54307960e-041 1.63620157e-036 5.99853337e-032]
#     [4.03940577e-070 1.57472001e-064 4.42260026e-059 ...
#      1.95677258e-034 3.99751846e-030 4.67742275e-026]
#     ...
#     [3.87641441e-033 1.50038012e-029 4.11323873e-026 ...
#      1.45820994e-011 2.88838293e-009 3.33145452e-007]
#     [3.60758944e-028 6.61282076e-025 8.55991515e-022 ...
#      6.97064529e-009 6.49679716e-007 3.53340388e-005]
#     [7.30021114e-024 6.63643342e-021 4.24826397e-018 ...
#      1.00184231e-006 4.60043407e-005 1.23504045e-003]]
#
#    [[1.34048633e-078 3.30171931e-072 5.51762134e-066 ...
#      6.04466279e-038 4.53255604e-033 1.75818031e-028]
#     [2.94483233e-068 2.07010026e-062 9.86686794e-057 ...
#      2.12660787e-031 4.67455682e-027 5.36970895e-023]
#     [4.76900147e-059 1.05418696e-053 1.57852937e-048 ...
#      1.07457312e-025 7.58884229e-022 2.82545660e-018]
#     ...
#     [1.02392502e-026 2.14325561e-023 3.01813942e-020 ...
#      1.62129870e-007 1.14944954e-005 4.42812844e-004]
#     [1.73753890e-022 1.70823157e-019 1.12815183e-016 ...
#      1.38031310e-005 4.62301290e-004 8.44891888e-003]
#     [7.18556994e-019 3.47610916e-016 1.12795203e-013 ...
#      3.96017871e-004 6.55700396e-003 5.94662139e-002]]
#
#    ...
#
#    [[1.04889527e-022 1.02170400e-018 4.25744445e-015 ...
#      2.71209604e-003 2.39682693e-002 6.34189796e-002]
#     [1.05220503e-018 3.20387093e-015 4.25748020e-012 ...
#      1.27720256e-002 4.19397052e-002 4.24995309e-002]
#     [2.55145840e-015 2.63448333e-012 1.20828897e-009 ...
#      2.43957829e-002 3.17084998e-002 1.30718979e-002]
#     ...
#     [3.77407025e-006 4.63892228e-005 2.69938839e-004 ...
#      5.80393196e-006 1.59700113e-007 1.54843071e-009]
#     [1.26914171e-005 7.52770450e-005 2.13343089e-004 ...
#      1.49759043e-007 2.16774495e-009 1.12378761e-011]
#     [1.82384222e-005 5.44776547e-005 7.84109124e-005 ...
#      2.18318525e-009 1.72271271e-011 4.94229330e-014]]
#
#    [[2.01354038e-015 3.20838009e-012 1.95443696e-009 ...
#      1.48415725e-002 9.60627354e-003 1.66055064e-003]
#     [1.38195840e-012 7.24852830e-010 1.48900497e-007 ...
#      7.44662631e-003 1.93353958e-003 1.38549984e-004]
#     [2.80681184e-010 5.22405129e-008 3.89085156e-006 ...
#      1.76679307e-003 1.94578955e-004 6.09346460e-006]
#     ...
#     [1.88665749e-005 4.90957733e-005 5.53560617e-005 ...
#      8.09532333e-011 2.45252031e-013 2.37478071e-016]
#     [1.25925516e-005 1.61793849e-005 9.11401617e-006 ...
#      5.12944700e-013 8.50751924e-016 4.59344566e-019]
#     [3.97942340e-006 2.62880169e-006 7.69649595e-007 ...
#      1.99744311e-015 1.87361546e-018 5.81968218e-022]]
#
#    [[4.72319846e-010 9.40254914e-008 6.37849071e-006 ...
#      1.47740260e-004 5.37149240e-006 4.67640809e-008]
#     [2.57428234e-008 1.79513782e-006 4.38612714e-005 ...
#      9.73903453e-006 1.54217817e-007 6.05210757e-010]
#     [4.99124429e-007 1.30512787e-005 1.22605509e-004 ...
#      3.46664341e-007 2.50913092e-009 4.64541334e-012]
#     ...
#     [2.42398811e-006 1.08323435e-006 1.91116060e-007 ...
#      6.24107550e-018 1.65932953e-021 1.27969164e-025]
#     [3.43074516e-007 7.79516121e-008 7.09335945e-009 ...
#      1.08204737e-020 1.64729614e-024 7.42189227e-029]
#     [2.53126715e-008 3.03727589e-009 1.47888666e-010 ...
#      1.24341715e-023 1.11603980e-027 3.02064922e-032]]]
#
#
#   [[[2.07487813e-119 9.12416955e-112 2.97535196e-104 ...
#      4.00325681e-069 1.08268637e-062 1.70069063e-056]
#     [2.96915382e-105 3.32801316e-098 2.75322518e-091 ...
#      3.80214821e-059 2.61059404e-053 1.04674437e-047]
#     [1.43327259e-092 4.57258306e-086 1.07181329e-079 ...
#      2.63195795e-050 5.11235951e-045 5.82519819e-040]
#     ...
#     [1.11131813e-046 2.34062135e-042 3.54993131e-038 ...
#      8.54293391e-020 1.04774534e-016 7.64267579e-014]
#     [2.55511055e-040 2.39702630e-036 1.61374357e-032 ...
#      6.50527026e-016 3.51954336e-013 1.13442607e-010]
#     [1.01664009e-034 4.47052295e-031 1.40614917e-027 ...
#      1.22769883e-012 3.08392915e-010 4.62187614e-008]]
#
#    [[1.00503693e-103 2.74031140e-096 5.18826582e-089 ...
#      1.53131743e-055 1.51230106e-049 7.93692738e-044]
#     [5.46801730e-091 3.74860516e-084 1.78176677e-077 ...
#      5.40164480e-047 1.37040241e-041 1.86546540e-036]
#     [1.33733100e-079 2.57526658e-073 3.43227354e-067 ...
#      1.84101978e-039 1.33376732e-034 5.22754709e-030]
#     ...
#     [8.75844683e-039 1.05098461e-034 8.64174006e-031 ...
#      4.24950800e-014 1.99260341e-011 5.19660559e-009]
#     [3.18380001e-033 1.68507816e-029 6.09919797e-026 ...
#      4.94176360e-011 1.02460627e-008 1.18598406e-006]
#     [2.27272089e-028 5.58627527e-025 9.37225636e-022 ...
#      1.61763858e-008 1.56011293e-006 8.42826218e-005]]
#
#    [[1.69727781e-088 2.46382288e-081 2.30640740e-074 ...
#      5.89174085e-043 1.71998275e-037 2.42150329e-032]
#     [3.42022293e-077 1.24159057e-070 2.91263479e-064 ...
#      8.03899741e-036 6.16844236e-031 2.31500299e-026]
#     [4.13012282e-067 4.18620965e-061 2.74595080e-055 ...
#      1.39419916e-029 3.11412856e-025 3.44411404e-021]
#     ...
#     [2.03486703e-031 1.24443728e-027 4.93348160e-024 ...
#      2.51630800e-009 3.86524125e-007 3.06836395e-005]
#     [1.14651400e-026 3.07352959e-023 5.33980869e-020 ...
#      4.51656478e-007 3.09119779e-005 1.09998501e-003]
#     [1.44109983e-022 1.78345404e-019 1.42990266e-016 ...
#      2.58758377e-005 8.29304670e-004 1.38947420e-002]]
#
#    ...
#
#    [[8.29413308e-026 2.44755108e-021 2.84452070e-017 ...
#      8.31441196e-004 1.20583634e-002 4.77565838e-002]
#     [1.92290761e-021 1.62509912e-017 5.54396863e-014 ...
#      5.41123059e-003 2.76036564e-002 3.98114790e-002]
#     [1.00991456e-017 2.67141306e-014 2.91533723e-011 ...
#      1.39532422e-002 2.67777616e-002 1.49938394e-002]
#     ...
#     [3.31068149e-007 7.60252847e-006 7.79482683e-005 ...
#      1.11945270e-005 3.70152122e-007 4.02955348e-009]
#     [1.83206612e-006 1.93103243e-005 9.19292359e-005 ...
#      3.51652244e-007 5.91526095e-009 3.33763426e-011]
#     [4.19432495e-006 2.12484544e-005 4.91330888e-005 ...
#      6.16240019e-009 5.47607478e-011 1.66070526e-013]]
#
#    [[1.27591565e-017 5.15661604e-014 7.30294405e-011 ...
#      9.76693367e-003 8.51992426e-003 1.80974001e-003]
#     [1.66020912e-014 2.04680199e-011 9.10157761e-009 ...
#      6.01376908e-003 2.01351569e-003 1.70336537e-004]
#     [6.10005388e-012 2.48810129e-009 3.75598404e-007 ...
#      1.72646931e-003 2.35285802e-004 8.37962945e-006]
#     ...
#     [4.52931131e-006 1.95335391e-005 3.42969271e-005 ...
#      1.72368094e-010 5.45441722e-013 5.14604329e-016]
#     [4.46468001e-006 9.09044621e-006 7.64309272e-006 ...
#      1.23998130e-012 2.08892582e-015 1.07115783e-018]
#     [2.03335424e-006 2.04133726e-006 8.57340992e-007 ...
#      5.43839580e-015 5.04687248e-018 1.45329166e-021]]
#
#    [[1.55962840e-011 6.53022685e-009 8.51453108e-007 ...
#      1.30883290e-004 5.27322598e-006 4.64443099e-008]
#     [1.36217000e-009 1.87276565e-007 8.28236561e-006 ...
#      9.65857454e-006 1.63739617e-007 6.30393729e-010]
#     [4.09709369e-008 1.98947074e-006 3.19968723e-005 ...
#      3.82021848e-007 2.86598866e-009 5.05716809e-012]
#     ...
#     [1.20316495e-006 7.83838080e-007 1.88850473e-007 ...
#      1.06088836e-017 2.55377471e-021 1.66244523e-025]
#     [2.28751054e-007 7.28536944e-008 8.72557820e-009 ...
#      1.97447111e-020 2.66067421e-024 9.91437231e-029]
#     [2.22732143e-008 3.61064303e-009 2.23526414e-010 ...
#      2.42486036e-023 1.88572219e-027 4.14039292e-032]]]
#
#
#   [[[4.68640982e-134 1.74024041e-125 4.58103435e-117 ...
#      9.73583041e-078 1.52821288e-070 1.30563965e-063]
#     [1.58830878e-118 1.28090879e-110 7.30596310e-103 ...
#      7.55986522e-067 2.62131878e-060 4.99297377e-054]
#     [1.32061510e-104 2.62753124e-097 3.68820307e-090 ...
#      3.48281901e-057 3.01599225e-051 1.44597191e-045]
#     ...
#     [4.87095093e-054 3.75405536e-049 2.01528453e-044 ...
#      1.53627456e-023 5.25899159e-020 1.02254159e-016]
#     [5.79483033e-047 1.83549516e-042 4.03994925e-038 ...
#      3.53520179e-019 4.97201493e-016 3.98531014e-013]
#     [1.05054113e-040 1.44837436e-036 1.38439541e-032 ...
#      1.85226835e-015 1.13275122e-012 3.95987641e-010]]
#
#    [[2.05633519e-116 4.35692142e-108 6.08698303e-100 ...
#      1.63393500e-062 8.21445292e-056 2.04265441e-049]
#     [1.79544378e-102 8.19341758e-095 2.46890145e-087 ...
#      3.35334642e-053 3.80286289e-047 2.16297306e-041]
#     [5.36067407e-090 5.98343625e-083 4.41336917e-076 ...
#      5.62265169e-045 1.62014274e-039 2.36963456e-034]
#     ...
#     [4.76885841e-045 1.97640919e-040 5.40743406e-036 ...
#      5.80971132e-017 6.96914517e-014 4.42120918e-011]
#     [7.45883381e-039 1.26068712e-034 1.40571749e-030 ...
#      1.73142911e-013 8.58544249e-011 2.26425453e-008]
#     [2.04953579e-033 1.49672154e-029 7.20538028e-026 ...
#      1.35303684e-010 2.93260672e-008 3.39802140e-006]]
#
#    [[2.59107916e-099 2.64557823e-091 1.64259882e-083 ...
#      2.01583626e-048 2.58293614e-042 1.47577509e-036]
#     [5.76028856e-087 1.26853405e-079 1.70828210e-072 ...
#      1.16710633e-040 3.48770028e-035 4.73568514e-030]
#     [6.09227863e-076 3.28098722e-069 1.08537172e-062 ...
#      7.51681101e-034 5.87087922e-029 2.11791875e-024]
#     ...
#     [1.21178723e-036 2.39297946e-032 2.93883898e-028 ...
#      2.14633807e-011 7.64968699e-009 1.33394444e-006]
#     [2.45584797e-031 1.97094565e-027 9.84970005e-024 ...
#      8.45317720e-009 1.26036937e-006 9.27000035e-005]
#     [1.00862327e-026 3.48505240e-023 7.50610504e-020 ...
#      1.00269436e-006 6.60442035e-005 2.16186660e-003]]
#
#    ...
#
#    [[3.50656114e-029 3.41961798e-024 1.19946017e-019 ...
#      2.13579922e-004 5.27316969e-003 3.22390201e-002]
#     [1.95747367e-024 4.97687890e-020 4.68986658e-016 ...
#      1.93917166e-003 1.59035315e-002 3.36027838e-002]
#     [2.31032729e-020 1.68733641e-016 4.69039452e-013 ...
#      6.80829208e-003 1.99226178e-002 1.55685921e-002]
#     ...
#     [1.92877479e-008 8.73327406e-007 1.65738661e-005 ...
#      1.90435028e-005 7.75024321e-007 9.66734869e-009]
#     [1.79384675e-007 3.53509148e-006 2.96135141e-005 ...
#      7.32062559e-007 1.46388514e-008 9.16488229e-011]
#     [6.67083303e-007 6.01331947e-006 2.33403700e-005 ...
#      1.54959231e-008 1.58445246e-010 5.17310653e-013]]
#
#    [[5.10569173e-020 5.61208163e-016 1.96660999e-012 ...
#      5.72134246e-003 6.89510859e-003 1.83590980e-003]
#     [1.29382242e-016 4.00114240e-013 4.08198564e-010 ...
#      4.34328001e-003 1.91948757e-003 1.95345272e-004]
#     [8.81233782e-014 8.37034127e-011 2.70419143e-008 ...
#      1.51524415e-003 2.61230405e-004 1.07705253e-005]
#     ...
#     [7.94014565e-007 5.93409519e-006 1.68899166e-005 ...
#      3.35375931e-010 1.12740946e-012 1.05073000e-015]
#     [1.17287028e-006 3.94740921e-006 5.14562531e-006 ...
#      2.74677831e-012 4.77638671e-015 2.35676353e-018]
#     [7.80274342e-007 1.23896676e-006 7.73824243e-007 ...
#      1.36039913e-014 1.26831624e-017 3.42847396e-021]]
#
#    [[3.68981257e-013 3.43022514e-010 9.01378085e-008 ...
#      1.06795576e-004 4.84156394e-006 4.36349285e-008]
#     [5.25161972e-011 1.49760928e-008 1.25341331e-006 ...
#      8.84117942e-006 1.62814417e-007 6.21676077e-010]
#     [2.48835705e-009 2.35342164e-007 6.75738084e-006 ...
#      3.89339644e-007 3.06977090e-009 5.21659235e-012]
#     ...
#     [4.69577916e-007 4.62261772e-007 1.56988102e-007 ...
#      1.68180750e-017 3.70616946e-021 2.05367810e-025]
#     [1.21094196e-007 5.59292058e-008 9.08611015e-009 ...
#      3.36487232e-020 4.05622697e-024 1.26018465e-028]
#     [1.57010381e-008 3.55160637e-009 2.87676794e-010 ...
#      4.42238626e-023 3.01013567e-027 5.40339810e-032]]]]
#
#
#
#  [[[[3.66064804e-035 1.33730595e-032 4.32372427e-030 ...
#      1.43641407e-018 1.60167137e-016 1.40298506e-014]
#     [2.36743857e-029 4.96086694e-027 9.11924282e-025 ...
#      1.59216287e-014 9.63383457e-013 4.55007192e-011]
#     [2.82532669e-024 3.51744237e-022 3.81014592e-020 ...
#      4.21601458e-011 1.43923721e-009 3.81212809e-008]
#     ...
#     [4.54341753e-008 6.43129806e-007 7.65915351e-006 ...
#      8.51791766e-002 2.67335895e-001 6.35034875e-001]
#     [2.28537652e-006 2.24691468e-005 1.84838931e-004 ...
#      2.99347799e-001 6.30188752e-001 1.00000000e+000]
#     [4.24318002e-005 2.95424199e-004 1.71212700e-003 ...
#      4.47677480e-001 6.45892037e-001 6.99703248e-001]]
#
#    [[4.34858454e-030 1.32166502e-027 3.45553801e-025 ...
#      2.41563006e-014 1.75837970e-012 9.62430429e-011]
#     [7.57197743e-025 1.29217996e-022 1.88130759e-020 ...
#      6.29856504e-011 2.44917815e-009 7.12380039e-008]
#     [2.66319375e-020 2.64740076e-018 2.22794794e-016 ...
#      4.33658833e-008 9.37519247e-007 1.50865814e-005]
#     ...
#     [2.82459724e-006 2.94826952e-005 2.52384307e-004 ...
#      3.47846547e-001 6.51074334e-001 8.88528575e-001]
#     [6.20474928e-005 4.44100955e-004 2.59334475e-003 ...
#      4.91805063e-001 6.11442875e-001 5.52352602e-001]
#     [5.27681011e-004 2.64273963e-003 1.07456165e-002 ...
#      3.12022329e-001 2.63432282e-001 1.61077787e-001]]
#
#    [[3.52892488e-025 8.38075795e-023 1.65644114e-020 ...
#      1.60821035e-010 6.91194591e-009 2.12464881e-007]
#     [1.57465618e-020 2.05816516e-018 2.22207020e-016 ...
#      9.52380439e-008 2.15915399e-006 3.48791280e-005]
#     [1.55969689e-016 1.16567818e-014 7.14565785e-013 ...
#      1.65019871e-005 2.05543631e-004 1.81772820e-003]
#     ...
#     [9.11214063e-005 6.63302411e-004 3.84657854e-003 ...
#      4.60551847e-001 4.72651806e-001 3.39101504e-001]
#     [8.49618240e-004 4.18972911e-003 1.63806355e-002 ...
#      2.56485769e-001 1.73417380e-001 8.17518173e-002]
#     [3.22337198e-003 1.09967723e-002 2.96099148e-002 ...
#      6.76882845e-002 3.08409293e-002 9.77299235e-003]]
#
#    ...
#
#    [[6.57122644e-006 1.10230921e-004 1.18962515e-003 ...
#      7.19237564e-002 2.67200385e-002 4.96461228e-003]
#     [1.86702580e-004 1.62994306e-003 9.15929140e-003 ...
#      2.21118612e-002 4.38223724e-003 4.37740507e-004]
#     [1.96085358e-003 9.28108754e-003 2.82830081e-002 ...
#      3.31914081e-003 3.64328117e-004 2.02972839e-005]
#     ...
#     [7.24547240e-004 2.66121593e-004 6.28637321e-005 ...
#      2.31172932e-011 2.11521135e-013 1.00844434e-015]
#     [6.65974255e-005 1.59487702e-005 2.45529367e-006 ...
#      1.07633496e-013 6.48291976e-016 2.04271006e-018]
#     [3.26799844e-006 5.22245170e-007 5.36238800e-008 ...
#      3.14021782e-016 1.27291161e-018 2.70923680e-021]]
#
#    [[6.62352090e-004 4.37835122e-003 1.73070711e-002 ...
#      2.08219528e-003 1.72238544e-004 6.50240784e-006]
#     [4.13631135e-003 1.42767119e-002 2.95545229e-002 ...
#      1.51961064e-004 6.85248128e-006 1.42504806e-007]
#     [1.05796920e-002 1.98464108e-002 2.23851836e-002 ...
#      5.93929736e-006 1.51246455e-007 1.79316518e-009]
#     ...
#     [1.17041645e-005 1.71138835e-006 1.51648361e-007 ...
#      1.55802597e-016 3.55705587e-019 3.92207177e-022]
#     [4.12958772e-007 3.93703440e-008 2.27680286e-009 ...
#      2.87402499e-019 4.36705168e-022 3.22310056e-025]
#     [8.22794365e-009 5.23369216e-010 2.02103484e-011 ...
#      3.50272823e-022 3.61841391e-025 1.82523539e-028]]
#
#    [[7.06146282e-003 1.54024885e-002 1.85392762e-002 ...
#      1.59971753e-006 2.36393381e-008 1.44904872e-010]
#     [9.87339397e-003 1.13561402e-002 7.24830523e-003 ...
#      2.96205197e-008 2.45503717e-010 8.55074400e-013]
#     [6.24609524e-003 3.93762242e-003 1.38436005e-003 ...
#      3.20025269e-010 1.53710505e-012 3.13948850e-015]
#     ...
#     [2.17056898e-008 1.09681110e-009 3.14584006e-011 ...
#      3.96253049e-023 1.88452090e-026 3.99399055e-030]
#     [2.95718156e-010 9.77879795e-012 1.84006443e-013 ...
#      2.99712032e-026 9.63367750e-030 1.39022497e-033]
#     [2.40470523e-012 5.32276124e-014 6.71959483e-016 ...
#      1.57501404e-029 3.49119955e-033 3.49848773e-037]]]
#
#
#   [[[2.93618675e-041 2.63653319e-038 2.06914822e-035 ...
#      4.55368534e-022 1.10675686e-019 2.06324893e-017]
#     [8.75466133e-035 4.24992092e-032 1.78708256e-029 ...
#      1.53728996e-017 1.91224764e-015 1.81363050e-013]
#     [4.27016745e-029 1.16618127e-026 2.73587128e-024 ...
#      1.13545928e-013 7.55015503e-012 3.80646979e-010]
#     ...
#     [1.90630485e-010 4.75546765e-009 9.85031184e-008 ...
#      1.37675451e-002 6.78045475e-002 2.47354576e-001]
#     [2.36378364e-008 3.95343192e-007 5.45994048e-006 ...
#      9.31658943e-002 2.97234049e-001 6.99719762e-001]
#     [1.01976627e-006 1.16845576e-005 1.09979227e-004 ...
#      2.56867356e-001 5.43600758e-001 8.45785121e-001]]
#
#    [[2.15757869e-035 1.58119023e-032 9.81386901e-030 ...
#      3.86127000e-017 5.86268225e-015 6.50815273e-013]
#     [1.50469678e-029 5.83294319e-027 1.89926382e-024 ...
#      2.66529826e-013 2.04069886e-011 1.13718267e-009]
#     [1.90179392e-024 4.06462776e-022 7.24101096e-020 ...
#      4.50256208e-010 1.81748741e-008 5.31650063e-007]
#     ...
#     [3.37604676e-008 6.07702615e-007 8.83468025e-006 ...
#      1.30910151e-001 3.69680845e-001 7.42756921e-001]
#     [1.68762720e-006 2.01028479e-005 1.92401354e-004 ...
#      3.29102545e-001 5.96449215e-001 7.66725215e-001]
#     [3.09550046e-005 2.49554384e-004 1.60863643e-003 ...
#      3.57412172e-001 4.25938534e-001 3.58989655e-001]]
#
#    [[1.03771194e-029 5.78781139e-027 2.63578494e-024 ...
#      1.17108311e-012 9.94684201e-011 5.84883049e-009]
#     [1.60966274e-024 4.65465894e-022 1.09101883e-019 ...
#      1.60004302e-009 6.77748156e-008 1.98182256e-006]
#     [5.03341008e-020 7.87689066e-018 9.92369133e-016 ...
#      5.99781694e-007 1.32535896e-005 2.01622314e-004]
#     ...
#     [2.95861760e-006 3.61644012e-005 3.45946018e-004 ...
#      3.69652328e-001 5.46561626e-001 5.49532711e-001]
#     [5.79250639e-005 4.62881545e-004 2.88122295e-003 ...
#      3.38446561e-001 3.18787287e-001 2.03744155e-001]
#     [4.39786428e-004 2.35156011e-003 9.75131769e-003 ...
#      1.42130987e-001 8.74185859e-002 3.64084708e-002]]
#
#    ...
#
#    [[3.61490591e-007 1.08043931e-005 1.99185310e-004 ...
#      8.60196970e-002 4.04470504e-002 8.98119898e-003]
#     [1.81911017e-005 2.68880285e-004 2.45632738e-003 ...
#      3.39350684e-002 8.19020082e-003 9.42689956e-004]
#     [3.25144793e-004 2.48516554e-003 1.17587148e-002 ...
#      6.42533173e-003 8.28530966e-004 5.14049186e-005]
#     ...
#     [1.05554192e-003 5.16524426e-004 1.57119915e-004 ...
#      1.15605244e-010 1.07117518e-012 4.93942015e-015]
#     [1.38425705e-004 4.28020088e-005 8.22972400e-006 ...
#      6.28329639e-013 3.73953582e-015 1.11333205e-017]
#     [9.48379751e-006 1.90000992e-006 2.36761293e-007 ...
#      2.11924261e-015 8.29431355e-018 1.63166881e-020]]
#
#    [[1.04317211e-004 1.12262814e-003 6.89058206e-003 ...
#      3.40919364e-003 3.15193493e-004 1.25061020e-005]
#     [1.02727678e-003 5.50603731e-003 1.69115491e-002 ...
#      2.93247411e-004 1.42938339e-005 3.02802860e-007]
#     [4.01787338e-003 1.12012240e-002 1.79683509e-002 ...
#      1.33602555e-005 3.56422445e-007 4.18023908e-009]
#     ...
#     [2.54734087e-005 4.62545638e-006 4.90083287e-007 ...
#      6.57082946e-016 1.37948127e-018 1.33131946e-021]
#     [1.19755910e-006 1.37665684e-007 9.25182589e-009 ...
#      1.34309132e-018 1.83630774e-021 1.16221869e-024]
#     [3.12521892e-008 2.33147512e-009 1.01857112e-010 ...
#      1.80213555e-021 1.64107273e-024 6.96286374e-028]]
#
#    [[2.55131475e-003 8.17639177e-003 1.37228342e-002 ...
#      2.65445752e-006 3.83669158e-008 2.15604668e-010]
#     [5.06109318e-003 8.19407810e-003 7.00047213e-003 ...
#      5.39363209e-008 4.25134060e-010 1.32272605e-012]
#     [4.44045708e-003 3.78608545e-003 1.71493654e-003 ...
#      6.35545204e-010 2.82721696e-012 5.03396125e-015]
#     ...
#     [5.97200019e-008 3.46197785e-009 1.09268315e-010 ...
#      1.12283181e-022 4.42506515e-026 7.37508033e-030]
#     [1.01766244e-009 3.75710583e-011 7.57936699e-013 ...
#      8.99840871e-026 2.35234767e-029 2.62351279e-033]
#     [1.02164301e-011 2.46090450e-013 3.24973634e-015 ...
#      4.99156451e-029 8.84052993e-033 6.73466961e-037]]]
#
#
#   [[[4.82473157e-048 1.17059014e-044 2.44649514e-041 ...
#      5.48031462e-026 3.13967259e-023 1.34330026e-020]
#     [7.44092929e-041 9.13978745e-038 9.58421328e-035 ...
#      6.05817414e-021 1.66613358e-018 3.40373009e-016]
#     [1.64434128e-034 1.06971599e-031 5.89163058e-029 ...
#      1.33171913e-016 1.84591491e-014 1.89099795e-012]
#     ...
#     [2.99219488e-013 1.39780723e-011 5.34365914e-010 ...
#      1.23327746e-003 1.00137409e-002 5.88319242e-002]
#     [9.68828808e-011 2.91944437e-009 7.15950438e-008 ...
#      1.66593825e-002 8.43913897e-002 3.08240706e-001]
#     [1.02384253e-008 2.03864756e-007 3.28644254e-006 ...
#      8.75190025e-002 2.83919039e-001 6.61912970e-001]]
#
#    [[2.67623564e-041 5.18017076e-038 8.34130001e-035 ...
#      2.77109571e-020 9.43677434e-018 2.27751130e-015]
#     [8.25684027e-035 7.91465492e-032 6.26058046e-029 ...
#      5.37135181e-016 8.66329064e-014 9.86604317e-012]
#     [4.09985729e-029 2.03936633e-026 8.30838640e-024 ...
#      2.34727569e-012 1.88402051e-010 1.06397126e-008]
#     ...
#     [1.70005163e-010 5.59436752e-009 1.46186099e-007 ...
#      3.01348581e-002 1.34414054e-001 4.15398852e-001]
#     [2.03321995e-008 4.25941601e-007 7.04985760e-006 ...
#      1.38748837e-001 3.82775732e-001 7.29734999e-001]
#     [8.42199888e-007 1.15159307e-005 1.23817002e-004 ...
#      2.65030920e-001 4.64445586e-001 5.61049073e-001]]
#
#    [[9.23324725e-035 1.31908288e-031 1.50567432e-028 ...
#      4.46686045e-015 8.01057846e-013 9.59402175e-011]
#     [5.41739417e-029 3.75759135e-026 2.06811442e-023 ...
#      1.47525499e-011 1.24163248e-009 6.96722903e-008]
#     [5.76914619e-024 2.03870511e-021 5.67978939e-019 ...
#      1.24752791e-008 5.17958161e-007 1.43129726e-005]
#     ...
#     [4.53426867e-008 9.83839131e-007 1.63825044e-005 ...
#      1.98672935e-001 4.41327544e-001 6.47025123e-001]
#     [1.94575056e-006 2.65548831e-005 2.76887822e-004 ...
#      3.06212868e-001 4.18014767e-001 3.76033116e-001]
#     [3.07515672e-005 2.70862099e-004 1.81513320e-003 ...
#      2.09124950e-001 1.80244310e-001 1.02220703e-001]]
#
#    ...
#
#    [[1.28928749e-008 7.24527936e-007 2.39847192e-005 ...
#      8.95571040e-002 5.47395297e-002 1.48640200e-002]
#     [1.17824925e-006 3.10097813e-005 4.82591388e-004 ...
#      4.56468912e-002 1.37572599e-002 1.86449492e-003]
#     [3.66684047e-005 4.74508097e-004 3.64258337e-003 ...
#      1.09704522e-002 1.70158507e-003 1.19995118e-004]
#     ...
#     [1.14321520e-003 7.72240471e-004 3.12637843e-004 ...
#      5.22692202e-010 4.99332604e-012 2.26185267e-014]
#     [2.16907039e-004 8.95592520e-005 2.21905116e-005 ...
#      3.32939893e-012 1.99162487e-014 5.68580061e-017]
#     [2.10184643e-005 5.45043441e-006 8.49111955e-007 ...
#      1.30296772e-014 5.00422110e-017 9.22751597e-020]]
#
#    [[1.17849274e-005 2.16086520e-004 2.14688023e-003 ...
#      5.07533818e-003 5.34505024e-004 2.26394122e-005]
#     [1.86236349e-004 1.61778819e-003 7.66634667e-003 ...
#      5.16394971e-004 2.77004659e-005 6.06639578e-007]
#     [1.13186424e-003 4.88207458e-003 1.15558029e-002 ...
#      2.75162412e-005 7.82192069e-007 9.20272136e-009]
#     ...
#     [4.38216842e-005 1.01872977e-005 1.32721395e-006 ...
#      2.57182939e-015 5.03061894e-018 4.29577892e-021]
#     [2.77282938e-006 3.95638373e-007 3.17309062e-008 ...
#      5.83788781e-018 7.27233982e-021 3.98811808e-024]
#     [9.56729290e-008 8.60474543e-009 4.36183799e-010 ...
#      8.64179927e-021 7.02036060e-024 2.53028701e-027]]
#
#    [[7.17171259e-004 3.50478085e-003 8.47965143e-003 ...
#      4.10968340e-006 5.88079626e-008 3.05736817e-010]
#     [2.04201159e-003 4.81973522e-003 5.68740844e-003 ...
#      9.17924471e-008 6.96037349e-010 1.95140636e-012]
#     [2.51157403e-003 2.99377360e-003 1.79976412e-003 ...
#      1.18151507e-009 4.92163427e-012 7.70295006e-015]
#     ...
#     [1.36504904e-007 9.31184646e-009 3.30908720e-010 ...
#      2.99863912e-022 9.87863850e-026 1.30341086e-029]
#     [2.92987543e-009 1.23722609e-010 2.73480858e-012 ...
#      2.54914447e-025 5.46525030e-029 4.74089389e-033]
#     [3.65512612e-011 9.80468905e-013 1.38280755e-014 ...
#      1.49427934e-028 2.13160585e-032 1.24207395e-036]]]
#
#
#   ...
#
#
#   [[[2.59449076e-094 5.38490723e-088 8.56562818e-082 ...
#      5.93452563e-053 1.03170755e-047 1.10573249e-042]
#     [1.33829541e-082 8.87134458e-077 4.47894154e-071 ...
#      9.44329052e-045 5.13471163e-040 1.72432160e-035]
#     [3.98412387e-072 9.19712773e-067 1.60756404e-061 ...
#      1.59503321e-037 2.95831006e-033 3.39328978e-029]
#     ...
#     [1.03120217e-034 3.33941509e-031 7.98948476e-028 ...
#      2.98247071e-013 7.05748144e-011 1.03583449e-008]
#     [1.15894857e-029 1.87325698e-026 2.22784705e-023 ...
#      2.42025014e-010 2.81119875e-008 2.02559455e-006]
#     [2.81842633e-025 2.37123749e-022 1.46230630e-019 ...
#      5.72247367e-008 3.40533353e-006 1.25717684e-004]]
#
#    [[1.56965694e-081 2.13257364e-075 2.09703562e-069 ...
#      4.99431914e-042 3.56844691e-037 1.45228007e-032]
#     [5.37066252e-071 2.29150227e-065 7.04948872e-060 ...
#      4.95413548e-035 1.11055139e-030 1.42540252e-026]
#     [1.32666176e-061 1.94020039e-056 2.03825307e-051 ...
#      6.53063117e-029 5.00322534e-025 2.20439132e-021]
#     ...
#     [1.75843641e-028 3.37742105e-025 4.58265267e-022 ...
#      4.73619873e-009 4.62971646e-007 2.64028182e-005]
#     [4.07606271e-024 3.86545227e-021 2.58210275e-018 ...
#      7.55182063e-007 3.62006935e-005 1.01430288e-003]
#     [2.26765015e-020 1.10805282e-017 3.80332608e-015 ...
#      3.90116037e-005 9.57040403e-004 1.37459711e-002]]
#
#    [[3.76265440e-069 2.93437836e-063 1.55240123e-057 ...
#      5.63891360e-032 1.37397492e-027 1.74778435e-023]
#     [8.24310024e-060 1.99749619e-054 3.28032404e-049 ...
#      3.54524433e-026 2.74297473e-022 1.11788460e-018]
#     [1.63411752e-051 1.34326940e-046 7.47396586e-042 ...
#      3.69366675e-021 9.86409560e-018 1.39838391e-014]
#     ...
#     [9.65653656e-023 9.95402167e-020 6.89384720e-017 ...
#      1.06930890e-005 3.75253503e-004 7.18218413e-003]
#     [4.51355486e-019 2.27894967e-016 7.71928071e-014 ...
#      3.35676934e-004 5.79649442e-003 5.47993048e-002]
#     [5.62458539e-016 1.45229182e-013 2.51187459e-011 ...
#      3.79375187e-003 3.36240667e-002 1.63718047e-001]]
#
#    ...
#
#    [[5.59337391e-019 1.86288125e-015 2.70048917e-012 ...
#      1.19291392e-002 4.18595234e-002 4.51437851e-002]
#     [1.54969644e-015 1.73277035e-012 8.58588536e-010 ...
#      2.44506610e-002 3.37089589e-002 1.46861425e-002]
#     [1.13924266e-012 4.60837898e-010 8.39370004e-008 ...
#      2.14286289e-002 1.23082254e-002 2.29133182e-003]
#     ...
#     [1.30791772e-005 8.07716301e-005 2.38034800e-004 ...
#      1.98346691e-007 2.95452780e-009 1.57282746e-011]
#     [1.98764513e-005 6.15551008e-005 9.17479498e-005 ...
#      2.97562779e-009 2.40816183e-011 7.07166144e-014]
#     [1.35393482e-005 2.18804224e-005 1.71515725e-005 ...
#      2.59782337e-011 1.18109913e-013 1.97611481e-016]]
#
#    [[9.32612293e-013 5.30591735e-010 1.17836435e-007 ...
#      8.22782013e-003 2.25578358e-003 1.69925688e-004]
#     [2.10449732e-010 4.21046227e-008 3.36111921e-006 ...
#      2.05298237e-003 2.37256138e-004 7.76565018e-006]
#     [1.51642337e-008 1.14336913e-006 3.50784806e-005 ...
#      2.52463446e-004 1.29540519e-005 1.93552893e-007]
#     ...
#     [1.43543339e-005 1.91252715e-005 1.11537461e-005 ...
#      7.25455967e-013 1.23048776e-015 6.77808641e-019]
#     [4.74076210e-006 3.23490287e-006 9.76817022e-007 ...
#      2.88063817e-015 2.75526196e-018 8.70727064e-022]
#     [7.71992565e-007 2.80195583e-007 4.54579687e-008 ...
#      7.20217317e-018 4.00532181e-021 7.47864408e-025]]
#
#    [[2.14533534e-008 1.60652101e-006 4.19911541e-005 ...
#      1.22723981e-005 2.02622692e-007 8.25343654e-010]
#     [4.50831025e-007 1.25596919e-005 1.25276819e-004 ...
#      4.51891205e-007 3.39318906e-009 6.49046193e-012]
#     [3.58316919e-006 3.95537944e-005 1.59957632e-004 ...
#      9.27814880e-009 3.31506729e-011 3.10763051e-014]
#     ...
#     [4.26793166e-007 1.00063415e-007 9.37716180e-009 ...
#      1.60305601e-020 2.47875468e-024 1.13141738e-028]
#     [3.25571229e-008 4.01675036e-009 2.00732707e-010 ...
#      1.86388755e-023 1.69505912e-027 4.63733281e-032]
#     [1.33954516e-009 9.01134713e-011 2.48579541e-012 ...
#      1.46491808e-026 8.05445229e-031 1.35599372e-035]]]
#
#
#   [[[1.55883281e-106 1.95674759e-099 1.81510595e-092 ...
#      4.49820248e-060 3.47578594e-054 1.56827009e-048]
#     [1.13652246e-093 4.00690880e-087 1.03904510e-080 ...
#      4.27534996e-051 9.21772693e-046 1.16573148e-040]
#     [3.72487098e-082 4.07322991e-076 3.26136155e-070 ...
#      3.65646884e-043 2.42558582e-038 9.47399442e-034]
#     ...
#     [9.71314550e-041 9.59184114e-037 6.80079741e-033 ...
#      3.56967222e-016 2.03684711e-013 6.92348667e-011]
#     [4.54559863e-035 2.09383075e-031 6.90179383e-028 ...
#      7.64853627e-013 2.01575993e-010 3.16928691e-008]
#     [4.14108472e-030 9.32626893e-027 1.49832807e-023 ...
#      4.44456245e-010 5.67240057e-008 4.32428564e-006]]
#
#    [[4.00782169e-092 3.08503794e-085 1.64775896e-078 ...
#      8.99412931e-048 2.56527166e-042 3.92296437e-037]
#     [1.42185651e-080 3.03274901e-074 4.48022579e-068 ...
#      4.03925797e-040 3.24532942e-035 1.40977371e-030]
#     [2.93225857e-070 1.91490727e-064 8.64398347e-059 ...
#      2.10350115e-033 5.23945724e-029 7.10702876e-025]
#     ...
#     [1.40028175e-033 7.80903065e-030 2.97916848e-026 ...
#      3.14552450e-011 6.87428575e-009 8.38409852e-007]
#     [1.15835022e-028 2.98495253e-025 5.25166036e-022 ...
#      1.15100289e-008 1.16398189e-006 6.59136841e-005]
#     [2.09515882e-024 2.61638927e-021 2.22651329e-018 ...
#      1.28447562e-006 6.29951653e-005 1.73527199e-003]]
#
#    [[3.51167859e-078 1.43329896e-071 3.78143901e-065 ...
#      1.87051638e-036 1.60897423e-031 6.75971359e-027]
#     [5.90493978e-068 6.63745274e-062 4.82961404e-056 ...
#      4.10616426e-030 1.01466999e-025 1.23998314e-021]
#     [7.46892063e-059 2.55383575e-053 5.65792706e-048 ...
#      1.33848040e-024 1.04247017e-020 4.05928542e-017]
#     ...
#     [5.83800564e-027 1.64980833e-023 3.02186520e-020 ...
#      3.32235680e-007 2.39351472e-005 8.95941674e-004]
#     [8.37598637e-023 1.08713521e-019 9.14192133e-017 ...
#      2.09527870e-005 7.03230451e-004 1.23310373e-002]
#     [2.95471792e-019 1.84764855e-016 7.48229633e-014 ...
#      4.52571950e-004 7.41028960e-003 6.37093170e-002]]
#
#    ...
#
#    [[9.61825401e-022 8.96128465e-018 3.35948181e-014 ...
#      4.96768946e-003 2.71903297e-002 4.18840641e-002]
#     [5.81498927e-018 1.67721452e-014 1.99020741e-011 ...
#      1.37757142e-002 2.81428021e-002 1.67058810e-002]
#     [8.79243782e-015 8.51674586e-012 3.46157242e-009 ...
#      1.59850881e-002 1.29730829e-002 3.14939351e-003]
#     ...
#     [1.84062551e-006 2.02672535e-005 1.00643066e-004 ...
#      4.62596764e-007 8.02160488e-009 4.65469809e-011]
#     [4.46888090e-006 2.35428444e-005 5.65320388e-005 ...
#      8.34937724e-009 7.62119888e-011 2.36885931e-013]
#     [4.71930552e-006 1.24169076e-005 1.50364307e-005 ...
#      8.66676992e-011 4.31417225e-013 7.43207251e-016]]
#
#    [[1.07553348e-014 1.44741801e-011 6.99877690e-009 ...
#      6.59329472e-003 2.33722205e-003 2.08321253e-004]
#     [4.41212865e-012 1.94533036e-009 3.16360332e-007 ...
#      1.99257735e-003 2.85630686e-004 1.06532088e-005]
#     [5.53655891e-010 8.61823881e-008 5.06569349e-006 ...
#      2.92934793e-004 1.79352365e-005 2.94794141e-007]
#     ...
#     [5.00150242e-006 1.05891164e-005 9.24050333e-006 ...
#      1.74810510e-012 3.01499891e-015 1.57868034e-018]
#     [2.38509428e-006 2.47938678e-006 1.07639088e-006 ...
#      7.82062926e-015 7.40763661e-018 2.17190932e-021]
#     [5.48189374e-007 2.91385365e-007 6.54692561e-008 ...
#      2.18659243e-017 1.17456439e-020 1.98868554e-024]]
#
#    [[1.10676339e-009 1.64191370e-007 7.80142483e-006 ...
#      1.21450816e-005 2.14997922e-007 8.60112405e-010]
#     [3.61858761e-008 1.88005974e-006 3.22273577e-005 ...
#      4.97025857e-007 3.87342111e-009 7.06829859e-012]
#     [4.34270339e-007 8.45326627e-006 5.57635059e-005 ...
#      1.12635428e-008 4.05110381e-011 3.52521943e-014]
#     ...
#     [2.81399904e-007 9.26710276e-008 1.14515311e-008 ...
#      2.92112184e-020 4.00017794e-024 1.51058098e-028]
#     [2.83609760e-008 4.73605977e-009 3.01420651e-010 ...
#      3.62984764e-023 2.86136686e-027 6.35205979e-032]
#     [1.51636774e-009 1.33350229e-010 4.53399520e-012 ...
#      3.03627428e-026 1.41795680e-030 1.90182540e-035]]]
#
#
#   [[[5.97522232e-120 5.48554685e-112 3.56563824e-104 ...
#      7.15983280e-068 2.83569616e-061 6.16686968e-055]
#     [7.85554845e-106 1.75164475e-098 2.75826923e-091 ...
#      4.66832989e-058 4.54490105e-052 2.44888525e-046]
#     [3.50408959e-093 2.12737207e-086 9.09639216e-080 ...
#      2.28137779e-049 6.09744078e-044 9.08043328e-039]
#     ...
#     [1.93417811e-047 6.49036044e-043 1.51408422e-038 ...
#      1.77904320e-019 2.65435798e-016 2.25661287e-013]
#     [4.18567000e-041 6.07955429e-037 6.12436737e-033 ...
#      1.06897761e-015 6.89470023e-013 2.54150473e-010]
#     [1.57033964e-035 1.04082156e-031 4.77376368e-028 ...
#      1.61211662e-012 4.73641546e-010 7.97441270e-008]]
#
#    [[9.88159796e-104 5.14459227e-096 1.76958130e-088 ...
#      4.66173358e-054 6.02602642e-048 3.90236010e-042]
#     [4.45011206e-091 5.57762163e-084 4.62218621e-077 ...
#      1.05531924e-045 3.41279178e-040 5.59670456e-035]
#     [9.14281906e-080 3.09217674e-073 6.91657822e-067 ...
#      2.38539137e-038 2.14875379e-033 9.91961256e-029]
#     ...
#     [2.93190137e-039 5.25426416e-035 6.21348236e-031 ...
#      1.02709029e-013 5.39775269e-011 1.50799869e-008]
#     [9.45600006e-034 7.28011322e-030 3.69561667e-026 ...
#      9.04629897e-011 2.06603375e-008 2.52129060e-006]
#     [6.02410261e-029 2.10130027e-025 4.82886681e-022 ...
#      2.27715167e-008 2.37979522e-006 1.33514682e-004]]
#
#    [[4.64599335e-088 1.16806368e-080 1.79572713e-073 ...
#      2.35660834e-041 7.99425571e-036 1.22985510e-030]
#     [7.06875563e-077 4.27767316e-070 1.59010323e-063 ...
#      1.95779925e-034 1.71013014e-029 6.88833646e-025]
#     [6.58966651e-067 1.07460518e-060 1.08035571e-054 ...
#      2.14341925e-028 5.34482571e-024 6.23633429e-020]
#     ...
#     [1.13693447e-031 9.67699055e-028 5.12881660e-024 ...
#      5.88175444e-009 9.27781446e-007 7.21304822e-005]
#     [5.38793991e-027 1.96299580e-023 4.45789562e-020 ...
#      7.73038189e-007 5.35617645e-005 1.84286251e-003]
#     [5.75014600e-023 9.45723037e-020 9.70338542e-017 ...
#      3.29914569e-005 1.05602521e-003 1.69000887e-002]]
#
#    ...
#
#    [[9.17785877e-025 2.59455482e-020 2.70810478e-016 ...
#      1.74863093e-003 1.54533537e-002 3.50035985e-002]
#     [1.25694044e-020 1.00849097e-016 3.06941201e-013 ...
#      6.61745442e-003 2.06913935e-002 1.71980434e-002]
#     [4.04312257e-017 1.00609814e-013 9.72811647e-011 ...
#      1.02475079e-002 1.21133534e-002 3.93440498e-003]
#     ...
#     [1.75432891e-007 3.62470409e-006 3.17792573e-005 ...
#      9.56247642e-007 1.97475118e-008 1.27342394e-010]
#     [6.93937946e-007 6.52601447e-006 2.63834657e-005 ...
#      2.08653123e-008 2.19498864e-010 7.35518708e-013]
#     [1.15681031e-006 5.18634853e-006 1.01153949e-005 ...
#      2.58676164e-010 1.43900543e-012 2.59734848e-015]]
#
#    [[8.02855969e-017 2.72869768e-013 3.04588721e-010 ...
#      4.72386400e-003 2.21647677e-003 2.38209920e-004]
#     [6.13697581e-014 6.33888092e-011 2.21820787e-008 ...
#      1.73659729e-003 3.15687786e-004 1.36582225e-005]
#     [1.37156601e-011 4.66718978e-009 5.53239614e-007 ...
#      3.06431251e-004 2.28604479e-005 4.20387441e-007]
#     ...
#     [1.29002618e-006 4.52784438e-006 6.14219170e-006 ...
#      3.85944672e-012 6.87869881e-015 3.46890050e-018]
#     [9.00413666e-007 1.48430337e-006 9.60555021e-007 ...
# ...
#      1.74692693e-001 4.44020611e-001 8.09623025e-001]
#     ...
#     [1.21494923e-004 3.39081785e-004 7.48088452e-004 ...
#      6.90889475e-004 2.71443501e-004 7.54247047e-005]
#     [4.21661047e-005 8.75434275e-005 1.43158220e-004 ...
#      2.81685496e-005 8.05453123e-006 1.62503943e-006]
#     [7.23217795e-006 1.13313559e-005 1.39364315e-005 ...
#      6.30289658e-007 1.33240933e-007 1.98304038e-008]]
#
#    [[2.39385079e-009 6.13908198e-008 1.24800177e-006 ...
#      7.14841300e-002 2.45605489e-001 5.83749716e-001]
#     [2.00502956e-007 3.29509057e-006 4.27029881e-005 ...
#      2.40677371e-001 5.14322985e-001 7.58221654e-001]
#     [5.76837088e-006 6.22908170e-005 5.27864048e-004 ...
#      3.33782626e-001 4.55750320e-001 4.28172338e-001]
#     ...
#     [1.31426713e-004 2.38086226e-004 3.31698563e-004 ...
#      1.93602353e-005 3.94814145e-006 5.48004163e-007]
#     [2.36394168e-005 3.15931831e-005 3.23639812e-005 ...
#      3.88753303e-007 5.73777778e-008 5.75368517e-009]
#     [2.17527228e-006 2.17694820e-006 1.66469398e-006 ...
#      4.44967998e-009 4.83020276e-010 3.55637889e-011]]
#
#    [[4.08287886e-007 6.86989344e-006 8.85492548e-005 ...
#      2.90607753e-001 4.94463434e-001 5.54303858e-001]
#     [1.23151796e-005 1.31156930e-004 1.06511631e-003 ...
#      3.28046448e-001 3.44848149e-001 2.38441722e-001]
#     [1.35837041e-004 9.39691783e-004 4.93554451e-003 ...
#      1.63158684e-001 1.08901439e-001 4.77339253e-002]
#     ...
#     [5.56886645e-005 6.16538350e-005 5.09037668e-005 ...
#      1.29527676e-007 1.25810078e-008 7.97064290e-010]
#     [5.10148140e-006 4.13498096e-006 2.49206945e-006 ...
#      1.26707901e-009 8.86972231e-011 4.04532526e-012]
#     [2.47807817e-007 1.49335607e-007 6.67284734e-008 ...
#      7.34464918e-012 3.76648038e-013 1.25713437e-014]]
#
#    ...
#
#    [[8.26390014e-004 4.17789742e-004 1.26229527e-004 ...
#      4.67547321e-011 3.27444663e-013 1.08405520e-015]
#     [1.11642804e-004 3.46911236e-005 6.45036040e-006 ...
#      2.20431317e-013 9.72159426e-016 2.04005686e-018]
#     [7.70252837e-006 1.51195241e-006 1.77785368e-007 ...
#      6.39663549e-016 1.82192451e-018 2.48412816e-021]
#     ...
#     [1.91672812e-015 5.35342952e-017 8.99114592e-019 ...
#      2.24616436e-031 9.92753933e-035 2.15249291e-038]
#     [5.02483859e-018 1.00771477e-019 1.21592142e-021 ...
#      5.95860166e-035 1.91740235e-038 3.03896718e-042]
#     [8.46811721e-021 1.23987488e-022 1.09280963e-024 ...
#      1.13974036e-038 2.71276767e-042 3.19233541e-046]]
#
#    [[1.76584226e-005 3.04061198e-006 2.92489496e-007 ...
#      1.18500301e-016 1.67848556e-019 1.03456041e-022]
#     [7.98278222e-007 8.48491645e-008 5.05345023e-009 ...
#      2.00189850e-019 1.81690080e-022 7.23662049e-026]
#     [1.97044409e-008 1.32806756e-009 5.02925916e-011 ...
#      2.21182080e-022 1.31734328e-025 3.47037314e-029]
#     ...
#     [6.64015696e-020 6.45620925e-022 3.56401842e-024 ...
#      1.34112429e-039 1.32173146e-043 5.94998675e-048]
#     [8.47272049e-023 5.92745736e-025 2.35824250e-027 ...
#      1.79995112e-043 1.30508559e-047 4.34533563e-052]
#     [7.22865703e-026 3.69930928e-028 1.07826002e-030 ...
#      1.80743535e-047 9.78919870e-052 2.44690655e-056]]
#
#    [[2.95665545e-008 1.47656659e-009 3.82817852e-011 ...
#      6.80854434e-024 1.60321109e-027 1.50709462e-031]
#     [4.55462513e-010 1.41655297e-011 2.29837378e-013 ...
#      4.34017763e-027 6.69535539e-031 4.16604868e-035]
#     [4.08856809e-012 8.12810598e-014 8.46750885e-016 ...
#      1.91485847e-030 1.97873861e-034 8.32712102e-039]
#     ...
#     [1.98645318e-025 5.87516643e-028 9.26785512e-031 ...
#      2.42787146e-049 4.51305488e-054 3.55477276e-059]
#     [1.24594724e-028 2.66434632e-031 3.04738798e-034 ...
#      1.70063201e-053 2.35778522e-058 1.39432866e-063]
#     [5.43173534e-032 8.53521395e-035 7.19265442e-038 ...
#      9.23115187e-058 9.68409754e-063 4.36059672e-068]]]
#
#
#   ...
#
#
#   [[[2.43144811e-032 5.55504393e-029 9.37678918e-026 ...
#      6.13823689e-012 1.02644420e-009 1.06507078e-007]
#     [1.85670988e-027 2.13730565e-024 1.80979316e-021 ...
#      3.59128974e-009 2.96918290e-007 1.52302660e-005]
#     [3.01081961e-023 1.82157219e-020 8.07362717e-018 ...
#      6.02389837e-007 2.57142375e-005 6.80877196e-004]
#     ...
#     [1.18041321e-010 4.81035898e-009 1.41217648e-007 ...
#      1.11980474e-002 2.99045895e-002 4.94824901e-002]
#     [1.46605985e-009 3.79405060e-008 7.05403304e-007 ...
#      5.53279139e-003 9.27089174e-003 9.62355132e-003]
#     [7.21778086e-009 1.21460202e-007 1.46467050e-006 ...
#      1.28264860e-003 1.38195266e-003 9.22239844e-004]]
#
#    [[2.31006891e-026 3.12287807e-023 2.98241163e-020 ...
#      5.33494479e-008 3.67426657e-006 1.47668643e-004]
#     [3.64746701e-022 2.45605103e-019 1.16458947e-016 ...
#      6.12290530e-006 2.08190039e-004 4.13751357e-003]
#     [1.35966136e-018 4.76067241e-016 1.17026302e-013 ...
#      2.24670696e-004 3.93816517e-003 4.04052871e-002]
#     ...
#     [1.23485397e-008 2.78797180e-007 4.36396101e-006 ...
#      7.87581582e-003 8.57244657e-003 5.49067824e-003]
#     [5.61514254e-008 7.99431915e-007 7.87457715e-006 ...
#      1.37774322e-003 9.39712384e-004 3.77484131e-004]
#     [1.07146492e-007 9.85426011e-007 6.25833396e-006 ...
#      1.19984776e-004 5.25577871e-005 1.35697249e-005]]
#
#    [[6.96985320e-021 5.04189166e-018 2.45029324e-015 ...
#      6.46493541e-005 1.59195812e-003 2.13797885e-002]
#     [2.22232027e-017 7.93921899e-015 1.90203649e-012 ...
#      1.45779752e-003 1.77768004e-002 1.18652593e-001]
#     [1.86298935e-014 3.43303562e-012 4.23506746e-010 ...
#      1.17134502e-002 7.38264138e-002 2.55516535e-001]
#     ...
#     [3.58919059e-007 4.12487757e-006 3.14967684e-005 ...
#      7.75245579e-004 3.06052096e-004 6.71904352e-005]
#     [5.89290299e-007 4.24743713e-006 2.03149666e-005 ...
#      4.80188490e-005 1.18939051e-005 1.64159007e-006]
#     [4.30255574e-007 1.99315837e-006 6.11976233e-006 ...
#      1.57116020e-006 2.50219156e-007 2.22468048e-008]]
#
#    ...
#
#    [[3.39338009e-005 1.42578564e-004 2.85450576e-004 ...
#      3.36253262e-008 3.37097712e-010 1.20591529e-012]
#     [3.53184665e-005 7.49654456e-005 7.64656349e-005 ...
#      3.63721972e-010 1.99600569e-012 3.96880073e-015]
#     [1.64645980e-005 1.83795552e-005 9.93639128e-006 ...
#      2.29435847e-012 7.12876706e-015 8.13981523e-018]
#     ...
#     [1.12946022e-011 8.39672238e-013 3.11613581e-014 ...
#      1.98118019e-026 5.50125771e-030 5.94531271e-034]
#     [1.10041712e-013 5.17826841e-015 1.22225887e-016 ...
#      8.89252539e-030 1.63876920e-033 1.18648378e-037]
#     [6.38962452e-016 1.94892376e-017 2.99510956e-019 ...
#      2.78658479e-033 3.47973920e-037 1.72230560e-041]]
#
#    [[1.73414652e-005 1.55558199e-005 6.09685250e-006 ...
#      5.29334924e-014 5.97197556e-017 2.18495380e-020]
#     [3.93776391e-006 1.82309689e-006 3.72853475e-007 ...
#      1.52731984e-016 9.79697364e-020 2.07354910e-023]
#     [4.41494118e-007 1.09609600e-007 1.21424063e-008 ...
#      2.78449822e-019 1.04725709e-022 1.32073356e-026]
#     ...
#     [8.14718856e-016 1.45170714e-017 1.20103449e-019 ...
#      1.33216006e-035 5.15168035e-040 7.13619052e-045]
#     [2.96886704e-018 3.38777784e-020 1.80636326e-022 ...
#      2.50826191e-039 6.58505586e-044 6.26035496e-049]
#     [6.81626952e-021 5.09653013e-023 1.79123464e-025 ...
#      3.45936832e-043 6.28629788e-048 4.17932118e-053]]
#
#    [[2.29468809e-007 3.57980100e-008 2.22776743e-009 ...
#      4.78679286e-022 4.86657778e-026 1.45895376e-030]
#     [1.21115439e-008 1.00257556e-009 3.35519746e-011 ...
#      4.08893171e-025 2.46689077e-029 4.47280688e-034]
#     [3.45891921e-010 1.57467354e-011 2.93407920e-013 ...
#      2.37154059e-028 8.72840201e-033 9.82731330e-038]
#     ...
#     [2.14253988e-021 7.72648143e-024 1.19803284e-026 ...
#      9.22537447e-047 4.10078352e-052 6.00155541e-058]
#     [3.02280421e-024 7.09048471e-027 7.20822858e-030 ...
#      7.75051633e-051 2.40114317e-056 2.47932239e-062]
#     [2.83375000e-027 4.41911007e-030 3.00907401e-033 ...
#      4.98488338e-055 1.09568303e-060 8.12019379e-067]]]
#
#
#   [[[3.87327065e-038 2.63241073e-034 1.28534396e-030 ...
#      1.05742284e-014 4.17629580e-012 9.83555052e-010]
#     [1.22760845e-032 3.93063698e-029 9.00843786e-026 ...
#      1.63242753e-011 3.00002928e-009 3.29125498e-007]
#     [7.41214543e-028 1.17234229e-024 1.32264628e-021 ...
#      6.71054608e-009 6.02033252e-007 3.22732946e-005]
#     ...
#     [5.74957702e-013 4.77197943e-011 2.78517194e-009 ...
#      4.57971673e-003 2.05067006e-002 5.50569031e-002]
#     [1.67559855e-011 8.48172666e-010 3.01220465e-008 ...
#      4.04213058e-003 1.09485385e-002 1.77907998e-002]
#     [1.83276239e-010 5.80811870e-009 1.28858533e-007 ...
#      1.61209401e-003 2.71294603e-003 2.74037427e-003]]
#
#    [[3.00714685e-031 1.15231652e-027 3.02246047e-024 ...
#      4.95344527e-010 7.47499400e-008 6.30004306e-006]
#     [1.68746235e-026 3.01558168e-023 3.68019621e-020 ...
#      1.30203787e-007 9.15482458e-006 3.60615561e-004]
#     [2.03177424e-022 1.77661980e-019 1.05856282e-016 ...
#      1.02826350e-005 3.53288364e-004 6.81908159e-003]
#     ...
#     [2.08367576e-010 9.19537303e-009 2.73937989e-007 ...
#      7.91747913e-003 1.36067740e-002 1.32773383e-002]
#     [2.03413699e-009 5.44034420e-008 9.80723409e-007 ...
#      2.28034574e-003 2.37105367e-003 1.40217028e-003]
#     [7.93784322e-009 1.32130788e-007 1.48031477e-006 ...
#      3.16629822e-004 2.04585214e-004 7.53014265e-005]]
#
#    [[6.65930802e-025 1.29016637e-021 1.62084289e-018 ...
#      2.72613229e-006 1.35125721e-004 3.48168949e-003]
#     [6.48439965e-021 5.81953463e-018 3.38435892e-015 ...
#      1.23094319e-004 2.86104888e-003 3.47507952e-002]
#     [1.52795853e-017 6.66709576e-015 1.88369432e-012 ...
#      1.88170474e-003 2.14916935e-002 1.28890490e-001]
#     ...
#     [1.91996183e-008 4.11529019e-007 5.69110103e-006 ...
#      1.67747430e-003 9.77903601e-004 3.04974439e-004]
#     [6.20317317e-008 8.02213397e-007 6.68925758e-006 ...
#      1.58258767e-004 5.59878445e-005 1.06275816e-005]
#     [8.54029944e-008 6.84529194e-007 3.53560755e-006 ...
#      7.67798206e-006 1.69268042e-006 2.00782284e-007]]
#
#    ...
#
#    [[6.30859920e-006 4.62491866e-005 1.52744511e-004 ...
#      8.98098662e-008 1.02868330e-009 3.93864732e-012]
#     [1.04008006e-005 3.67652070e-005 5.91698068e-005 ...
#      1.16216210e-009 7.06281098e-012 1.46018341e-014]
#     [7.45160389e-006 1.32643449e-005 1.08545917e-005 ...
#      8.66767670e-012 2.89645516e-014 3.34654066e-017]
#     ...
#     [3.01714596e-011 2.99157387e-012 1.41626751e-013 ...
#      1.49257797e-025 3.94459502e-029 3.84961732e-033]
#     [3.94146417e-013 2.40185269e-014 7.03045852e-016 ...
#      7.50333074e-029 1.28942616e-032 8.27101891e-037]
#     [3.01659567e-015 1.15886971e-016 2.15047834e-018 ...
#      2.61518616e-032 2.98698670e-036 1.28640885e-040]]
#
#    [[7.66581992e-006 1.06941743e-005 6.14061192e-006 ...
#      1.40450675e-013 1.58189661e-016 5.40399402e-020]
#     [2.49221461e-006 1.72117120e-006 4.95748863e-007 ...
#      4.54253910e-016 2.83430626e-019 5.46959478e-023]
#     [3.91067866e-007 1.39295451e-007 2.09443719e-008 ...
#      9.21524661e-019 3.28988354e-022 3.69910468e-026]
#     ...
#     [2.91860302e-015 6.34931164e-017 6.11648969e-019 ...
#      6.85244208e-035 2.26905558e-039 2.54909552e-044]
#     [1.34141372e-017 1.81941241e-019 1.10114436e-021 ...
#      1.38709198e-038 3.06444831e-043 2.32522054e-048]
#     [3.83333375e-020 3.32174833e-022 1.29362568e-024 ...
#      2.04751264e-042 3.07988580e-047 1.60963630e-052]]
#
#    [[1.83992124e-007 3.94652377e-008 3.17149420e-009 ...
#      9.22635109e-022 8.16048721e-026 1.98944308e-030]
#     [1.27277312e-008 1.39665259e-009 5.83245112e-011 ...
#      8.38679558e-025 4.31064317e-029 6.23693538e-034]
#     [4.68635230e-010 2.73296854e-011 6.15339961e-013 ...
#      5.15560204e-028 1.58485156e-032 1.39871895e-037]
#     ...
#     [8.40595546e-021 3.36590925e-023 5.51240541e-026 ...
#      2.54793560e-046 8.69507005e-052 9.24288029e-058]
#     [1.41657783e-023 3.60235165e-026 3.78176073e-029 ...
#      2.22579345e-050 5.21853798e-056 3.86329064e-062]
#     [1.57065254e-026 2.59606495e-029 1.78689944e-032 ...
#      1.48476332e-054 2.43641762e-060 1.27868601e-066]]]
#
#
#   [[[1.32657830e-044 2.98421976e-040 4.67310672e-036 ...
#      7.64886549e-018 7.73028852e-015 4.45885148e-012]
#     [1.94002625e-038 1.90888263e-034 1.30381231e-030 ...
#      3.31209087e-014 1.45799058e-011 3.67262200e-009]
#     [4.79767059e-033 2.17774071e-029 6.84387228e-026 ...
#      3.52549311e-011 7.12837073e-009 8.26700682e-007]
#     ...
#     [1.05490205e-015 1.91096367e-013 2.37058348e-011 ...
#      1.08703233e-003 8.59251248e-003 3.93049405e-002]
#     [7.61770603e-014 8.05326553e-012 5.81979268e-010 ...
#      1.76858188e-003 8.12993193e-003 2.16574256e-002]
#     [1.94631436e-012 1.23608896e-010 5.35737950e-009 ...
#      1.24900377e-003 3.43804634e-003 5.49150680e-003]]
#
#    [[1.04561303e-036 1.25528347e-032 9.95666591e-029 ...
#      2.27932671e-012 8.09993488e-010 1.53225852e-007]
#     [2.27996091e-031 1.18727562e-027 4.07997263e-024 ...
#      1.44004352e-009 2.23948801e-007 1.86291695e-005]
#     [9.60995731e-027 2.29051648e-023 3.59843285e-020 ...
#      2.55661223e-007 1.83361959e-005 7.06511410e-004]
#     ...
#     [1.50949603e-012 1.38955683e-010 8.38653771e-009 ...
#      5.10034760e-003 1.44991145e-002 2.25198146e-002]
#     [3.31383085e-011 1.77073706e-009 6.19796337e-008 ...
#      2.48007926e-003 4.10817283e-003 3.72795713e-003]
#     [2.76000915e-010 8.81555736e-009 1.84287317e-007 ...
#      5.61895504e-004 5.58363540e-004 3.04721353e-004]]
#
#    [[2.07989559e-029 1.18414322e-025 4.20259594e-022 ...
#      6.59939118e-008 7.01729324e-006 3.68140907e-004]
#     [6.65893755e-025 1.63732370e-021 2.51127851e-018 ...
#      6.19171131e-006 2.91119013e-004 6.80220465e-003]
#     [4.71471344e-021 5.28354234e-018 3.69522596e-015 ...
#      1.86199131e-004 4.07470315e-003 4.46053375e-002]
#     ...
#     [4.98104966e-010 2.11542950e-008 5.61378237e-007 ...
#      2.54018004e-003 2.27912027e-003 1.04946337e-003]
#     [3.29227320e-009 8.09006537e-008 1.24234495e-006 ...
#      3.72221779e-004 1.95598555e-004 5.29653848e-005]
#     [8.85873614e-009 1.29726426e-007 1.18732249e-006 ...
#      2.72632680e-005 8.63531124e-006 1.41479571e-006]]
#
#    ...
#
#    [[8.00919206e-007 1.07714269e-005 6.14330244e-005 ...
#      2.13181165e-007 2.85240093e-009 1.19109003e-011]
#     [2.13238785e-006 1.31604224e-005 3.48939883e-005 ...
#      3.31566167e-009 2.27893693e-011 4.98699882e-014]
#     [2.38998722e-006 7.09365606e-006 9.15298860e-006 ...
#      2.93658340e-011 1.07667613e-013 1.28026630e-016]
#     ...
#     [6.13090939e-011 8.39100344e-012 5.22968026e-013 ...
#      1.02646691e-024 2.62262011e-028 2.34230216e-032]
#     [1.08613778e-012 8.85628148e-014 3.31270121e-015 ...
#      5.79608218e-028 9.42806593e-032 5.42675233e-036]
#     [1.10735392e-014 5.52792431e-016 1.27462484e-017 ...
#      2.25302031e-031 2.38762222e-035 9.05716401e-040]]
#
#    [[2.52516857e-006 5.71039118e-006 4.98639782e-006 ...
#      3.41959658e-013 3.90560679e-016 1.26167908e-019]
#     [1.19110932e-006 1.27615204e-006 5.36280978e-007 ...
#      1.24283133e-015 7.65629452e-019 1.36355263e-022]
#     [2.64822721e-007 1.40456192e-007 2.96411149e-008 ...
#      2.81210432e-018 9.66598545e-022 9.80257432e-026]
#     ...
#     [8.40188100e-015 2.29715018e-016 2.64508774e-018 ...
#      3.28224277e-034 9.41302791e-039 8.65662987e-044]
#     [4.91011689e-017 8.13797915e-019 5.73217844e-021 ...
#      7.15472472e-038 1.34477995e-042 8.21732800e-048]
#     [1.75982809e-019 1.81469460e-021 8.02049054e-024 ...
#      1.13212252e-041 1.42453508e-046 5.90327733e-052]]
#
#    [[1.17641813e-007 3.58691811e-008 3.83351553e-009 ...
#      1.66137960e-021 1.29150064e-025 2.58032621e-030]
#     [1.07599341e-008 1.61548671e-009 8.65737314e-011 ...
#      1.60913169e-024 7.11537362e-029 8.27688032e-034]
#     [5.14992982e-010 3.96473278e-011 1.10781609e-012 ...
#      1.04970527e-027 2.72062171e-032 1.89571844e-037]
#     ...
#     [2.76722096e-020 1.25997910e-022 2.22615720e-025 ...
#      6.62601742e-046 1.74953262e-051 1.35897880e-057]
#     [5.60159604e-023 1.57992887e-025 1.74789921e-028 ...
#      6.02430749e-050 1.07699177e-055 5.74974227e-062]
#     [7.38490962e-026 1.32229762e-028 9.38108729e-032 ...
#      4.17176705e-054 5.14791894e-060 1.92409943e-066]]]]]

# %%
marginliks = np.zeros((n,n))

for i, om in enumerate(oms):
    for j, ol in enumerate(ols):
        marginliks[i,j] = np.sum([np.sum([np.sum(likelihood[i,j,k,l,:]) for l, orr in enumerate(orrs)]) for k, wa in enumerate(was)])

# [np.sum(np.sum(np.sum(likelihood[i,j,k,l,:])))]

# np.sum(likelihood[i,j,k,l,:])

# np.sum([np.sum([np.sum(likelihood[1,2,3,4,:])][1,2,3,:])][1,2,:])

# [np.sum(likelihood[i,j,1,l,:]) for l ]

# marginliks = np.ones((n,n))
# print(marginliks)
# [np.sum([np.sum(likelihood[1,2,k,l,:]) for l, orr in enumerate(orrs)]) for k, wa in enumerate(was)]

# %%
np.sum(likelihood)
# Out:
# 1398.1117567741946

# %%
marginliks
# Out:
# array([[34.55488869, 26.94441038, 20.31056036, 14.93055956, 10.73990802,
#          7.55325848,  5.18187254,  3.45885328,  2.23971683,  1.40331926],
#        [37.34010892, 30.00886607, 23.06821546, 17.09622007, 12.31832757,
#          8.6625544 ,  5.94283914,  3.96909249,  2.57503717,  1.61869801],
#        [38.16624966, 31.59290977, 24.99337491, 18.91240244, 13.77021886,
#          9.72122717,  6.68133958,  4.46986635,  2.90462492,  1.82936863],
#        [37.54835726, 31.71373081, 25.71962847, 19.97292983, 14.84490937,
#         10.60309433,  7.32583076,  4.9166362 ,  3.20594251,  2.0267456 ],
#        [36.08527825, 30.86628172, 25.43429338, 20.15241696, 15.31683953,
#         11.15461082,  7.80172252,  5.26732982,  3.44640669,  2.1869168 ],
#        [34.04227117, 29.42692436, 24.51410462, 19.67302178, 15.19146172,
#         11.26848   ,  8.0199162 ,  5.48254825,  3.61223822,  2.30066859],
#        [31.4137448 , 27.49834006, 23.15493221, 18.77047791, 14.65101995,
#         11.00517411,  7.94709308,  5.5124846 ,  3.67511919,  2.35995587],
#        [28.06773439, 25.02383804, 21.37329498, 17.52693053, 13.81662742,
#         10.47824584,  7.64626859,  5.36594653,  3.61891732,  2.34654602],
#        [23.83902217, 21.89364336, 19.10747588, 15.92591499, 12.71525479,
#          9.74259961,  7.17324724,  5.08000264,  3.46074615,  2.26607495],
#        [18.63447839, 18.01321318, 16.29092728, 13.9267378 , 11.32798174,
#          8.80359178,  6.55456697,  4.68319049,  3.21567928,  2.12429111]])

# %%
marginchi2=-2*np.log(marginliks)
print(marginchi2-np.amin(marginchi2))
# Out:
# [[0.19880514 0.69635148 1.26162129 1.87708304 2.53597017 3.2399451
#   3.99357025 4.80202899 5.67120433 6.60622255]
#  [0.04376711 0.48091747 1.00699178 1.60618844 2.26172682 2.96588393
#   3.71952924 4.52682826 5.39217528 6.32065896]
#  [0.         0.37803777 0.84668164 1.40426737 2.0388868  2.73527949
#   3.48526621 4.2891862  5.15129468 6.07596142]
#  [0.03264396 0.37040375 0.78939431 1.29514752 1.88858921 2.56161146
#   3.30109009 4.09865402 4.95389097 5.8710405 ]
#  [0.11213326 0.42457445 0.81170642 1.27725476 1.82599752 2.46019734
#   3.17521413 3.9608561  4.80923892 5.71891782]
#  [0.22869717 0.52008312 0.88540592 1.32540673 1.84243613 2.43988432
#   3.12004727 3.88076321 4.71524804 5.61750367]
#  [0.38941216 0.65565193 0.99948759 1.41933259 1.91488331 2.48717215
#   3.13829079 3.86987232 4.68073209 5.56661738]
#  [0.61466187 0.84424543 1.15961873 1.55642605 2.03215771 2.58530065
#   3.21546769 3.92375764 4.71155342 5.57801428]
#  [0.94125557 1.11151054 1.38374388 1.7480079  2.19829834 2.73088725
#   3.34318633 4.03327966 4.80093478 5.64780474]
#  [1.43387613 1.50169211 1.70268653 2.01628207 2.42935137 2.93358363
#   3.52357911 4.195944   4.94782598 5.77702691]]

# %%
plt.contour(oms, ols, np.transpose(marginchi2 - np.amin(marginchi2)),cmap="winter", **{'levels':[5.89,11.31,18.21]}) #
# 5.89,11.31,18.21
# 2.3,6.18,11.83
plt.plot(oms[ibest[0]], ols[ibest[1]],'x',color='black',label='(om,ol)=(%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]]) )
plt.xlabel("$\Omega_m$", fontsize=12)
# plt.xlim(min(oms),max(oms))
plt.xlim(0,1)
plt.ylabel("$\Omega_\Lambda$", fontsize=12)
# plt.ylim(min(ols),max(ols)+0.1)
plt.ylim(0,1.1)
# plt.plot([oms[0],oms[1]], [ols[0],ols[1]],'-',color='black',label='Step size indicator' ) # Delete this line after making step size smaller!
plt.legend(frameon=False)
#plt.savefig('plots/contours.png', bbox_inches="tight", transparent=True)
plt.show()
plt.close()

# %%
mu_BestFit = dist_mod_test(zHDs,om=oms[ibest[0]], ol=ols[ibest[1]], wa=was[ibest[2]], orr=orrs[ibest[3]], w0=w0s[ibest[4]])
mscr_BestFit = np.sum((mu_BestFit-mu)/muerr**2)/np.sum(1./muerr**2)
mu_BestFit=mu_BestFit-mscr_BestFit

empty = dist_mod_test(zHDs,om=0.0, ol=0.0, orr=0.0)
mscrempty = np.sum((empty-mu)/muerr**2)/np.sum(1./muerr**2)
empty=empty-mscrempty

hubblediagram=plt.scatter(zHDs,mu-empty,marker='.',c=muerr,alpha=0.4)
plt.xlabel('redshift')
plt.ylabel('distance modulus ($\mu$)')
cbar=plt.colorbar(hubblediagram)
cbar.set_label('$\mu$ uncertainty', rotation=270)
# plt.ylim(35,45)

plt.plot(np.sort(zHDs),mu_BestFit[np.argsort(zHDs)] - empty[np.argsort(zHDs)],'-',color='black',label='(om, ol, wa, orr, w0)=(%.3f,%.3f,%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], was[ibest[2]], orrs[ibest[3]], w0s[ibest[4]] ))
# plt.axhline(y=0.0,ls=':',color='black')
plt.legend(frameon=False)
plt.show()
