# %% [markdown]
# # 3. Fitting models to data
#
# In this workbook we will import data and find the cosmological model that best fits that data.
#
# ### 3.1 First set up the packages and functions
# We need to know the distance modulus as a function of redshift.  Distance modulus is defined as
# \begin{equation} \mu(z) = 5 \log_{10}(D_L)\end{equation}
# where
# \begin{equation} D_L = R_0 S_k(\chi) (1+z) \end{equation}
# and $S_k(\chi)=\sin(\chi), \chi,\; {\rm or}\; \sinh(\chi)$ for closed, flat, and open universes respectively, and
# \begin{equation} R_0\chi = \frac{c}{H_0}\int_0^z \frac{dz}{E(z)}\end{equation}
# with $E(z)=H(z)/H_0$.
#
# Note that the absolute magnitude of the SNe is about -19.5, but it enters as an additive constant in the same way as $c/H_0$ and both have high uncertainty.  Therefore we *marginalise* over this offset and it doesn't matter what value of $H_0$ we use.
#
# #### Important: In the code below, replace ez = 1.0 with the actual function for E(z).

# %%
# First let's set up our packages
import numpy as np
from matplotlib import pyplot as plt
from scipy import integrate
import math
# And set some constants
c = 299792.458 # km/s (speed of light)
H0kmsmpc = 70.  # Hubble constant in km/s/Mpc
H0s = H0kmsmpc * 3.2408e-20 # H0 in inverse seconds is H0 in km/s/Mpc * (3.2408e-20 Mpc/km)

# Write a function for the integrand, i.e. $1/E(z)$,
def ezinv(z, om=0.3, orr=0.0, ol=0.7, w0=-1.0, wa=0.0):
    # ok = 1.-om-orr-ol
    power_for_ol = 3*(1+w0+(wa*(1-(1/(1+z)))))
    ez = np.sqrt((orr*((1+z)**4)) + (om*((1+z)**3)) + ((1.0-om-ol-orr)*((1+z)**2)) + (ol*((1+z)**(power_for_ol))))
    return 1./ez

# The curvature correction function
def Sk(xx, ok):
    if ok < 0.0:
        dk = np.sin(np.sqrt(-ok)*xx)/np.sqrt(-ok)
    elif ok > 0.0:
        dk = np.sinh(np.sqrt(ok)*xx)/np.sqrt(ok)
    else:
        dk = xx
    return dk

# The distance modulus
def dist_mod(zs, om=0.3, orr=0.0, ol=0.7, w0=-1.0, wa=0.0):
    """ Calculate the distance modulus, correcting for curvature"""
    ok = 1.0 - om - orr - ol
    xx = np.array([integrate.quad(ezinv, 0, z, args=(om, orr, ol, w0, wa))[0] for z in zs])
    D = Sk(xx, ok)
    lum_dist = D * (1 + zs) 
    dist_mod = 5 * np.log10(lum_dist) # Distance modulus
    # Add an arbitrary constant that's approximately the log of c on Hubble constant minus absolute magnitude of -19.5
    # dist_mod = dist_mod + np.log(c/H0kmsmpc)-(-19.5)  # You can actually skip this step and it won't make a difference to our fitting
    return dist_mod

# The distance modulus
def dist_mod_test(zs, om=0.3, orr=0.0, ol=0.7, w0=-1.0, wa=0.0):
    """ Calculate the distance modulus, correcting for curvature"""
    ok = 1.0 - om - orr - ol
    keypoints = np.linspace(0.0,max(zs),100)
    xxkey = np.array([integrate.quad(ezinv, 0, z, args=(om, orr, ol, w0, wa))[0] for z in keypoints])
    xx = np.ones([len(zs)])
    for i, z in enumerate(zs):
        closeind = np.argmin(abs(z*np.ones([100]) - keypoints))
        closexxkey = xxkey[closeind]
        closez = keypoints[closeind] 
        if closez < z:
            g = ((xxkey[closeind+1] - closexxkey)/(keypoints[closeind+1] - closez)) 
            a = (closexxkey-(g*closez))
            xx[i] = g*z + a
        elif closez > z:
            g = ((closexxkey - xxkey[closeind-1] )/(closez - keypoints[closeind-1])) 
            a = (closexxkey-(g*closez))
            xx[i] = g*z + a
        else:
            xx[i] = closexxkey
    D = Sk(xx, ok)
    lum_dist = D * (1 + zs) 
    dist_mod = 5 * np.log10(lum_dist) # Distance modulus
    # Add an arbitrary constant that's approximately the log of c on Hubble constant minus absolute magnitude of -19.5
    # dist_mod = dist_mod + np.log(c/H0kmsmpc)-(-19.5)  # You can actually skip this step and it won't make a difference to our fitting
    return dist_mod

# %%
w0=-1.0
wa=0.0
3*(1+w0+(wa*(1-(1/(1+2)))))
# Out:
# 0.0

# %% [markdown]
# ### 3.2 Now read in the data
# I have generated some mock supernova data at random redshifts between $0.02<z<1.0$.  I then choose a cosmological model and calculate the distance modulus for each redshift in that model.  Then I give some uncertainty to the data points and scatter them randomly about the correct model by an amount corresponding to their uncertainty.
#
# I've generated 5 different models, all in files called DataX.txt, where X is a number from 0-4.
#
# There are five possible variables that I have specified in the models.  These are
# * Matter density: $\Omega_M$
# * Dark Energy density: $\Omega_\Lambda$
# * Radiation density: $\Omega_R$
# * Equation of state of dark energy: $w_0$
# * Change in the equation of state with scalefactor: $w_a$, where $w=w_0+w_a(1-a)$.
#
# You can test your code on Data00.txt and Data0.txt.  Both were generated using a model with $(\Omega_M,\Omega_{\Lambda})=(0.3,0.7)$ and all other parameters set to their standard values, namely $\Omega_R=0.0$, $w_0=-1.0$, $w_a=0.0$.  In addition Data00.txt has perfect data with no scatter and small uncertainties, so you should be able to recover exactly the correct model.
#
# Data sets 1-2 are models in which $\Omega_R=0.0$, $w_0=-1.0$, $w_a=0.0$ and only $\Omega_M$ and $\Omega_{\Lambda}$ change.
#
# Data sets 3-4 could be anything! (Within the realms of the five parameters described above.)
#
# Feel free to choose which data set you want to analyse for your project.

# %%
# Add a new function that reads in the data (data files should be in a directory called data)
def read_data(model_name):
    d = np.genfromtxt('data/'+model_name+'.txt',delimiter=',')
    zs = d[:,0]
    mu = d[:,1]
    muerr=d[:,2]
    return zs, mu, muerr

zs, mu, muerr = read_data('Data00')

# Plot it to see what it looks like, this is called a Hubble diagram
plt.errorbar(zs,mu,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
plt.xlim(0,1.0)
plt.xlabel('redshift')
plt.ylabel('magnitude')
plt.show()

# %% [markdown]
# ### 3.3 Calculate the theory corresponding to that data for a range of cosmological models
# Then overplot them on the Hubble diagram.  Here we're just testing some specific interesting examples.
# It's always important to visualise your data and check that the models and data are doing what you think they are!

# %%
mu_om00_ox00 = dist_mod(zs,om=0.0,ol=0.0)  # We're going to use this empty model as a benchmark to compare the others to
mu_om10_ox00 = dist_mod(zs,om=1.0,ol=0.0)
mu_om03_ox00 = dist_mod(zs,om=0.3,ol=0.0)
mu_om03_ox07 = dist_mod(zs,om=0.3,ol=0.7)
test = dist_mod_test(zs,om=0.3,ol=0.7)

# Plot it to see what it looks like, this is called a Hubble diagram
plt.errorbar(zs,mu,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
plt.plot(zs,mu_om00_ox00,':',color='black',label='(0.0, 0.0)')
plt.plot(zs,mu_om10_ox00,'-.',color='red',label='(1.0, 0.0)')
plt.plot(zs,mu_om03_ox00,'--',color='blue',label='(0.3, 0.0)')
plt.plot(zs,mu_om03_ox07,'-',color='green',label='(0.3, 0.7)')
plt.plot(zs,test,'-',color='yellow',label='test')
plt.xlim(0,1.0)
plt.xlabel('redshift')
plt.ylabel('magnitude')
plt.legend(frameon=False)
plt.show()

# Now plot a Hubble diagram relative to the empty model (i.e. subtract the empty model from all the data and models)
plt.errorbar(zs,mu-mu_om00_ox00,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
# plt.plot(zs,mu_om10_ox00-mu_om00_ox00,'-.',color='red',label='(1.0, 0.0)')
# plt.plot(zs,mu_om03_ox00-mu_om00_ox00,'--',color='blue',label='(0.3, 0.0)')
plt.plot(zs,mu_om03_ox07-mu_om00_ox00,'-',color='green',label='(0.3, 0.7)')
plt.plot(zs,test-mu_om00_ox00,'-',color='yellow',label='test')
plt.axhline(y=0.0,ls=':',color='black')
plt.xlim(0.0,1.0)
plt.xlabel('redshift')
plt.ylabel('magnitude normalised to (0,0)')
plt.legend(frameon=False)
plt.show()

# %% [markdown]
# ### 3.4 Normalise the theory
# You can see that there is a vertical offset between the different theory curves.
# We marginalise over this vertical offset, because we do not have enough information to constrain the vertical offset independently.
# In other words we use the data to determine what the vertical offset should be, but we do not care about what the answer is!
# (We are interested in the other parameters in the fit, but not that one.  The other parameters determine the *shape* of the curve.)
#
# The easiest way to normalise the curves is to take a weighted average of the difference between the data points and the theory in each case.

# %%
# Calculate mscript for each of these, which is the thing that determines the vertical normalisation 
mscr_om10_ox00 = np.sum((mu_om10_ox00-mu)/muerr**2)/np.sum(1./muerr**2)
mscr_om03_ox00 = np.sum((mu_om03_ox00-mu)/muerr**2)/np.sum(1./muerr**2)
mscr_om03_ox07 = np.sum((mu_om03_ox07-mu)/muerr**2)/np.sum(1./muerr**2)

print(mscr_om10_ox00,mscr_om03_ox00,mscr_om03_ox07)

mu_om10_ox00=mu_om10_ox00-mscr_om10_ox00
mu_om03_ox00=mu_om03_ox00-mscr_om03_ox00
mu_om03_ox07=mu_om03_ox07-mscr_om03_ox07

# Repeat the plot and see how it changes
# Plot it to see what it looks like, this is called a Hubble diagram
plt.errorbar(zs,mu,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
plt.plot(zs,mu_om10_ox00,'-.',color='red',label='(1.0, 0.0)')
plt.plot(zs,mu_om03_ox00,'--',color='blue',label='(0.3, 0.0)')
plt.plot(zs,mu_om03_ox07,'-',color='green',label='(0.3, 0.7)')
plt.xlim(0,1.0)
plt.xlabel('redshift')
plt.ylabel('magnitude')
plt.legend(frameon=False)
plt.show()

# Now plot a Hubble diagram relative to the empty model (i.e. subtract the empty model from all the data and models)
plt.errorbar(zs,mu-mu_om00_ox00,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
plt.plot(zs,mu_om10_ox00-mu_om00_ox00,'-.',color='red',label='(1.0, 0.0)')
plt.plot(zs,mu_om03_ox00-mu_om00_ox00,'--',color='blue',label='(0.3, 0.0)')
plt.plot(zs,mu_om03_ox07-mu_om00_ox00,'-',color='green',label='(0.3, 0.7)')
# plt.axhline(y=0.0,ls=':',color='black')
plt.xlim(0,1.0)
plt.xlabel('redshift')
plt.ylabel('magnitude normalised to (0,0)')
plt.legend(frameon=False)
plt.show()
# Out:
# -28.23197544216794 -28.051825848149726 -27.862352670695035

# %% [markdown]
# ## 3.5 Perform a fit to many models
# To find the best model that best matches the data use a $\chi^2$ test.

# %%
# Set up the arrays for the models you want to test, e.g. a range of Omega_m and Omega_Lambda models:
n = 21                         # Increase this for a finer grid
oms = np.linspace(0.0, 0.5, n)   # Array of matter densities
ols = np.linspace(0.0, 1.0, n)   # Array of cosmological constant values
chi2 = np.ones((n, n)) * np.inf  # Array to hold our chi2 values, set initially to super large values

# Calculate Chi2 for each model
for i, om in enumerate(oms):                                          # loop through matter densities
        for j, ol in enumerate(ols):                                  # loop through cosmological constant densities
            mu_model = dist_mod_test(zs, om=om, ol=ol)                     # calculate the distance modulus vs redshift for that model 
            mscr = np.sum((mu_model-mu)/muerr**2)/np.sum(1./muerr**2) # Calculate the vertical offset to apply
            mu_model_norm = mu_model-mscr                             # Apply the vertical offset
            chi2[i,j] = np.sum((mu_model_norm - mu) ** 2 / muerr**2)  # Calculate the chi2 and save it in a matrix
            
# Convert that to a likelihood and calculate the reduced chi2
likelihood = np.exp(-0.5 * (chi2-np.amin(chi2)))  # convert the chi^2 to a likelihood (np.amin(chi2) calculates the minimum of the chi^2 array)
chi2_reduced = chi2 / (len(mu)-2)                 # calculate the reduced chi^2, i.e. chi^2 per degree of freedom, where dof = number of data points minus number of parameters being fitted 

# Calculate the best fit values (where chi2 is minimum)
indbest = np.argmin(chi2)                 # Gives index of best fit but where the indices are just a single number
ibest   = np.unravel_index(indbest,[n,n]) # Converts the best fit index to the 2d version (i,j)
print( 'Best fit values are (om,ol)=(%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]] ) )
print( 'Reduced chi^2 for the best fit is %0.2f'%chi2_reduced[ibest[0],ibest[1]] )
print('likelihood = ',likelihood[ibest[0],ibest[1]])


# # Uncomment this code and comment the previous if doing a grid search with three parameters: om, orr, and ol.
# # Set up the arrays for the models you want to test, e.g. a range of Omega_m and Omega_Lambda models:
# n = 25                        # Increase this for a finer grid
# oms = np.linspace(0.0, 0.5, n)   # Array of matter densities
# ols = np.linspace(0.0, 1, n)   # Array of cosmological constant values
# orrs = np.linspace(0.0, 1.0, n)  # Array of radiation densities
# chi2 = np.ones((n, n, n)) * np.inf  # Array to hold our chi2 values, set initially to super large values

# # Calculate Chi2 for each model
# for i, om in enumerate(oms):                                          # loop through matter densities
#         for j, ol in enumerate(ols):
#                 for k, orr in enumerate(orrs):                              # loop through cosmological constant densities
#                     mu_model = dist_mod(zs, om=om, orr=orr, ol=ol)                     # calculate the distance modulus vs redshift for that model 
#                     mscr = np.sum((mu_model-mu)/muerr**2)/np.sum(1./muerr**2) # Calculate the vertical offset to apply
#                     mu_model_norm = mu_model-mscr                             # Apply the vertical offset
#                     chi2[i,j,k] = np.sum((mu_model_norm - mu) ** 2 / muerr**2)  # Calculate the chi2 and save it in a matrix
            
# # Convert that to a likelihood and calculate the reduced chi2
# # likelihood = np.exp(-0.5 * (chi2-np.amin(chi2)))  # convert the chi^2 to a likelihood (np.amin(chi2) calculates the minimum of the chi^2 array)
# chi2_reduced = chi2 / (len(mu)-3)                 # calculate the reduced chi^2, i.e. chi^2 per degree of freedom, where dof = number of data points minus number of parameters being fitted 

# # Calculate the best fit values (where chi2 is minimum)
# indbest = np.argmin(chi2)                 # Gives index of best fit but where the indices are just a single number
# ibest   = np.unravel_index(indbest,[n,n,n]) # Converts the best fit index to the 3d version (i,j,k)
# print( 'Best fit values are (om,ol,orr)=(%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], orrs[ibest[2]] ) )
# print( 'Reduced chi^2 for the best fit is %0.2f'%chi2_reduced[ibest[0],ibest[1],ibest[2]] )
# # print('likelihood = ',likelihood[ibest[0],ibest[1]])



# # Uncomment this code and comment the previous if doing a grid search with three parameters: om, ol, and wa
# # Set up the arrays for the models you want to test, e.g. a range of Omega_m and Omega_Lambda models:
# n = 25                        # Increase this for a finer grid
# oms = np.linspace(0.0, 0.5, n)   # Array of matter densities
# ols = np.linspace(0.0, 1.0, n)   # Array of cosmological constant values
# was = np.linspace(0.0, 1.0, n)  # Array of changes in equation of state
# chi2 = np.ones((n, n, n)) * np.inf  # Array to hold our chi2 values, set initially to super large values

# # Calculate Chi2 for each model
# for i, om in enumerate(oms):                                          # loop through matter densities
#         for j, ol in enumerate(ols):
#                 for k, wa in enumerate(was):                              # loop through cosmological constant densities
#                     mu_model = dist_mod(zs, om=om, wa=wa, ol=ol)                     # calculate the distance modulus vs redshift for that model 
#                     mscr = np.sum((mu_model-mu)/muerr**2)/np.sum(1./muerr**2) # Calculate the vertical offset to apply
#                     mu_model_norm = mu_model-mscr                             # Apply the vertical offset
#                     chi2[i,j,k] = np.sum((mu_model_norm - mu) ** 2 / muerr**2)  # Calculate the chi2 and save it in a matrix
            
# # Convert that to a likelihood and calculate the reduced chi2
# # likelihood = np.exp(-0.5 * (chi2-np.amin(chi2)))  # convert the chi^2 to a likelihood (np.amin(chi2) calculates the minimum of the chi^2 array)
# chi2_reduced = chi2 / (len(mu)-3)                 # calculate the reduced chi^2, i.e. chi^2 per degree of freedom, where dof = number of data points minus number of parameters being fitted 

# # Calculate the best fit values (where chi2 is minimum)
# indbest = np.argmin(chi2)                 # Gives index of best fit but where the indices are just a single number
# ibest   = np.unravel_index(indbest,[n,n,n]) # Converts the best fit index to the 3d version (i,j,k)
# print( 'Best fit values are (om,ol,wa)=(%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], was[ibest[2]] ) )
# print( 'Reduced chi^2 for the best fit is %0.2f'%chi2_reduced[ibest[0],ibest[1],ibest[2]] )
# # print('likelihood = ',likelihood[ibest[0],ibest[1]])


# ##### THIS WILL TAKE A LOOOOOOOONNNG TIME TO RUN.
# # Uncomment this code and comment the previous if doing a grid search with three parameters: om, ol, orr, wa, and w0
# # Set up the arrays for the models you want to test, e.g. a range of Omega_m and Omega_Lambda models:
# n = 10                        # Increase this for a finer grid
# oms = np.linspace(0.0, 0.4, n)   # Array of matter densities
# ols = np.linspace(0.0, 0.4, n)   # Array of cosmological constant values
# was = np.linspace(0.0, 0.5, n)  # Array of changes in equation of state
# orrs = np.linspace(0.0, 0.25, n) # array of radiation densities
# w0s = np.linspace(-1.5, -1.0, n)
# chi2 = np.ones((n, n, n, n, n)) * np.inf  # Array to hold our chi2 values, set initially to super large values

# # Calculate Chi2 for each model
# for i, om in enumerate(oms):    # loop through matter densities                                   
#         for j, ol in enumerate(ols):    # loop through cosmological constant densities
#                 for k, wa in enumerate(was):    # loop through changes in equation of state
#                                 for l, orr in enumerate(orrs):     # loop through radiation densities       
#                                                 for m, w0 in enumerate(w0s):                
#                                                         mu_model = dist_mod(zs, om=om, wa=wa, ol=ol, orr=orr, w0=w0)                     # calculate the distance modulus vs redshift for that model 
#                                                         mscr = np.sum((mu_model-mu)/muerr**2)/np.sum(1./muerr**2) # Calculate the vertical offset to apply
#                                                         mu_model_norm = mu_model-mscr                             # Apply the vertical offset
#                                                         chi2[i,j,k,l,m] = np.sum((mu_model_norm - mu) ** 2 / muerr**2)  # Calculate the chi2 and save it in a matrix
            
# # Convert that to a likelihood and calculate the reduced chi2
# # likelihood = np.exp(-0.5 * (chi2-np.amin(chi2)))  # convert the chi^2 to a likelihood (np.amin(chi2) calculates the minimum of the chi^2 array)
# chi2_reduced = chi2 / (len(mu)-5)                 # calculate the reduced chi^2, i.e. chi^2 per degree of freedom, where dof = number of data points minus number of parameters being fitted 

# # Calculate the best fit values (where chi2 is minimum)
# indbest = np.argmin(chi2)                 # Gives index of best fit but where the indices are just a single number
# ibest   = np.unravel_index(indbest,[n,n,n,n,n]) # Converts the best fit index to the 3d version (i,j,k)
# print( 'Best fit values are (om,ol,wa,orr,w0)=(%.3f,%.3f,%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], was[ibest[2]], orrs[ibest[3]], w0s[ibest[4]] ) )
# print( 'Reduced chi^2 for the best fit is %0.2f'%chi2_reduced[ibest[0],ibest[1],ibest[2],ibest[3],ibest[4]] )
# #For a good fit, the reduced Chi^2 should be close to 1.
# Out:
# Best fit values are (om,ol)=(0.300,0.700)
# Reduced chi^2 for the best fit is 0.00
# likelihood =  1.0

# %%
chi2
# Out:
# array([[7.29927777e+01, 6.17672618e+01, 5.65870037e+01, 5.81330287e+01,
#         6.71787310e+01, 8.46059677e+01, 1.11424704e+02, 1.48797180e+02,
#         1.98067906e+02, 2.60801222e+02, 3.38828836e+02, 4.34310673e+02,
#         5.49813748e+02, 6.88415865e+02, 8.53844157e+02, 1.05066353e+03,
#         1.28453839e+03, 1.56260500e+03, 1.89401636e+03, 2.29076693e+03,
#         2.76899282e+03],
#        [8.16193503e+01, 6.49669520e+01, 5.38158984e+01, 4.87787199e+01,
#         5.05490768e+01, 5.99155041e+01, 7.77780974e+01, 1.05168919e+02,
#         1.43277157e+02, 1.93480411e+02, 2.57383981e+02, 3.36870715e+02,
#         4.34165024e+02, 5.51916133e+02, 6.93307976e+02, 8.62206645e+02,
#         1.06336200e+03, 1.30268936e+03, 1.58767302e+03, 1.92796179e+03,
#         2.33627966e+03],
#        [9.56454053e+01, 7.39991165e+01, 5.73596409e+01, 4.62785968e+01,
#         4.13789936e+01, 4.33669985e+01, 5.30461467e+01, 7.13346204e+01,
#         9.92864194e+01, 1.38117513e+02, 1.89238432e+02, 2.54295297e+02,
#         3.35222012e+02, 4.34307481e+02, 5.54283337e+02, 6.98440158e+02,
#         8.70784096e+02, 1.07625209e+03, 1.32101434e+03, 1.61291053e+03,
#         1.96209917e+03],
#        [1.14759072e+02, 8.85186086e+01, 6.68349496e+01, 5.02054637e+01,
#         3.91904542e+01, 3.44232562e+01, 3.66223678e+01, 4.66061217e+01,
#         6.53105543e+01, 9.38113366e+01, 1.33350916e+02, 1.85372412e+02,
#         2.51562382e+02, 3.33905367e+02, 4.34754327e+02, 5.56922871e+02,
#         7.03807872e+02, 8.79555401e+02, 1.08928982e+03, 1.33943752e+03,
#         1.63819704e+03],
#        [1.38669739e+02, 1.08204528e+02, 8.18863232e+01, 6.01641098e+01,
#         4.35424519e+01, 3.25901743e+01, 2.79507449e+01, 3.03547650e+01,
#         4.06350952e+01, 5.97453052e+01, 8.87823539e+01, 1.29014707e+02,
#         1.81917522e+02, 2.49217125e+02, 3.32947885e+02, 4.35525843e+02,
#         5.59845395e+02, 7.09408279e+02, 8.88498776e+02, 1.10242667e+03,
#         1.35787236e+03],
#        [1.67106267e+02, 1.32758121e+02, 1.02183554e+02, 7.57883474e+01,
#         5.40274484e+01, 3.74124530e+01, 2.65205127e+01, 2.20049949e+01,
#         2.46083220e+01, 3.51775407e+01, 5.46833374e+01, 8.42434470e+01,
#         1.25151721e+02, 1.78914563e+02, 2.47297080e+02, 3.32382209e+02,
#         4.36647453e+02, 5.63065901e+02, 7.15241397e+02, 8.97592749e+02,
#         1.11561017e+03],
#        [1.99815386e+02, 1.61900895e+02, 1.27419507e+02, 9.67383790e+01,
#         7.02682324e+01, 4.84698214e+01, 3.18615886e+01, 2.10287864e+01,
#         1.66344060e+01, 1.94323531e+01, 3.02834431e+01, 5.01749594e+01,
#         8.02447618e+01, 1.21811264e+02, 1.76411063e+02, 2.45846685e+02,
#         3.32247857e+02, 4.38151184e+02, 5.66605268e+02, 7.21311690e+02,
#         9.06817666e+02],
#        [2.36560249e+02, 1.95372932e+02, 1.57308138e+02, 1.22698453e+02,
#         9.19151329e+01, 6.53737047e+01, 4.35405590e+01, 2.69407771e+01,
#         1.61674562e+01, 1.18928945e+01, 1.48820862e+01, 2.60091197e+01,
#         4.62772488e+01, 7.68436583e+01, 1.19050293e+02, 1.74462602e+02,
#         2.44918759e+02, 3.32592913e+02, 4.40077551e+02, 5.70492334e+02,
#         7.27630288e+02],
#        [2.77119127e+02, 2.32931369e+02, 1.91582711e+02, 1.53374767e+02,
#         1.18643541e+02, 8.77642729e+01, 6.11571436e+01, 3.92939985e+01,
#         2.27063298e+01, 1.19947962e+01, 7.84064623e+00, 1.10195122e+01,
#         2.24181822e+01, 4.30551438e+01, 7.41059527e+01, 1.16934835e+02,
#         1.73134439e+02, 2.44576362e+02, 3.33476148e+02, 4.42477975e+02,
#         5.74766635e+02],
#        [3.21284228e+02, 2.74349024e+02, 2.29994197e+02, 1.88493596e+02,
#         1.50151697e+02, 1.15307820e+02, 8.43410677e+01, 5.76761218e+01,
#         3.57900898e+01, 1.92206325e+01, 8.57566249e+00, 4.54498722e+00,
#         7.91437511e+00, 1.95826655e+01, 4.05827357e+01, 7.21074028e+01,
#         1.15541701e+02, 1.72503490e+02, 2.44895093e+02, 3.34969704e+02,
#         4.45417912e+02],
#        [3.68860628e+02, 3.19413157e+02, 2.72309840e+02, 2.27799607e+02,
#         1.86158717e+02, 1.47694429e+02, 1.12749291e+02, 8.17061445e+01,
#         5.49940191e+01, 3.30950875e+01, 1.65529272e+01, 5.98238035e+00,
#         2.08139414e+00, 5.64532741e+00, 1.75843561e+01, 3.89448033e+01,
#         7.09354884e+01, 1.14960557e+02, 1.72660769e+02, 2.45965968e+02,
#         3.37162496e+02],
#        [4.19665297e+02, 3.67924352e+02, 3.18311850e+02, 2.71054345e+02,
#         2.26402819e+02, 1.84635891e+02, 1.46063542e+02, 1.11031458e+02,
#         7.99261072e+01, 5.31807194e+01, 3.12823396e+01, 1.47802090e+01,
#         4.29576843e+00, 5.34669074e-01, 4.30128436e+00, 1.65163605e+01,
#         3.82386392e+01, 7.06915528e+01, 1.15296458e+02, 1.73714386e+02,
#         2.47899009e+02],
#        [4.73526218e+02, 4.19695497e+02, 3.67796232e+02, 3.18034869e+02,
#         2.70639734e+02, 2.25863837e+02, 1.83988124e+02, 1.45325243e+02,
#         1.10223948e+02, 7.90742375e+01, 5.23134060e+01, 3.04331920e+01,
#         1.39882599e+01, 3.60632542e+00, 3.09248213e-04, 3.98301371e+00,
#         1.64849622e+01, 3.85762336e+01, 7.14933873e+01, 1.16672928e+02,
#         1.75793262e+02],
#        [5.30281580e+02, 4.74550862e+02, 4.20571719e+02, 3.68532521e+02,
#         3.18641272e+02, 2.71128070e+02, 2.26247947e+02, 1.84284158e+02,
#         1.45551991e+02, 1.10403218e+02, 7.92312913e+01, 5.24774678e+01,
#         3.06380261e+01, 1.42728410e+01, 4.01560789e+00, 5.86108381e-01,
#         4.80500870e+00, 1.76118268e+01, 4.00868908e+01, 7.34783630e+01,
#         1.19235746e+02],
#        [5.89779042e+02, 5.32325256e+02, 4.76458807e+02, 4.22351811e+02,
#         3.70194033e+02, 3.20195056e+02, 2.72586776e+02, 2.27626264e+02,
#         1.85599096e+02, 1.46823198e+02, 1.11653343e+02, 8.04864064e+01,
#         5.37675376e+01, 3.19974515e+01, 1.57410718e+01, 5.63783447e+00,
#         2.41403419e+00, 6.89770083e+00, 2.00366311e+01, 4.29203782e+01,
#         7.68072396e+01],
#        [6.51875068e+02, 5.92863259e+02, 5.35288876e+02, 4.79309404e+02,
#         4.25098234e+02, 3.72846576e+02, 3.22765646e+02, 2.75089186e+02,
#         2.30076357e+02, 1.88015100e+02, 1.49226022e+02, 1.14066930e+02,
#         8.29381359e+01, 5.62886813e+01, 3.46236818e+01, 1.85130303e+01,
#         8.60175867e+00, 5.62243615e+00, 1.04100829e+01, 2.39202055e+01,
#         4.72507290e+01],
#        [7.16434302e+02, 6.56018529e+02, 5.96903389e+02, 5.39233203e+02,
#         4.83166658e+02, 4.28878496e+02, 3.76561447e+02, 3.26428445e+02,
#         2.78715161e+02, 2.33682941e+02, 1.91622183e+02, 1.52856269e+02,
#         1.17746139e+02, 8.66956321e+01, 6.01577657e+01, 3.86421247e+01,
#         2.27236137e+01, 1.30528617e+01, 1.03686497e+01, 1.55128280e+01,
#         2.94483062e+01],
#        [7.83329014e+02, 7.21653152e+02, 6.61153163e+02, 6.01961518e+02,
#         5.44223692e+02, 4.88099668e+02, 4.33765641e+02, 3.81415976e+02,
#         3.31265443e+02, 2.83551782e+02, 2.38538661e+02, 1.96519096e+02,
#         1.57819412e+02, 1.22803859e+02, 9.18800008e+01, 6.55050333e+01,
#         4.41932240e+01, 2.85247080e+01, 1.91559271e+01, 1.68320777e+01,
#         2.24020127e+01],
#        [8.52438580e+02, 7.89637063e+02, 7.27897701e+02, 6.67342297e+02,
#         6.08104456e+02, 5.50330923e+02, 4.94183103e+02, 4.39838786e+02,
#         3.87494128e+02, 3.37365909e+02, 2.89694125e+02, 2.44744981e+02,
#         2.02814345e+02, 1.64231749e+02, 1.29365049e+02, 9.86258586e+01,
#         7.24759212e+01, 5.14346004e+01, 3.60877254e+01, 2.70980745e+01,
#         2.52178495e+01],
#        [9.23649002e+02, 8.59847507e+02, 7.97004586e+02, 7.35232440e+02,
#         6.74654009e+02, 6.15404166e+02, 5.57631078e+02, 5.01497740e+02,
#         4.47183725e+02, 3.94887188e+02, 3.44827151e+02, 2.97246133e+02,
#         2.52413175e+02, 2.10627332e+02, 1.72221731e+02, 1.37568271e+02,
#         1.07083124e+02, 8.12331679e+01, 6.05435449e+01, 4.56065813e+01,
#         3.70923433e+01],
#        [9.96852479e+02, 9.32168541e+02, 8.68348916e+02, 8.05497158e+02,
#         7.43726624e+02, 6.83161542e+02, 6.23938232e+02, 5.66206470e+02,
#         5.10131058e+02, 4.55893597e+02, 4.03694513e+02, 3.53755385e+02,
#         3.06321607e+02, 2.61665462e+02, 2.20089662e+02, 1.81931467e+02,
#         1.47567452e+02, 1.17419087e+02, 9.19592581e+01, 7.17199329e+01,
#         5.73011959e+01]])

# %%
# Plot contours of 1, 2, and 3 sigma
plt.contour(oms,ols,np.transpose(chi2-np.amin(chi2)),cmap="winter",**{'levels':[2.30,6.18,11.83]})
plt.plot(oms[ibest[0]], ols[ibest[1]],'x',color='black',label='(om,ol)=(%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]]) )
plt.xlabel("$\Omega_m$", fontsize=12)
plt.ylabel("$\Omega_\Lambda$", fontsize=12)
# plt.plot([oms[0],oms[1]], [ols[0],ols[1]],'-',color='black',label='Step size indicator' ) # Delete this line after making step size smaller!
plt.legend(frameon=False)
#plt.savefig('plots/contours.png', bbox_inches="tight", transparent=True)
plt.show()
plt.close()

# %%
print(chi2-np.amin(chi2))
print(len(chi2))
print(np.sum(np.exp(-0.5 * (chi2))))
# Out:
# [[7.29924685e+01 6.17669526e+01 5.65866945e+01 5.81327194e+01
#   6.71784218e+01 8.46056585e+01 1.11424394e+02 1.48796871e+02
#   1.98067597e+02 2.60800912e+02 3.38828527e+02 4.34310364e+02
#   5.49813438e+02 6.88415556e+02 8.53843848e+02 1.05066322e+03
#   1.28453808e+03 1.56260469e+03 1.89401605e+03 2.29076662e+03
#   2.76899251e+03]
#  [8.16190410e+01 6.49666428e+01 5.38155892e+01 4.87784106e+01
#   5.05487676e+01 5.99151949e+01 7.77777881e+01 1.05168610e+02
#   1.43276848e+02 1.93480102e+02 2.57383671e+02 3.36870406e+02
#   4.34164715e+02 5.51915824e+02 6.93307667e+02 8.62206336e+02
#   1.06336169e+03 1.30268905e+03 1.58767271e+03 1.92796149e+03
#   2.33627935e+03]
#  [9.56450961e+01 7.39988072e+01 5.73593317e+01 4.62782876e+01
#   4.13786843e+01 4.33666893e+01 5.30458375e+01 7.13343111e+01
#   9.92861102e+01 1.38117204e+02 1.89238123e+02 2.54294988e+02
#   3.35221702e+02 4.34307172e+02 5.54283028e+02 6.98439849e+02
#   8.70783787e+02 1.07625179e+03 1.32101403e+03 1.61291022e+03
#   1.96209886e+03]
#  [1.14758763e+02 8.85182994e+01 6.68346403e+01 5.02051544e+01
#   3.91901450e+01 3.44229470e+01 3.66220586e+01 4.66058124e+01
#   6.53102450e+01 9.38110274e+01 1.33350606e+02 1.85372103e+02
#   2.51562073e+02 3.33905057e+02 4.34754018e+02 5.56922562e+02
#   7.03807562e+02 8.79555091e+02 1.08928951e+03 1.33943721e+03
#   1.63819674e+03]
#  [1.38669430e+02 1.08204219e+02 8.18860140e+01 6.01638006e+01
#   4.35421427e+01 3.25898650e+01 2.79504357e+01 3.03544558e+01
#   4.06347859e+01 5.97449959e+01 8.87820447e+01 1.29014398e+02
#   1.81917213e+02 2.49216816e+02 3.32947576e+02 4.35525534e+02
#   5.59845086e+02 7.09407970e+02 8.88498466e+02 1.10242636e+03
#   1.35787205e+03]
#  [1.67105958e+02 1.32757811e+02 1.02183245e+02 7.57880381e+01
#   5.40271391e+01 3.74121437e+01 2.65202035e+01 2.20046856e+01
#   2.46080127e+01 3.51772315e+01 5.46830282e+01 8.42431377e+01
#   1.25151412e+02 1.78914254e+02 2.47296771e+02 3.32381900e+02
#   4.36647143e+02 5.63065592e+02 7.15241088e+02 8.97592440e+02
#   1.11560987e+03]
#  [1.99815077e+02 1.61900585e+02 1.27419198e+02 9.67380697e+01
#   7.02679231e+01 4.84695121e+01 3.18612793e+01 2.10284772e+01
#   1.66340967e+01 1.94320438e+01 3.02831339e+01 5.01746502e+01
#   8.02444526e+01 1.21810954e+02 1.76410754e+02 2.45846376e+02
#   3.32247547e+02 4.38150875e+02 5.66604959e+02 7.21311381e+02
#   9.06817357e+02]
#  [2.36559940e+02 1.95372623e+02 1.57307829e+02 1.22698143e+02
#   9.19148237e+01 6.53733954e+01 4.35402498e+01 2.69404678e+01
#   1.61671470e+01 1.18925853e+01 1.48817769e+01 2.60088105e+01
#   4.62769395e+01 7.68433491e+01 1.19049983e+02 1.74462293e+02
#   2.44918450e+02 3.32592603e+02 4.40077242e+02 5.70492025e+02
#   7.27629979e+02]
#  [2.77118818e+02 2.32931060e+02 1.91582401e+02 1.53374458e+02
#   1.18643231e+02 8.77639636e+01 6.11568343e+01 3.92936892e+01
#   2.27060205e+01 1.19944869e+01 7.84033699e+00 1.10192030e+01
#   2.24178729e+01 4.30548345e+01 7.41056434e+01 1.16934526e+02
#   1.73134130e+02 2.44576053e+02 3.33475839e+02 4.42477666e+02
#   5.74766325e+02]
#  [3.21283919e+02 2.74348714e+02 2.29993888e+02 1.88493287e+02
#   1.50151387e+02 1.15307510e+02 8.43407584e+01 5.76758126e+01
#   3.57897806e+01 1.92203233e+01 8.57535325e+00 4.54467797e+00
#   7.91406586e+00 1.95823562e+01 4.05824265e+01 7.21070935e+01
#   1.15541391e+02 1.72503181e+02 2.44894784e+02 3.34969395e+02
#   4.45417603e+02]
#  [3.68860319e+02 3.19412847e+02 2.72309531e+02 2.27799298e+02
#   1.86158407e+02 1.47694120e+02 1.12748982e+02 8.17058353e+01
#   5.49937098e+01 3.30947782e+01 1.65526179e+01 5.98207111e+00
#   2.08108489e+00 5.64501817e+00 1.75840468e+01 3.89444940e+01
#   7.09351792e+01 1.14960247e+02 1.72660460e+02 2.45965659e+02
#   3.37162187e+02]
#  [4.19664988e+02 3.67924043e+02 3.18311541e+02 2.71054036e+02
#   2.26402510e+02 1.84635582e+02 1.46063233e+02 1.11031148e+02
#   7.99257980e+01 5.31804102e+01 3.12820303e+01 1.47798997e+01
#   4.29545919e+00 5.34359826e-01 4.30097511e+00 1.65160512e+01
#   3.82383300e+01 7.06912436e+01 1.15296149e+02 1.73714077e+02
#   2.47898700e+02]
#  [4.73525909e+02 4.19695188e+02 3.67795923e+02 3.18034560e+02
#   2.70639425e+02 2.25863528e+02 1.83987814e+02 1.45324934e+02
#   1.10223639e+02 7.90739282e+01 5.23130967e+01 3.04328828e+01
#   1.39879507e+01 3.60601617e+00 0.00000000e+00 3.98270447e+00
#   1.64846529e+01 3.85759244e+01 7.14930780e+01 1.16672619e+02
#   1.75792952e+02]
#  [5.30281271e+02 4.74550553e+02 4.20571410e+02 3.68532212e+02
#   3.18640963e+02 2.71127761e+02 2.26247638e+02 1.84283848e+02
#   1.45551682e+02 1.10402908e+02 7.92309821e+01 5.24771586e+01
#   3.06377169e+01 1.42725317e+01 4.01529864e+00 5.85799133e-01
#   4.80469945e+00 1.76115176e+01 4.00865816e+01 7.34780538e+01
#   1.19235437e+02]
#  [5.89778733e+02 5.32324946e+02 4.76458498e+02 4.22351502e+02
#   3.70193723e+02 3.20194747e+02 2.72586467e+02 2.27625955e+02
#   1.85598787e+02 1.46822888e+02 1.11653034e+02 8.04860971e+01
#   5.37672283e+01 3.19971422e+01 1.57407625e+01 5.63752522e+00
#   2.41372494e+00 6.89739159e+00 2.00363219e+01 4.29200689e+01
#   7.68069303e+01]
#  [6.51874758e+02 5.92862950e+02 5.35288567e+02 4.79309094e+02
#   4.25097924e+02 3.72846266e+02 3.22765337e+02 2.75088876e+02
#   2.30076048e+02 1.88014791e+02 1.49225712e+02 1.14066621e+02
#   8.29378267e+01 5.62883721e+01 3.46233725e+01 1.85127210e+01
#   8.60144942e+00 5.62212690e+00 1.04097736e+01 2.39198962e+01
#   4.72504197e+01]
#  [7.16433993e+02 6.56018220e+02 5.96903080e+02 5.39232894e+02
#   4.83166349e+02 4.28878187e+02 3.76561138e+02 3.26428135e+02
#   2.78714852e+02 2.33682631e+02 1.91621873e+02 1.52855960e+02
#   1.17745829e+02 8.66953228e+01 6.01574565e+01 3.86418154e+01
#   2.27233045e+01 1.30525524e+01 1.03683404e+01 1.55125188e+01
#   2.94479969e+01]
#  [7.83328705e+02 7.21652843e+02 6.61152853e+02 6.01961208e+02
#   5.44223383e+02 4.88099359e+02 4.33765331e+02 3.81415667e+02
#   3.31265134e+02 2.83551473e+02 2.38538352e+02 1.96518787e+02
#   1.57819102e+02 1.22803550e+02 9.18796916e+01 6.55047240e+01
#   4.41929148e+01 2.85243987e+01 1.91556179e+01 1.68317684e+01
#   2.24017035e+01]
#  [8.52438270e+02 7.89636754e+02 7.27897392e+02 6.67341988e+02
#   6.08104147e+02 5.50330614e+02 4.94182793e+02 4.39838477e+02
#   3.87493819e+02 3.37365600e+02 2.89693815e+02 2.44744672e+02
#   2.02814036e+02 1.64231440e+02 1.29364740e+02 9.86255494e+01
#   7.24756119e+01 5.14342912e+01 3.60874162e+01 2.70977652e+01
#   2.52175402e+01]
#  [9.23648693e+02 8.59847197e+02 7.97004277e+02 7.35232131e+02
#   6.74653699e+02 6.15403857e+02 5.57630769e+02 5.01497430e+02
#   4.47183415e+02 3.94886878e+02 3.44826842e+02 2.97245824e+02
#   2.52412865e+02 2.10627023e+02 1.72221422e+02 1.37567962e+02
#   1.07082815e+02 8.12328586e+01 6.05432356e+01 4.56062720e+01
#   3.70920340e+01]
#  [9.96852170e+02 9.32168232e+02 8.68348607e+02 8.05496849e+02
#   7.43726314e+02 6.83161233e+02 6.23937922e+02 5.66206161e+02
#   5.10130749e+02 4.55893288e+02 4.03694204e+02 3.53755076e+02
#   3.06321298e+02 2.61665152e+02 2.20089353e+02 1.81931158e+02
#   1.47567142e+02 1.17418777e+02 9.19589488e+01 7.17196236e+01
#   5.73008867e+01]]
# 21
# 4.3810737066248775

# %%
# # Use this cell if doing a grid search of two parameters.
# mu_BestFit = dist_mod(zs,om=oms[ibest[0]],ol=ols[ibest[1]])
# mscr_BestFit = np.sum((mu_BestFit-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_BestFit=mu_BestFit-mscr_BestFit


# mu_om07_ox00 = dist_mod(zs,0.7, ol=0.0, orr=0.0)
# mscr_om07_ox00 = np.sum((mu_om07_ox00-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_om07_ox00=mu_om07_ox00-mscr_om07_ox00

# plt.errorbar(zs,mu-mu_om00_ox00,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
# # plt.plot(zs,mu_om10_ox00-mu_om00_ox00,'-.',color='red',label='(1.0, 0.0)')
# # plt.plot(zs,mu_om03_ox00-mu_om00_ox00,'--',color='blue',label='(0.3, 0.0)')
# # plt.plot(zs,mu_om03_ox07-mu_om00_ox00,'-',color='green',label='(0.3, 0.7)')
# plt.plot(zs,mu_om07_ox00-mu_om00_ox00,'--',color='green',label='(0.7, 0.0)')
# plt.plot(zs,mu_BestFit-mu_om00_ox00,'-',color='black',label='(om,ol)=(%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]] ))
# # plt.axhline(y=0.0,ls=':',color='black')
# plt.xlim(0,1.0)
# plt.xlabel('redshift')
# plt.ylabel('magnitude normalised to (0,0)')
# plt.legend(frameon=False)
# plt.show()



# # Uncomment this code and comment the previous if doing a grid search with three parameters: om, orr, and ol.
# mu_BestFit = dist_mod(zs,om=oms[ibest[0]], ol=ols[ibest[1]], orr=orrs[ibest[2]])
# mscr_BestFit = np.sum((mu_BestFit-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_BestFit=mu_BestFit-mscr_BestFit

# mu_om05_ox00 = dist_mod(zs,om=0.5, ol=0.0, orr=0.0)
# mscr_om05_ox00 = np.sum((mu_om05_ox00-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_om05_ox00=mu_om05_ox00-mscr_om05_ox00

# mu_test = dist_mod(zs,om=0.333, ol=0.292, orr=0.0)
# mscr_test = np.sum((mu_test-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_test=mu_test-mscr_test

# plt.errorbar(zs,mu-mu_om00_ox00,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
# # plt.plot(zs,mu_om10_ox00-mu_om00_ox00,'-.',color='red',label='(1.0, 0.0)')
# # plt.plot(zs,mu_om03_ox00-mu_om00_ox00,'--',color='blue',label='(0.3, 0.0)')
# # plt.plot(zs,mu_om05_ox00-mu_om00_ox00,'--',color='green',label='(0.5, 0.0)')
# plt.plot(zs,mu_test-mu_om00_ox00,'--',color='purple',label='(missing)')

# plt.plot(zs,mu_om03_ox07-mu_om00_ox00,'-',color='green',label='(0.3, 0.7)')
# plt.plot(zs,mu_BestFit-mu_om00_ox00,'-',color='black',label='(om, ol, orr)=(%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], orrs[ibest[2]] ))
# # plt.axhline(y=0.0,ls=':',color='black')
# plt.xlim(0,1.0)
# plt.xlabel('redshift')
# plt.ylabel('magnitude normalised to (0,0)')
# plt.legend(frameon=False)
# plt.show()


# # Uncomment this code and comment the previous if doing a grid search with three parameters: om, ol, and wa.
# mu_BestFit = dist_mod(zs,om=oms[ibest[0]], ol=ols[ibest[1]], wa=was[ibest[2]])
# mscr_BestFit = np.sum((mu_BestFit-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_BestFit=mu_BestFit-mscr_BestFit


# mu_om05_ox00 = dist_mod(zs,0.5, ol=0.0, orr=0.0)
# mscr_om05_ox00 = np.sum((mu_om05_ox00-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_om05_ox00=mu_om05_ox00-mscr_om05_ox00

# plt.errorbar(zs,mu-mu_om00_ox00,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
# # plt.plot(zs,mu_om10_ox00-mu_om00_ox00,'-.',color='red',label='(1.0, 0.0)')
# # plt.plot(zs,mu_om03_ox00-mu_om00_ox00,'--',color='blue',label='(0.3, 0.0)')
# # plt.plot(zs,mu_om05_ox00-mu_om00_ox00,'--',color='green',label='(0.5, 0.0)')

# plt.plot(zs,mu_om03_ox07-mu_om00_ox00,'-',color='green',label='(0.3, 0.7)')
# plt.plot(zs,mu_BestFit-mu_om00_ox00,'-',color='black',label='(om, ol, wa)=(%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], was[ibest[2]] ))
# # plt.axhline(y=0.0,ls=':',color='black')
# plt.xlim(0,1.0)
# plt.xlabel('redshift')
# plt.ylabel('magnitude normalised to (0,0)')
# plt.legend(frameon=False)
# plt.show()


# # Uncomment this code and comment the previous if doing a grid search with three parameters: om, ol, and wa.
# mu_BestFit = dist_mod(zs,om=oms[ibest[0]], ol=ols[ibest[1]], wa=was[ibest[2]], orr=orrs[ibest[3]], w0=w0s[ibest[4]])
# mscr_BestFit = np.sum((mu_BestFit-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_BestFit=mu_BestFit-mscr_BestFit


# # mu_om05_ox00 = dist_mod(zs,0.5, ol=0.0, orr=0.0)
# # mscr_om05_ox00 = np.sum((mu_om05_ox00-mu)/muerr**2)/np.sum(1./muerr**2)
# # mu_om05_ox00=mu_om05_ox00-mscr_om05_ox00

# plt.errorbar(zs,mu-mu_om00_ox00,yerr=muerr,fmt='.',elinewidth=0.7,markersize=4,alpha=0.5)
# # plt.plot(zs,mu_om10_ox00-mu_om00_ox00,'-.',color='red',label='(1.0, 0.0)')
# # plt.plot(zs,mu_om03_ox00-mu_om00_ox00,'--',color='blue',label='(0.3, 0.0)')
# # plt.plot(zs,mu_om05_ox00-mu_om00_ox00,'--',color='green',label='(0.5, 0.0)')

# plt.plot(zs,mu_om03_ox07-mu_om00_ox00,'-',color='green',label='(0.3, 0.7)')
# plt.plot(zs,mu_BestFit-mu_om00_ox00,'-',color='black',label='(om, ol, wa, orr, w0)=(%.3f,%.3f,%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], was[ibest[2]], orrs[ibest[3]], w0s[ibest[4]] ))
# # plt.axhline(y=0.0,ls=':',color='black')
# plt.xlim(0,1.0)
# plt.xlabel('redshift')
# plt.ylabel('magnitude normalised to (0,0)')
# plt.legend(frameon=False)
# plt.show()

# %% [markdown]
# ### 3.6 Now fit the real data!!

# %% [markdown]
# The Dark Energy Survey recently released a set of 1635 new high-redshift supernovae, which they combined with 194 low-redshift supernovae to make the state-of-the-art supernova data set. You can read about it here: https://ui.adsabs.harvard.edu/abs/2024arXiv240102929D/abstract

# %% [markdown]
# The data are all available from here: https://github.com/des-science/DES-SN5YR Go into 4_DISTANCES_COVMAT and download the Hubble diagram from DES-SN5YR_HD.csv and the covariance matrix from STAT+SYS.txt.gz Use gunzip STAT+SYS.txt.gz to unzip it.
#
# Here's a snippet of code to read in the data:

# %%
import pandas as pd  # Pandas is a useful package to read in data files and select portions of the data
from matplotlib import pyplot as plt
import numpy as np

df = pd.read_csv('data/DES-SN5YR_HD.csv') # Pandas reads into a "data frame (we'll call it df)"
zHELs = df['zHEL'].to_numpy() # You can keep using it in Pandas format, but just turning it into numpy arrays so it matches what you did above. 
zHDs = df['zHD'].to_numpy()
mu = df['MU'].to_numpy()
muerr = df['MUERR_FINAL'].to_numpy()
nSN = len(zHDs)
print(nSN)

hubblediagram=plt.scatter(zHDs,mu,marker='.',c=muerr,alpha=0.4)
plt.xlabel('redshift')
plt.ylabel('distance modulus ($\mu$)')
cbar=plt.colorbar(hubblediagram)
cbar.set_label('$\mu$ uncertainty', rotation=270)
plt.ylim(35,45)
plt.show()

# Warning, with this many data points it's going to take a long time to do the fit!  Test with a small grid first!  
# And consider adding interpolation to determine luminosity distances instead of doing this many integrals.
# Out:
# 1829

# %%
# To do this properly, you really should use the covariance matrix, rather than just the diagonal errors. 
# It's optional for this project, but here's how you construct the covariance matrix from the file provided.

df2 = pd.read_csv('data/STAT+SYS.txt.gz', skiprows = 1, delim_whitespace=True,comment='#',names=['COV'], compression='gzip')
cov1d=df2['COV'].to_numpy()
cov2d=cov1d.reshape(len(mu),len(mu))  
muerr_diag = np.diag(muerr)**2
cov2d=cov2d+muerr_diag
acov = np.linalg.inv(cov2d)

# %%
n = 10                        # Increase this for a finer grid
oms = np.linspace(0.1, 0.5, n)   # Array of matter densities
ols = np.linspace(0.5, 1, n)   # Array of cosmological constant values
was = np.linspace(-1.0, 0.0, n)  # Array of changes in equation of state
orrs = np.linspace(0.0, 0.2, n) # array of radiation densities
w0s = np.linspace(-1.0, -0.5, n)
chi2 = np.ones((n, n, n, n, n)) * np.inf  # Array to hold our chi2 values, set initially to super large values
om_prior = 0.3
om_prior_sig = 0.05
omol_prior = 1.00
omol_prior_sig = 0.05


# Calculate Chi2 for each model
for i, om in enumerate(oms):    # loop through matter densities                                   
        for j, ol in enumerate(ols):    # loop through cosmological constant densities
                for k, wa in enumerate(was):    # loop through changes in equation of state
                                for l, orr in enumerate(orrs):     # loop through radiation densities       
                                                for m, w0 in enumerate(w0s):                
                                                        mu_model = dist_mod_test(zHDs, om=om, wa=wa, ol=ol, orr=orr, w0=w0)                     # calculate the distance modulus vs redshift for that model 
                                                        mscr = np.sum((mu_model-mu)/muerr**2)/np.sum(1./muerr**2) # Calculate the vertical offset to apply
                                                        # mu_model_norm = mu_model-mscr  # Apply the vertical offset
                                                        delta = np.array([mu_model - mscr - mu]) 
                                                        chi2[i,j,k,l,m]  = np.sum(delta @ acov @ np.transpose(delta)) + ((om-om_prior)/om_prior_sig)**2 + ((om+ol - omol_prior)/omol_prior_sig)**2 # Calculate the chi2 and save it in a matrix




                                                       

# Convert that to a likelihood and calculate the reduced chi2
likelihood = np.exp(-0.5 * (chi2-np.amin(chi2)))  # convert the chi^2 to a likelihood (np.amin(chi2) calculates the minimum of the chi^2 array)
chi2_reduced = chi2 / (len(mu)-1-5)                 # calculate the reduced chi^2, i.e. chi^2 per degree of freedom, where dof = number of data points minus number of parameters being fitted 

# Calculate the best fit values (where chi2 is minimum)
indbest = np.argmin(chi2)                 # Gives index of best fit but where the indices are just a single number
ibest   = np.unravel_index(indbest,[n,n,n,n,n]) # Converts the best fit index to the 5d version
print( 'Best fit values are (om,ol,wa,orr,w0)=(%.3f,%.3f,%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], was[ibest[2]], orrs[ibest[3]], w0s[ibest[4]] ) )
print( 'Reduced chi^2 for the best fit is %0.2f'%chi2_reduced[ibest[0],ibest[1],ibest[2],ibest[3],ibest[4]] )
#For a good fit, the reduced Chi^2 should be close to 1.
# Out:
# Best fit values are (om,ol,wa,orr,w0)=(0.278,0.722,-1.000,0.067,-0.722)
# Reduced chi^2 for the best fit is 0.90

# %%
print(likelihood)
# Out:
# [[[[[2.41161120e-046 4.97485169e-043 7.44845652e-040 ...
#      3.01449741e-027 1.14839216e-025 1.63481545e-024]
#     [2.64804866e-036 9.44428124e-034 2.32478518e-031 ...
#      5.94762738e-023 2.97339484e-022 5.45185141e-022]
#     [7.02109098e-029 5.37520280e-027 2.71857846e-025 ...
#      1.44964651e-020 1.22008897e-020 3.70120122e-021]
#     ...
#     [7.91251024e-020 2.51295434e-020 4.52993277e-021 ...
#      1.92419313e-029 2.84877343e-032 1.42251695e-035]
#     [4.16434293e-022 6.01055425e-023 4.82197254e-024 ...
#      2.71894739e-034 1.62375521e-037 3.23962667e-041]
#     [2.15523090e-025 1.52120486e-026 5.85734458e-028 ...
#      6.58750178e-040 1.72971959e-043 1.50456686e-047]]
#
#    [[3.97004951e-044 7.23266068e-041 9.18465026e-038 ...
#      7.34492360e-026 1.65094709e-024 1.27520357e-023]
#     [1.26043677e-034 3.82372068e-032 7.70133983e-030 ...
#      3.38761614e-022 9.83409624e-022 9.67908962e-022]
#     [1.14018491e-027 7.18898381e-026 2.88416357e-024 ...
#      2.34090323e-020 1.12742179e-020 1.81709899e-021]
#     ...
#     [3.08034008e-020 7.22884246e-021 9.31045900e-022 ...
#      3.95149055e-031 3.17222758e-034 8.08549600e-038]
#     [9.61823913e-023 1.01109317e-023 5.71531676e-025 ...
#      3.04240837e-036 9.77906469e-040 9.90273103e-044]
#     [3.11075009e-026 1.57886250e-027 4.23103948e-029 ...
#      4.27310815e-042 5.99951076e-046 2.63559921e-050]]
#
#    [[6.17002771e-042 9.67885076e-039 1.01276975e-035 ...
#      1.29778838e-024 1.62592182e-023 6.40175553e-023]
#     [5.51066057e-033 1.38787071e-030 2.22505742e-028 ...
#      1.38264184e-021 2.21049120e-021 1.10207266e-021]
#     [1.66157786e-026 8.42806588e-025 2.61220723e-023 ...
#      2.67958941e-020 7.02690338e-021 5.69892780e-022]
#     ...
#     [9.97668536e-021 1.69389964e-021 1.52297205e-022 ...
#      5.53461046e-033 2.31540100e-036 2.88536780e-040]
#     [1.83036247e-023 1.37251338e-024 5.34295064e-026 ...
#      2.31009307e-038 3.84549778e-042 1.89583563e-046]
#     [3.66819679e-027 1.31154877e-028 2.39168406e-030 ...
#      1.87259148e-044 1.35422929e-048 2.88559139e-053]]
#
#    ...
#
#    [[1.21859082e-031 5.60283597e-029 1.29452839e-026 ...
#      3.86820293e-021 9.53701825e-022 4.34621214e-023]
#     [1.31298784e-025 8.28790088e-024 2.54886253e-022 ...
#      2.55585191e-021 8.14445565e-023 4.92710685e-025]
#     [1.17810968e-021 1.30633841e-020 6.86188858e-020 ...
#      8.05440881e-023 4.22314681e-025 4.29201373e-028]
#     ...
#     [1.32169976e-024 3.06373968e-026 3.03152700e-028 ...
#      3.42676017e-045 2.77528855e-050 4.61287291e-056]
#     [1.48035277e-028 1.42224489e-030 5.74624692e-033 ...
#      6.42823157e-052 2.05649279e-057 1.35929641e-063]
#     [2.40446860e-033 1.04135310e-035 1.87137935e-038 ...
#      3.22201113e-059 4.44966284e-065 1.27723335e-071]]
#
#    [[8.73816440e-030 2.79091593e-027 4.17204676e-025 ...
#      3.75956720e-021 3.35137940e-022 4.88698687e-024]
#     [2.29944022e-024 9.84673282e-023 1.92208540e-021 ...
#      5.76644503e-022 6.77338176e-024 1.34705560e-026]
#     [6.08915426e-021 4.48412470e-020 1.46899293e-019 ...
#      5.08276751e-024 9.96872267e-027 3.40214632e-030]
#     ...
#     [1.01361502e-025 1.44573937e-027 8.36066508e-030 ...
#      2.53339390e-048 7.97418159e-054 4.72857516e-060]
#     [6.33069984e-030 3.70320163e-032 8.66498073e-035 ...
#      2.55688194e-055 3.19280180e-061 7.58427534e-068]
#     [6.08752963e-035 1.59030556e-037 1.64178402e-040 ...
#      7.35010962e-063 3.97719377e-069 4.12952761e-076]]
#
#    [[5.01328776e-028 1.05984550e-025 9.71473282e-024 ...
#      1.85495454e-021 5.48105363e-023 2.33374082e-025]
#     [3.16724527e-023 8.79719462e-022 1.03702944e-020 ...
#      6.71276249e-023 2.68087432e-025 1.60928958e-028]
#     [2.43786251e-020 1.14310554e-019 2.22919745e-019 ...
#      1.67544633e-025 1.13963129e-028 1.20558462e-032]
#     ...
#     [5.71022563e-027 4.84427897e-029 1.57768954e-031 ...
#      1.01047884e-051 1.16580162e-057 2.31746411e-064]
#     [1.97479207e-031 6.80543742e-034 8.89678478e-037 ...
#      5.50733392e-059 2.53722022e-065 2.04012103e-072]
#     [1.11732343e-036 1.70509701e-039 9.76575333e-043 ...
#      9.10973046e-067 1.82921968e-073 6.48475829e-081]]]
#
#
#   [[[4.66564857e-055 2.82616200e-050 1.11416160e-045 ...
#      5.02940145e-027 1.59885516e-024 1.42778004e-022]
#     [3.68984130e-042 2.35051041e-038 9.26573622e-035 ...
#      2.37279032e-021 6.31353298e-020 4.71073026e-019]
#     [2.55662926e-032 2.29422400e-029 1.21926382e-026 ...
#      8.41746203e-018 2.57201666e-017 2.19608921e-017]
#     ...
#     [2.41952176e-015 2.22265044e-015 1.03895848e-015 ...
#      6.35648829e-023 9.52670223e-026 3.90019016e-029]
#     [1.41019864e-016 4.87352565e-017 8.39385492e-018 ...
#      2.72363507e-027 1.38560666e-030 1.91815510e-034]
#     [6.13394854e-019 8.75490865e-020 6.11333072e-021 ...
#      1.74356181e-032 3.34306523e-036 1.73833956e-040]]
#
#    [[6.98720033e-052 3.55833890e-047 1.11742318e-042 ...
#      5.71502323e-025 9.07493406e-023 3.64821636e-021]
#     [1.11299325e-039 5.73306487e-036 1.73678864e-032 ...
#      4.50590181e-020 5.96170089e-019 2.00818518e-018]
#     [1.94558290e-030 1.36524827e-027 5.40564306e-025 ...
#      3.41982489e-017 5.16779998e-017 1.99330123e-017]
#     ...
#     [1.67538202e-015 1.07577003e-015 3.37372286e-016 ...
#      1.32249224e-024 9.54660248e-028 1.75270039e-031]
#     [5.10642968e-017 1.21533138e-017 1.38492479e-018 ...
#      2.74199373e-029 6.69156458e-033 4.14756528e-037]
#     [1.24128284e-019 1.20423922e-020 5.49568287e-022 ...
#      9.16124902e-035 8.39631269e-039 1.95209096e-043]]
#
#    [[9.60300393e-049 3.97194008e-044 9.55503778e-040 ...
#      4.21422526e-023 3.11147796e-021 5.21110692e-020]
#     [2.99370304e-037 1.20717840e-033 2.70988801e-030 ...
#      5.53472249e-019 3.40889574e-018 4.82683340e-018]
#     [1.28846998e-028 6.85636953e-026 1.95424844e-023 ...
#      8.95143955e-017 6.29167789e-017 1.02589332e-017]
#     ...
#     [9.32952420e-016 4.08033941e-016 8.34481824e-017 ...
#      1.73973363e-026 5.76960366e-030 4.51455514e-034]
#     [1.47217003e-017 2.35270799e-018 1.72540484e-019 ...
#      1.74065727e-031 1.94706857e-035 5.14523514e-040]
#     [1.98249704e-020 1.27533268e-021 3.70224525e-023 ...
#      3.02822443e-037 1.26955514e-041 1.25881432e-046]]
#
#    ...
#
#    [[5.21893186e-034 4.00972391e-030 1.23904495e-026 ...
#      2.01660559e-017 9.42651235e-018 5.31279264e-019]
#     [3.24185837e-026 2.11570659e-023 5.45261630e-021 ...
#      3.82963321e-017 1.65503242e-018 9.12710393e-021]
#     [9.21464291e-021 7.02149539e-019 2.07525522e-017 ...
#      2.93926582e-018 1.56420701e-020 1.11200267e-023]
#     ...
#     [9.88029980e-019 4.01959721e-020 5.89228807e-022 ...
#      2.07883283e-039 6.30185024e-045 2.92742489e-051]
#     [5.07021817e-022 7.10679505e-024 3.54960661e-026 ...
#      5.49050999e-046 5.72778926e-052 9.31530846e-059]
#     [3.16981669e-026 1.69795230e-028 3.20871703e-031 ...
#      3.68653196e-053 1.46716399e-059 9.24306913e-067]]
#
#    [[2.38213434e-031 1.11753085e-027 1.92587197e-024 ...
#      3.30094435e-017 4.25283754e-018 5.74037598e-020]
#     [2.54749949e-024 9.99777996e-022 1.42471100e-019 ...
#      1.13740568e-017 1.41215791e-019 1.96137528e-022]
#     [1.59400255e-019 7.19761469e-018 1.16547203e-016 ...
#      1.97846222e-019 3.12577519e-022 5.82811802e-026]
#     ...
#     [9.84513668e-020 2.24028000e-021 1.72685173e-023 ...
#      8.13078877e-043 8.04120731e-049 1.10553215e-055]
#     [2.49002667e-023 1.93594299e-025 5.05275798e-028 ...
#      1.05213275e-049 3.62171054e-056 1.76955056e-063]
#     [8.26244549e-028 2.43680598e-030 2.39293633e-033 ...
#      3.72857573e-057 4.94566288e-064 9.48561812e-072]]
#
#    [[7.97637960e-029 2.14658138e-025 1.92663743e-022 ...
#      2.26547062e-017 7.27572625e-019 2.12002107e-021]
#     [1.45295097e-022 3.23810678e-020 2.39626548e-018 ...
#      1.46503214e-018 4.75955810e-021 1.51105537e-024]
#     [1.98086906e-018 5.02602907e-017 4.20677036e-016 ...
#      5.93072170e-021 2.54911096e-024 1.13816403e-028]
#     ...
#     [6.77508113e-021 8.27747646e-023 3.20927082e-025 ...
#      1.52662260e-046 4.60683412e-053 1.74718662e-060]
#     [8.39942842e-025 3.48220675e-027 4.55040980e-030 ...
#      9.76543907e-054 1.04023382e-060 1.42724775e-068]
#     [1.47224593e-029 2.30115786e-032 1.12674421e-035 ...
#      1.84098481e-061 7.65126305e-069 4.18651871e-077]]]
#
#
#   [[[9.01191095e-068 4.13768239e-061 1.05982850e-054 ...
#      2.13377080e-028 9.77382770e-025 8.81276907e-022]
#     [1.72839723e-051 4.43040807e-046 6.05655419e-041 ...
#      3.60366621e-021 8.11317693e-019 3.68647328e-017]
#     [8.18889887e-039 1.74157181e-034 1.89866361e-030 ...
#      2.55804887e-016 4.22475068e-015 1.43399851e-014]
#     ...
#     [1.02635795e-012 4.02812559e-012 7.05685384e-012 ...
#      2.69032602e-017 5.02947184e-020 2.01825910e-023]
#     [9.12694687e-013 1.07474003e-012 5.54295890e-013 ...
#      3.86594802e-021 2.01924387e-024 2.27423516e-028]
#     [4.39582297e-014 1.74813785e-014 2.99397855e-015 ...
#      7.12406063e-026 1.17944837e-029 4.22762413e-034]]
#
#    [[2.33215760e-063 8.35311933e-057 1.55473426e-050 ...
#      1.67605131e-025 3.09917151e-022 9.94890574e-020]
#     [5.65718558e-048 1.09040356e-042 1.04953166e-037 ...
#      3.16520600e-019 2.91790354e-017 4.83452537e-016]
#     [4.61129473e-036 7.14306112e-032 5.33307473e-028 ...
#      3.44436196e-015 2.35126523e-014 2.96115631e-014]
#     ...
#     [1.59243664e-012 4.08668884e-012 4.45567776e-012 ...
#      6.46665652e-019 5.08095404e-022 7.88752045e-026]
#     [6.36230593e-013 4.82931186e-013 1.53033652e-013 ...
#      3.92890787e-023 8.63464061e-027 3.77844099e-031]
#     [1.49823882e-014 3.79265667e-015 3.94617670e-016 ...
#      3.35533938e-028 2.33965218e-032 3.27070427e-037]]
#
#    [[5.29253278e-059 1.41169446e-052 1.81284831e-046 ...
#      7.38942913e-023 5.05214460e-020 5.25835224e-018]
#     [1.57984746e-044 2.19413825e-039 1.41799987e-034 ...
#      1.57800805e-017 5.49749944e-016 3.04870634e-015]
#     [2.16418417e-033 2.34669714e-029 1.14815493e-025 ...
#      2.65167026e-014 6.94808185e-014 2.99964665e-014]
#     ...
#     [1.90739448e-012 3.10182932e-012 2.03366644e-012 ...
#      9.00216174e-021 2.81294928e-024 1.59236293e-028]
#     [3.39070801e-013 1.60930142e-013 3.03098271e-014 ...
#      2.31469495e-025 2.03008036e-029 3.26164155e-034]
#     [3.87113277e-015 6.05587102e-016 3.70664507e-017 ...
#      9.16905404e-031 2.55912161e-035 1.32142258e-040]]
#
#    ...
#
#    [[1.29093286e-038 3.38169951e-033 2.66411488e-028 ...
#      1.98644710e-014 2.16087312e-014 1.72546623e-015]
#     [8.07329823e-029 1.00545137e-024 3.78049526e-021 ...
#      1.15838841e-013 8.08690691e-015 4.56026151e-017]
#     [1.13809826e-021 1.01503495e-018 2.73240714e-016 ...
#      2.28227121e-014 1.43301643e-016 7.85829063e-020]
#     ...
#     [4.37085418e-014 4.19445112e-015 1.18909818e-016 ...
#      3.11037281e-034 3.81521859e-040 5.19437652e-047]
#     [1.20277499e-016 3.21315527e-018 2.52384613e-020 ...
#      1.17552271e-040 4.28558192e-047 1.78782448e-054]
#     [3.31644036e-020 2.80041236e-022 6.92236457e-025 ...
#      1.07182290e-047 1.30753881e-054 1.87530446e-062]]
#
#    [[6.04697216e-035 8.13796849e-030 2.94249919e-025 ...
#      6.29602025e-014 1.37248367e-014 1.87909876e-016]
#     [4.25092909e-026 2.72018342e-022 4.73857861e-019 ...
#      5.08354655e-014 7.63139491e-016 7.99281936e-019]
#     [9.26373470e-020 4.23357884e-017 5.30558110e-015 ...
#      1.80434865e-015 2.57786132e-018 2.80165184e-022]
#     ...
#     [6.70861050e-015 3.21939316e-016 4.24307103e-018 ...
#      6.70721221e-038 2.21137263e-044 7.26141590e-052]
#     [7.88659624e-018 1.04886388e-019 3.82385147e-022 ...
#      1.12388121e-044 1.12393848e-051 1.15889073e-059]
#     [1.01761182e-021 4.26036904e-024 4.88031767e-027 ...
#      4.95077910e-052 1.68663964e-059 6.10975767e-068]]
#
#    [[1.84602054e-031 1.17978165e-026 1.79854300e-022 ...
#      6.66852668e-014 2.60450970e-015 5.45908951e-018]
#     [1.46054172e-023 4.47099522e-020 3.34025391e-017 ...
#      7.89159145e-015 2.29488052e-017 4.01375471e-021]
#     [4.91453340e-018 1.07774032e-015 5.85684128e-014 ...
#      5.27919658e-017 1.55633391e-020 3.03289447e-025]
#     ...
#     [6.61237712e-016 1.51160185e-017 8.78924129e-020 ...
#      6.09785151e-042 5.01496798e-049 3.67510277e-057]
#     [3.31191960e-019 2.09307482e-021 3.36853773e-024 ...
#      4.60143255e-049 1.17513039e-056 2.77998935e-065]
#     [1.99498190e-023 3.95989732e-026 2.00323141e-029 ...
#      9.92777363e-057 8.81793631e-065 7.51035725e-074]]]
#
#
#   ...
#
#
#   [[[1.42919637e-223 4.50621614e-196 5.38126733e-170 ...
#      1.61176920e-065 1.04202781e-050 3.25306014e-038]
#     [7.16962481e-175 4.03527562e-152 1.22992909e-130 ...
#      2.28461008e-046 5.57063899e-035 1.08949208e-025]
#     [1.69707319e-136 1.57080265e-117 1.00817827e-099 ...
#      7.20433529e-032 2.60221153e-023 1.10545818e-016]
#     ...
#     [4.97000260e-035 1.84080403e-027 8.33965404e-021 ...
#      6.57273261e-004 2.22638219e-004 2.48245586e-006]
#     [5.24473065e-026 7.21772451e-020 1.28380841e-014 ...
#      2.95117889e-004 6.58780262e-006 5.43720064e-009]
#     [1.95166111e-019 1.47519753e-014 1.50936534e-010 ...
#      5.74881022e-006 1.14810958e-008 9.37213689e-013]]
#
#    [[7.98843196e-205 3.86917563e-178 5.74245504e-153 ...
#      2.08925568e-054 4.78186130e-041 4.37338227e-030]
#     [1.02934800e-159 1.14542831e-137 5.73180561e-117 ...
#      7.13955337e-038 9.05666804e-028 7.67478042e-020]
#     [3.85683974e-124 8.33630299e-106 1.05897369e-088 ...
#      1.68873834e-025 4.20749853e-018 1.03581163e-012]
#     ...
#     [9.49430931e-031 1.15913026e-023 1.55339317e-017 ...
#      4.64082266e-004 2.21438830e-005 3.04089217e-008]
#     [1.07486697e-022 5.02084511e-017 2.73797711e-012 ...
#      3.15435378e-005 1.06966502e-007 1.17964779e-011]
#     [5.71579712e-017 1.50176744e-012 4.85122974e-009 ...
#      1.17013506e-007 3.78525306e-011 4.42631331e-016]]
#
#    [[1.25842032e-186 8.01332195e-161 1.26193673e-136 ...
#      2.56484366e-044 1.80382045e-032 4.22972328e-023]
#     [5.07924074e-145 9.77543464e-124 6.99990133e-104 ...
#      2.89076192e-030 1.66617905e-021 5.37063460e-015]
#     [3.42182769e-112 1.53635506e-094 3.42190829e-078 ...
#      6.42285975e-020 9.71689782e-014 1.22391415e-009]
#     ...
#     [9.10432968e-027 3.40711639e-020 1.25115108e-014 ...
#      9.19121792e-005 5.62391092e-007 8.64831953e-011]
#     [1.12843555e-019 1.67178614e-014 2.60199567e-010 ...
#      9.99750301e-007 4.71099386e-010 6.34074175e-015]
#     [8.71618752e-015 7.46858844e-011 7.12115306e-008 ...
#      7.40098518e-010 3.56250584e-014 5.47301053e-020]]
#
#    ...
#
#    [[1.04532831e-105 2.41127682e-085 4.73401593e-067 ...
#      8.85111807e-011 2.67522877e-007 1.28499665e-006]
#     [4.61610690e-080 1.68819807e-063 8.68502058e-049 ...
#      4.77798659e-007 8.34533727e-006 3.77120911e-007]
#     [6.32963447e-060 1.70492307e-046 9.36972913e-035 ...
#      2.72461291e-005 5.60279236e-006 4.42789627e-009]
#     ...
#     [3.71085988e-012 1.14028924e-008 1.86045730e-006 ...
#      1.31984620e-017 6.69123113e-025 4.34354729e-034]
#     [1.11786266e-009 1.74105278e-007 1.59547278e-006 ...
#      3.94568743e-023 2.45279012e-031 2.26881373e-041]
#     [7.96380240e-009 8.80554125e-008 6.25275109e-008 ...
#      2.09286177e-029 1.98330784e-038 3.19182352e-049]]
#
#    [[6.62707685e-092 7.78507103e-073 6.35404792e-056 ...
#      1.01388640e-007 4.80279006e-006 3.24116979e-007]
#     [4.29157427e-069 1.16416519e-053 3.66531257e-040 ...
#      1.22117107e-005 4.84771938e-006 4.40137033e-009]
#     [2.99603956e-051 7.84271902e-039 3.49787581e-028 ...
#      2.74951948e-005 1.72823500e-007 3.66404555e-012]
#     ...
#     [1.80354583e-010 1.03436400e-007 2.76061070e-006 ...
#      2.98817399e-022 1.09887752e-030 4.54731404e-041]
#     [7.27802752e-009 2.25827086e-007 3.63799250e-007 ...
#      2.14937999e-028 1.07450025e-037 7.04309329e-049]
#     [8.88816904e-009 2.06793898e-008 2.74303708e-009 ...
#      3.22092672e-035 2.68500224e-045 3.35880224e-057]]
#
#    [[5.11059203e-079 2.63132933e-061 7.73596147e-046 ...
#      5.98622833e-006 4.12258780e-006 3.67757389e-009]
#     [6.57242132e-059 1.14882856e-044 1.92982376e-032 ...
#      2.17544766e-005 1.79964787e-007 3.04678257e-012]
#     [2.89237011e-043 6.45798699e-032 2.05447511e-022 ...
#      2.45216280e-006 4.29474652e-010 2.24949766e-016]
#     ...
#     [2.93847467e-009 2.87076404e-007 1.14136291e-006 ...
#      1.17134580e-027 2.85374979e-037 6.90176260e-049]
#     [1.66624347e-008 9.45027728e-008 2.44969504e-008 ...
#      2.19134659e-034 8.06402179e-045 3.43910194e-057]
#     [3.62964650e-009 1.63790876e-009 3.73160131e-011 ...
#      9.92238807e-042 6.67546428e-053 5.96980074e-066]]]
#
#
#   [[[3.96039398e-285 5.71208332e-249 6.37370184e-215 ...
#      6.15457900e-081 3.10056553e-062 1.76061248e-046]
#     [1.88683901e-223 8.28337060e-194 5.77730223e-166 ...
#      4.86722017e-058 1.54896736e-043 1.19449451e-031]
#     [1.75729553e-175 7.12276536e-151 7.41720703e-128 ...
#      1.24034080e-040 1.50914916e-029 7.82954607e-021]
#     ...
#     [9.17268329e-049 1.21836985e-038 1.20137342e-029 ...
#      1.57578550e-004 4.42620582e-004 2.31135179e-005]
#     [5.90941737e-037 1.37944941e-028 2.64191853e-021 ...
#      6.02423631e-004 7.30227069e-005 1.93466366e-007]
#     [5.28667127e-028 3.58802936e-021 2.17155346e-015 ...
#      7.33994290e-005 5.52603633e-007 1.04483390e-010]]
#
#    [[3.74253628e-260 2.83600887e-225 1.32439379e-192 ...
#      6.94084965e-067 4.44893891e-050 2.75675241e-036]
#     [1.75209092e-203 6.88225579e-175 3.49902740e-148 ...
#      3.07173621e-047 2.25108108e-034 3.39281453e-024]
#     [2.73398423e-159 1.39333161e-135 1.51685875e-113 ...
#      1.98821639e-032 8.52173314e-023 1.32104411e-015]
#     ...
#     [6.22081057e-043 2.06496206e-033 4.50797368e-025 ...
#      4.48962868e-004 1.25934349e-004 5.72129738e-007]
#     [2.54637659e-032 1.57409435e-024 7.12620480e-018 ...
#      1.90946344e-004 2.57278350e-006 6.63721731e-010]
#     [2.09877642e-024 3.95360398e-018 5.96696005e-013 ...
#      3.40845667e-006 3.12259373e-009 6.32562464e-014]]
#
#    [[4.47428422e-236 1.49995554e-202 2.47696389e-171 ...
#      3.37601459e-054 2.45279480e-039 1.49733567e-027]
#     [3.15345162e-184 9.52482991e-157 3.03377460e-131 ...
#      1.36375086e-037 2.03491760e-026 5.35060780e-018]
#     [1.07425320e-143 6.02110838e-121 5.98395749e-100 ...
#      3.15905530e-025 4.22038970e-017 1.74109848e-011]
#     ...
#     [1.77128966e-037 1.35276915e-028 5.99880378e-021 ...
#      2.83868707e-004 7.21115926e-006 2.58542615e-009]
#     [4.79752613e-028 7.27203943e-021 7.18146689e-015 ...
#      1.45404859e-005 1.98403092e-008 4.53947890e-013]
#     [3.76355754e-021 1.83100042e-015 6.39094172e-011 ...
#      4.06357483e-008 4.14441500e-012 8.22442525e-018]]
#
#    ...
#
#    [[3.86788638e-131 1.89179635e-105 1.64374963e-082 ...
#      2.00385763e-012 7.25549118e-008 1.36400243e-006]
#     [2.17874240e-100 1.85616920e-079 6.22758428e-061 ...
#      5.73845312e-008 6.37706988e-006 6.85868663e-007]
#     [3.17069201e-076 3.70024732e-059 3.03159388e-044 ...
#      1.28200619e-005 9.93139840e-006 1.23149363e-008]
#     ...
#     [8.79442499e-017 1.14448554e-011 4.44594983e-008 ...
#      3.69690806e-016 1.34586790e-023 3.57359294e-033]
#     [6.49376109e-013 2.51694113e-009 3.38977891e-007 ...
#      1.77992478e-021 6.42226402e-030 2.03914153e-040]
#     [7.40086488e-011 1.28682233e-008 8.84408560e-008 ...
#      1.41466105e-027 6.45002759e-037 3.05152512e-048]]
#
#    [[1.28690771e-113 1.08942840e-089 1.37588969e-068 ...
#      1.41556927e-008 3.73667883e-006 4.86676557e-007]
#     [1.87738760e-086 5.07891847e-067 4.51680235e-050 ...
#      5.53903957e-006 7.23972731e-006 8.44769219e-009]
#     [3.83092221e-065 2.17704862e-049 7.27423463e-036 ...
#      3.27792846e-005 4.36394229e-007 8.42398910e-012]
#     ...
#     [3.72779697e-014 6.45624833e-010 2.90446880e-007 ...
#      6.31215172e-021 1.18084043e-029 1.42758706e-040]
#     [2.55328133e-011 1.45305406e-008 2.51704142e-007 ...
#      6.30172208e-027 1.32994719e-036 2.19008422e-048]
#     [3.64793475e-010 1.01085168e-008 9.75809345e-009 ...
#      1.24317734e-033 3.70953775e-044 1.01973595e-056]]
#
#    [[2.30494103e-097 2.96636396e-075 4.84317186e-056 ...
#      2.90089147e-006 5.42204868e-006 4.82198856e-009]
#     [1.42666017e-073 1.07214995e-055 2.22940170e-040 ...
#      2.29073940e-005 3.33625020e-007 4.05671558e-012]
#     [5.73691433e-055 1.39387927e-040 1.67644348e-028 ...
#      4.87137297e-006 1.04042702e-009 2.95465323e-016]
#     ...
#     [4.22398151e-012 8.83169182e-009 4.17014175e-007 ...
#      1.47226100e-026 1.29964902e-036 6.60615714e-049]
#     [2.88402290e-010 2.19770289e-008 4.45980323e-008 ...
#      3.36112592e-033 3.81309476e-044 3.00709267e-057]
#     [5.48219474e-010 2.21847560e-009 2.75203967e-010 ...
#      1.79045797e-040 3.21720950e-052 4.74716127e-066]]]
#
#
#   [[[0.00000000e+000 6.76203588e-317 4.16859696e-272 ...
#      4.67343089e-100 1.43671202e-076 7.39597044e-057]
#     [2.71997113e-285 1.56646151e-246 2.19406553e-210 ...
#      1.23830041e-072 2.39192807e-054 2.44111424e-039]
#     [1.15200366e-224 9.17951758e-193 4.39312617e-163 ...
#      8.52917991e-052 1.15636961e-037 1.89060382e-026]
#     ...
#     [1.17576909e-066 2.20372295e-053 1.60441067e-041 ...
#      2.12422211e-006 7.94620930e-005 2.83650953e-005]
#     [1.48798510e-051 1.91084252e-040 1.12646693e-030 ...
#      8.77955999e-005 8.70148799e-005 1.02580452e-006]
#     [8.23425233e-040 1.39380670e-030 1.24307355e-022 ...
#      8.12831998e-005 3.29553184e-006 1.91772934e-009]]
#
#    [[0.00000000e+000 2.97643094e-285 1.27169525e-242 ...
#      2.42683702e-082 2.38509570e-061 3.67671409e-044]
#     [7.88811498e-259 1.14462575e-221 3.32247255e-187 ...
#      5.28888855e-059 8.11515969e-043 5.87809923e-030]
#     [1.99675933e-203 7.79654113e-173 1.51591809e-144 ...
#      2.34012316e-041 4.74750714e-029 1.01670178e-019]
#     ...
#     [6.90155677e-059 2.23877936e-046 2.47291108e-035 ...
#      3.38197788e-005 8.40773094e-005 1.74132386e-006]
#     [2.85367605e-045 7.02199828e-035 7.00942999e-026 ...
#      1.08699950e-004 8.30432792e-006 6.61400195e-009]
#     [8.38968918e-035 2.95339204e-026 4.87495616e-019 ...
#      1.08941761e-005 3.85565092e-008 1.72350360e-012]]
#
#    [[5.41242191e-299 3.46745900e-255 8.98034001e-215 ...
#      1.83670588e-066 5.50674478e-048 2.46404610e-033]
#     [1.73066530e-233 5.44900494e-198 2.83857782e-165 ...
#      7.04941712e-047 7.88879553e-033 3.77230466e-022]
#     [4.43358990e-183 7.37311508e-154 5.07354635e-127 ...
#      3.36036323e-032 9.22340325e-022 2.36280671e-014]
#     ...
#     [1.33770423e-051 6.85174209e-040 1.04491943e-029 ...
#      9.02866445e-005 1.35268447e-005 1.47686533e-008]
#     [1.94208487e-039 8.40757278e-030 1.30126674e-021 ...
#      2.52045322e-005 1.35079965e-007 6.62315040e-012]
#     [3.21202580e-030 2.17099565e-022 6.10611001e-016 ...
#      2.99737446e-007 8.45753173e-011 2.65419033e-016]]
#
#    ...
#
#    [[2.83818861e-162 5.77633255e-130 2.44184990e-101 ...
#      6.61085997e-015 4.12512004e-009 3.74767719e-007]
#     [2.65563050e-125 5.12355441e-099 7.15986251e-076 ...
#      1.13903842e-009 1.08467779e-006 3.29850717e-007]
#     [2.45199392e-096 7.52976848e-075 4.05459387e-056 ...
#      1.09572785e-006 4.09710087e-006 9.19470839e-009]
#     ...
#     [2.08325797e-023 2.47560861e-016 4.36615557e-011 ...
#      2.38933564e-015 7.01928129e-023 8.13317633e-033]
#     [5.65371132e-018 1.06826796e-012 3.72416230e-009 ...
#      1.89750913e-020 4.40373543e-029 5.07812607e-040]
#     [1.44311129e-014 7.14201601e-011 7.83554227e-009 ...
#      2.30478392e-026 5.53712760e-036 8.09146746e-048]]
#
#    [[4.66097627e-140 3.59817238e-110 5.28555153e-084 ...
#      3.75775464e-010 7.09603879e-007 2.02176780e-007]
#     [1.11069784e-107 2.14430798e-083 2.62401309e-062 ...
#      5.12508862e-007 2.71168813e-006 4.50584214e-009]
#     [2.70414455e-082 1.61598929e-062 1.45600911e-045 ...
#      8.40738387e-006 2.81931865e-007 5.39502952e-012]
#     ...
#     [1.24218240e-019 1.29743279e-013 1.74688039e-009 ...
#      3.28458256e-020 3.39758034e-029 1.24634703e-040]
#     [2.02061119e-015 3.87141589e-011 1.19521957e-008 ...
#      4.61292534e-026 4.42367771e-036 1.89126805e-048]
#     [4.47040230e-013 2.52560290e-010 2.77721617e-009 ...
#      1.21130495e-032 1.38105854e-043 8.58534280e-057]]
#
#    [[1.28205140e-119 3.52596339e-092 1.71742297e-068 ...
#      3.18309294e-007 1.89253130e-006 1.78003455e-009]
#     [1.72728818e-091 3.02036950e-069 2.96671491e-050 ...
#      5.65306549e-006 1.65464116e-007 1.51563242e-012]
#     [1.89137961e-069 1.96533764e-051 2.67200919e-036 ...
#      2.32775413e-006 6.77957009e-010 1.08524717e-016]
#     ...
#     [1.49710025e-016 1.24330013e-011 1.15701004e-008 ...
#      4.75125709e-026 1.60511310e-036 1.74165112e-049]
#     [1.62117073e-013 2.86250378e-010 7.11398154e-009 ...
#      1.33198741e-032 4.88929147e-044 7.22455887e-058]
#     [3.38835063e-012 1.99483262e-010 2.00632925e-010 ...
#      8.38990525e-040 4.20335175e-052 1.03489721e-066]]]]
#
#
#
#  [[[[6.83381273e-033 2.76461952e-030 7.75995657e-028 ...
#      4.08582079e-019 2.38139435e-018 5.09680144e-018]
#     [3.41088204e-025 2.89169061e-023 1.62629086e-021 ...
#      1.55202673e-016 1.47782094e-016 5.07615417e-017]
#     [8.72508215e-020 1.86529009e-018 2.54363645e-017 ...
#      1.22437051e-015 2.36006056e-016 1.61444361e-017]
#     ...
#     [1.25918660e-017 1.87729654e-018 1.55692638e-019 ...
#      1.04351237e-029 6.45030523e-033 1.33115183e-036]
#     [7.39244034e-021 5.36114600e-022 2.12216531e-023 ...
#      2.74893146e-035 7.41952278e-039 6.62850190e-043]
#     [5.33825706e-025 2.01084980e-026 4.06486305e-028 ...
#      1.46558347e-041 1.86607296e-045 7.80499339e-050]]
#
#    [[3.63352984e-031 1.25545130e-028 2.89449384e-026 ...
#      2.65608500e-018 8.99784895e-018 1.03390438e-017]
#     [6.05461851e-024 4.24092031e-022 1.89767024e-020 ...
#      2.78516949e-016 1.51853877e-016 2.77125157e-017]
#     [5.95037074e-019 1.02133737e-017 1.07801041e-016 ...
#      7.15189671e-016 7.78749808e-017 2.80276116e-018]
#     ...
#     [2.98408845e-018 3.24197368e-019 1.89526787e-020 ...
#      1.19927351e-031 3.98756589e-035 4.17323291e-039]
#     [1.08941655e-021 5.68311054e-023 1.56601578e-024 ...
#      1.82014763e-037 2.62502441e-041 1.18330642e-045]
#     [5.12360321e-026 1.37245464e-027 1.91006870e-029 ...
#      5.90858050e-044 3.99657015e-048 8.39752887e-053]]
#
#    [[1.77985065e-029 5.12552278e-027 9.44078430e-025 ...
#      1.23784739e-017 2.31008719e-017 1.34380408e-017]
#     [9.66661940e-023 5.46372792e-021 1.89411667e-019 ...
#      3.54380627e-016 1.05216308e-016 9.65618588e-018]
#     [3.57604679e-018 4.81640861e-017 3.83497293e-016 ...
#      2.93286158e-016 1.72041562e-017 3.09321107e-019]
#     ...
#     [5.82820055e-019 4.51868388e-020 1.81985815e-021 ...
#      9.34682589e-034 1.60825141e-037 8.18545531e-042]
#     [1.31177527e-022 4.82182267e-024 9.04276190e-026 ...
#      8.13621541e-040 6.03870273e-044 1.31884550e-048]
#     [3.98789236e-027 7.44298433e-029 6.97446547e-031 ...
#      1.60196288e-046 5.54950084e-051 5.63108638e-056]]
#
#    ...
#
#    [[7.78258789e-022 5.70365770e-020 2.04144605e-018 ...
#      4.37615132e-017 1.61028655e-018 1.11835833e-020]
#     [1.11395570e-017 1.39271701e-016 8.26368609e-016 ...
#      1.78270928e-018 1.04834070e-020 1.18902831e-023]
#     [2.33957205e-015 6.16592209e-015 7.51509831e-015 ...
#      4.80587433e-021 5.57336503e-024 1.26802585e-027]
#     ...
#     [5.37470683e-024 5.34281843e-026 2.23305438e-028 ...
#      2.91681114e-047 9.57041536e-053 6.46855034e-059]
#     [9.53857536e-029 4.24617900e-031 7.84023290e-034 ...
#      1.52099127e-054 2.13898985e-060 6.23425102e-067]
#     [2.94269034e-034 6.32456297e-037 5.57003735e-040 ...
#      2.38621090e-062 1.55806428e-068 2.12006404e-075]]
#
#    [[1.54797953e-020 7.70989502e-019 1.75336273e-017 ...
#      1.11498083e-017 1.50480168e-019 3.41441804e-022]
#     [6.37254532e-017 5.29827198e-016 1.96212563e-015 ...
#      1.23842041e-019 2.71266206e-022 1.02779292e-025]
#     [4.52287849e-015 7.77465946e-015 5.81913080e-015 ...
#      1.06945163e-022 4.67487233e-026 3.61667537e-030]
#     ...
#     [2.35873786e-025 1.42722549e-027 3.45290748e-030 ...
#      1.18149043e-050 1.50941230e-056 3.65584047e-063]
#     [2.46374736e-030 6.61288079e-033 7.01010445e-036 ...
#      3.51145898e-058 1.93030404e-064 2.02952308e-071]
#     [4.71842517e-036 6.06354583e-039 3.04379691e-042 ...
#      3.32486070e-066 8.51628821e-073 4.20548722e-080]]
#
#    [[2.42420703e-019 7.84075089e-018 1.07724887e-016 ...
#      1.45900305e-018 6.65477275e-021 4.52497038e-024]
#     [2.82594899e-016 1.49731501e-015 3.30156158e-015 ...
#      4.47644549e-021 3.38340938e-024 3.94950327e-028]
#     [6.68535166e-015 7.19971046e-015 3.16548259e-015 ...
#      1.25079348e-024 1.91792940e-028 4.67527883e-033]
#     ...
#     [7.54770991e-027 2.68930176e-029 3.63256104e-032 ...
#      2.58594032e-054 1.21543513e-060 9.93251564e-068]
#     [4.61115818e-032 7.22577069e-035 4.24611220e-038 ...
#      4.39535297e-062 8.94232518e-069 3.20035116e-076]
#     [5.45249535e-038 4.05983367e-041 1.12260772e-044 ...
#      2.51959473e-070 2.40135154e-077 4.06865630e-085]]]
#
#
#   [[[1.93699538e-039 1.46292234e-035 6.87697006e-032 ...
#      4.52772005e-018 1.46473883e-016 1.32813613e-015]
#     [2.88957026e-029 2.97313201e-026 1.82001591e-023 ...
#      2.67856011e-014 9.56977201e-014 9.54935874e-014]
#     [9.51421111e-022 1.70822192e-019 1.75420697e-017 ...
#      2.17244398e-012 1.12314196e-012 1.61452536e-013]
#     ...
#     [1.41532145e-012 5.10455993e-013 9.18283239e-014 ...
#      3.72146559e-023 1.97719709e-026 2.85508347e-030]
#     [7.15463175e-015 1.05830614e-015 7.66265141e-017 ...
#      2.62200464e-028 5.20535671e-032 2.79890129e-036]
#     [3.49107171e-018 2.30153310e-019 7.30367972e-021 ...
#      3.31256927e-034 2.69843728e-038 5.93573984e-043]]
#
#    [[6.78310011e-037 4.16126177e-033 1.50948236e-029 ...
#      1.01795177e-016 1.63677652e-015 6.68976865e-015]
#     [2.47717603e-027 2.00012541e-024 9.15112592e-022 ...
#      1.24442205e-013 2.19775230e-013 9.89357960e-014]
#     [2.41252332e-020 3.29941573e-018 2.46326773e-016 ...
#      2.57133489e-012 6.53317238e-013 4.23436481e-014]
#     ...
#     [5.30264424e-013 1.31777107e-013 1.56906558e-014 ...
#      3.87599293e-025 9.86854458e-029 6.37179023e-033]
#     [1.48843646e-015 1.49697475e-016 7.08498759e-018 ...
#      1.41439651e-030 1.34074732e-034 3.21890800e-039]
#     [4.27733011e-019 1.89493019e-020 3.88772328e-022 ...
#      9.89915225e-037 3.83835513e-041 3.76554273e-046]]
#
#    [[2.12504070e-034 1.02483451e-030 2.76493550e-027 ...
#      1.47913172e-015 1.10560132e-014 1.89459428e-014]
#     [1.85262762e-025 1.13804364e-022 3.75897316e-020 ...
#      3.72190538e-013 3.05369258e-013 5.79863439e-014]
#     [5.22361096e-019 5.28314544e-017 2.77454904e-015 ...
#      1.95109795e-012 2.29870933e-013 6.30818124e-015]
#     ...
#     [1.58206155e-013 2.64110769e-014 2.02438311e-015 ...
#      2.54298534e-027 2.96392458e-031 8.14559514e-036]
#     [2.44401058e-016 1.63020551e-017 4.90821411e-019 ...
#      4.79480785e-033 2.07637182e-037 2.12253492e-042]
#     [4.10445222e-020 1.19242420e-021 1.54012088e-023 ...
#      1.85537532e-039 3.28079242e-044 1.37092125e-049]]
#
#    ...
#
#    [[5.11939874e-023 4.05049892e-020 1.26701192e-017 ...
#      2.27259812e-013 1.16471400e-014 7.54517110e-017]
#     [2.50212023e-017 2.22407791e-015 7.67465155e-014 ...
#      2.29764119e-014 1.40031040e-016 1.13108130e-019]
#     [1.08509655e-013 1.42097244e-012 7.09933160e-012 ...
#      1.33588458e-016 1.24158189e-019 1.58969095e-023]
#     ...
#     [6.46483826e-018 9.46474102e-020 4.93471155e-022 ...
#      9.23826061e-042 9.93023236e-048 1.65730999e-054]
#     [4.47673733e-022 2.48396396e-024 4.85867663e-027 ...
#      6.47160880e-049 2.63176226e-055 1.68772168e-062]
#     [4.62116505e-027 1.06597419e-029 8.58979367e-033 ...
#      1.30557917e-056 2.20374199e-063 5.94838185e-071]]
#
#    [[4.74078660e-021 2.25721819e-018 3.90281307e-016 ...
#      7.79832304e-014 1.13893254e-015 1.84073554e-018]
#     [4.93043866e-016 2.59832578e-014 4.91059489e-013 ...
#      1.73297573e-015 3.11460875e-018 6.54677180e-022]
#     [5.60033139e-013 4.28772397e-012 1.16240056e-011 ...
#      2.68226028e-018 7.55615422e-022 2.60565224e-026]
#     ...
#     [3.28213787e-019 2.66372369e-021 7.25071855e-024 ...
#      1.80895793e-045 6.39467340e-052 3.19407570e-059]
#     [1.19747443e-023 3.65561821e-026 3.71203618e-029 ...
#      6.63980533e-053 8.97125084e-060 1.74529543e-067]
#     [6.95538671e-029 8.76879379e-032 3.64991766e-035 ...
#      7.50173722e-061 4.24573018e-068 3.51894158e-076]]
#
#    [[3.18655956e-019 8.61445284e-017 7.72500112e-015 ...
#      1.15197945e-014 4.36186686e-017 1.59447074e-020]
#     [6.97911681e-015 2.06633013e-013 2.01642808e-012 ...
#      5.78566135e-017 2.80728177e-020 1.40068662e-024]
#     [2.05630659e-012 8.75282513e-012 1.21866746e-011 ...
#      2.43727519e-020 1.91558949e-024 1.63158391e-029]
#     ...
#     [1.14371020e-020 4.94537656e-023 6.73199370e-026 ...
#      1.71061917e-049 1.86431306e-056 2.60395918e-064]
#     [2.18791123e-025 3.53651195e-028 1.78840855e-031 ...
#      3.31658478e-057 1.39920326e-064 7.73534906e-073]
#     [7.12082103e-031 4.72728818e-034 9.76321903e-038 ...
#      2.11369606e-065 3.77791891e-073 9.02722439e-082]]]
#
#
#   [[[1.59742350e-049 5.15156380e-044 8.91310205e-039 ...
#      1.81563917e-018 5.23529567e-016 3.03679936e-014]
#     [1.93412458e-036 4.93894443e-032 6.49551718e-028 ...
#      2.33051576e-013 4.68625256e-012 1.93155896e-011]
#     [1.82850938e-026 5.15134088e-023 7.21085688e-020 ...
#      2.53213417e-010 4.98557283e-010 2.04014542e-010]
#     ...
#     [2.96657943e-009 3.69351258e-009 2.01564551e-009 ...
#      1.86598266e-017 1.02878649e-020 1.22071955e-024]
#     [1.70921365e-010 7.12146311e-011 1.27841311e-011 ...
#      3.83714214e-022 6.63492329e-026 2.47903740e-030]
#     [7.18193799e-013 1.11218734e-013 7.30836870e-015 ...
#      1.23774879e-027 7.51138177e-032 9.88606790e-037]]
#
#    [[6.39217796e-046 1.55729092e-040 1.90456074e-035 ...
#      1.97616343e-016 2.32676479e-014 4.90050517e-013]
#     [1.27685807e-033 2.38341783e-029 2.15322696e-025 ...
#      3.71699583e-012 3.08243214e-011 4.69784905e-011]
#     [2.57087804e-024 5.14533109e-021 4.82505120e-018 ...
#      7.71461573e-010 6.30543353e-010 9.67012005e-011]
#     ...
#     [2.16250089e-009 1.73634300e-009 5.82357337e-010 ...
#      1.97907725e-019 4.58383116e-023 2.10894766e-027]
#     [6.04126377e-011 1.60259818e-011 1.74785671e-012 ...
#      1.86832194e-024 1.35847056e-028 1.97567642e-033]
#     [1.32617400e-013 1.29289243e-014 5.10963627e-016 ...
#      3.00114965e-030 7.66557253e-035 3.94071147e-040]]
#
#    [[2.18939152e-042 3.85899464e-037 3.17922476e-032 ...
#      1.21727943e-014 5.39457263e-013 3.78173213e-012]
#     [7.04233375e-031 9.23095461e-027 5.47879137e-023 ...
#      3.38148211e-011 1.07289123e-010 5.58032972e-011]
#     [2.95780134e-022 4.04981675e-019 2.44017881e-016 ...
#      1.34753622e-009 4.26418976e-010 2.27477970e-011]
#     ...
#     [1.20527670e-009 6.05308707e-010 1.20673771e-010 ...
#      1.21494316e-021 1.12080143e-025 1.88879742e-030]
#     [1.61862294e-011 2.65371632e-012 1.70237979e-013 ...
#      5.27008889e-027 1.53089376e-031 8.20498464e-037]
#     [1.84246849e-014 1.09850488e-015 2.53011808e-017 ...
#      4.21929066e-033 4.31733606e-038 8.22396963e-044]]
#
#    ...
#
#    [[3.19581777e-026 5.09530901e-022 2.44982622e-018 ...
#      2.36753357e-010 2.01924163e-011 1.37149106e-013]
#     [8.47973220e-019 9.20422129e-016 3.01282008e-013 ...
#      6.27252414e-011 4.61626536e-013 2.93278445e-016]
#     [1.10722341e-013 1.15661137e-011 3.63397597e-010 ...
#      8.21582337e-013 6.98485874e-016 5.47925298e-020]
#     ...
#     [5.33002575e-013 1.50438671e-014 1.24698633e-016 ...
#      7.32918291e-037 2.76721955e-043 1.18918860e-050]
#     [1.65349526e-016 1.45989923e-018 3.76853678e-021 ...
#      6.99316303e-044 8.75046647e-051 1.28095051e-058]
#     [6.43976214e-021 1.99135800e-023 1.79307560e-026 ...
#      1.83536488e-051 8.46581883e-059 4.68202683e-067]]
#
#    [[2.07752106e-023 1.69981572e-019 3.77637828e-016 ...
#      1.23154177e-010 2.23146166e-012 2.77718795e-015]
#     [8.14992615e-017 4.52856136e-014 6.88651079e-012 ...
#      5.66767339e-012 9.39785319e-015 1.17026378e-018]
#     [2.05462177e-012 1.09416831e-010 1.60081308e-009 ...
#      1.61614480e-014 3.24696846e-018 5.27623622e-023]
#     ...
#     [3.64533366e-014 5.11660627e-016 1.96561473e-018 ...
#      7.18721820e-041 7.41122306e-048 7.83340310e-056]
#     [5.24377115e-018 2.29289689e-020 2.73880187e-023 ...
#      3.28535950e-048 1.14342145e-055 4.20860739e-064]
#     [1.02644671e-022 1.56617599e-025 6.51619623e-029 ...
#      4.46000855e-056 5.81551224e-064 8.24730911e-073]]
#
#    [[8.79735013e-021 3.43501990e-017 3.26002935e-014 ...
#      2.24142355e-011 7.76309359e-014 1.58999808e-017]
#     [5.09808440e-015 1.35674228e-012 8.91894562e-011 ...
#      1.87844771e-013 6.35749812e-017 1.40253867e-021]
#     [2.47587074e-011 6.31974187e-010 4.02761492e-009 ...
#      1.21124313e-016 5.24098501e-021 1.60372199e-026]
#     ...
#     [1.59487961e-015 1.06229234e-017 1.79824936e-020 ...
#      3.00658633e-045 7.87918256e-053 1.90056020e-061]
#     [1.06125808e-019 2.19699119e-022 1.15685485e-025 ...
#      6.67705743e-053 6.03193035e-061 5.19472441e-070]
#     [1.04192636e-024 7.51105689e-028 1.37807227e-031 ...
#      4.74711542e-061 1.63712940e-069 5.55444216e-079]]]
#
#
#   ...
#
#
#   [[[1.12235564e-178 1.95405598e-155 1.78288060e-133 ...
#      4.08426139e-047 2.21596495e-035 9.06585026e-026]
#     [6.45227709e-139 1.36632317e-119 1.96510220e-101 ...
#      5.08705606e-032 3.36520445e-023 2.50518210e-016]
#     [2.07868878e-107 2.86988524e-091 3.24130237e-076 ...
#      8.36213681e-021 2.00409074e-014 7.36630920e-010]
#     ...
#     [3.30821750e-025 5.55862152e-019 1.20207661e-013 ...
#      6.63926575e-003 1.71789423e-004 1.62443573e-007]
#     [1.92519683e-018 1.71499889e-013 2.06024023e-009 ...
#      1.60350768e-004 3.60674686e-007 3.28261832e-011]
#     [7.88174574e-014 5.20738228e-010 4.82747540e-007 ...
#      2.38373457e-007 6.08615490e-011 6.87061320e-016]]
#
#    [[4.32922190e-163 1.44936812e-140 2.10202956e-119 ...
#      2.58787101e-038 6.92494925e-028 1.16171393e-019]
#     [3.00503335e-126 1.46043985e-107 4.07231753e-090 ...
#      2.02592587e-025 8.90319222e-018 3.69244418e-012]
#     [4.53806176e-097 1.62336347e-081 4.08246299e-067 ...
#      5.11229635e-016 1.01849181e-010 2.63386606e-007]
#     ...
#     [7.97349049e-022 4.53205275e-016 2.99216372e-011 ...
#      8.00528460e-004 3.11718779e-006 3.89859094e-010]
#     [6.42791564e-016 1.98443450e-011 7.49885487e-008 ...
#      3.58901005e-006 1.29704780e-009 1.67622962e-014]
#     [4.65572208e-012 1.08750070e-008 3.25114987e-006 ...
#      1.20844550e-009 5.24364490e-014 8.93538277e-020]]
#
#    [[5.59085555e-148 3.13623486e-126 6.27775072e-106 ...
#      2.02353796e-030 2.32877002e-021 1.40486469e-014]
#     [5.37384448e-114 5.31693495e-096 2.53921809e-079 ...
#      1.26519177e-019 3.24624239e-013 6.61395493e-009]
#     [4.16954253e-087 3.47564973e-072 1.74281321e-058 ...
#      5.85003762e-012 8.58374327e-008 1.38610970e-005]
#     ...
#     [9.81010600e-019 1.76134694e-013 3.30280528e-009 ...
#      2.83818230e-005 1.52031076e-008 2.29557588e-013]
#     [1.11404831e-013 1.11767610e-009 1.24132889e-006 ...
#      2.47815707e-008 1.32113123e-012 2.22221852e-018]
#     [1.44723620e-010 1.12472524e-007 1.01692269e-005 ...
#      1.96870302e-012 1.33814462e-017 3.16689942e-024]]
#
#    ...
#
#    [[3.75286819e-081 3.23519036e-064 3.69525339e-049 ...
#      4.19570131e-006 1.10607728e-004 7.09359236e-006]
#     [2.37310706e-060 1.22273365e-046 1.23253883e-034 ...
#      3.69549835e-004 1.04706560e-004 1.08670218e-007]
#     [3.84704948e-044 4.00518078e-033 1.09660157e-023 ...
#      6.13343882e-004 3.40631102e-006 9.70138572e-011]
#     ...
#     [1.99934030e-008 3.65921002e-006 3.89988358e-005 ...
#      1.69655920e-021 1.13013408e-029 1.10248317e-039]
#     [1.81349745e-007 2.28603863e-006 1.83420688e-006 ...
#      9.58938742e-028 9.56361205e-037 1.59734157e-047]
#     [5.91433166e-008 6.88374069e-008 5.50555152e-009 ...
#      1.14101989e-034 2.06747402e-044 7.06458392e-056]]
#
#    [[7.29774397e-070 4.43307678e-054 2.93717935e-040 ...
#      1.52838628e-004 8.68323113e-005 1.06332376e-007]
#     [1.95128562e-051 9.42943987e-039 7.42798770e-028 ...
#      4.89986753e-004 4.07266489e-006 1.08952955e-010]
#     [3.54700496e-037 4.27743009e-027 1.14388786e-018 ...
#      4.77187151e-005 9.97395491e-009 9.35870711e-015]
#     ...
#     [1.47619000e-007 5.33764002e-006 9.90849247e-006 ...
#      9.72338741e-027 5.14116765e-036 3.50710777e-047]
#     [2.23591293e-007 5.88830548e-007 8.75557698e-008 ...
#      1.52824394e-033 1.32557876e-043 1.70112076e-055]
#     [1.50674148e-008 3.84130738e-009 6.00226289e-011 ...
#      5.82696071e-041 9.94753330e-052 2.83718782e-064]]
#
#    [[2.23140937e-059 8.28115439e-045 2.77073913e-032 ...
#      3.69898030e-004 4.16111060e-006 9.05244206e-011]
#     [3.16879300e-043 1.25810003e-031 6.79668443e-022 ...
#      5.53369718e-005 1.23129252e-008 7.83068860e-015]
#     [7.62021954e-031 9.41778547e-022 2.17704910e-014 ...
#      3.85551601e-007 2.75960276e-012 7.83070818e-020]
#     ...
#     [3.80371041e-007 2.49121346e-006 7.36773934e-007 ...
#      1.03104469e-032 3.96013663e-043 1.73432768e-055]
#     [1.00214324e-007 5.07896177e-008 1.28608891e-009 ...
#      4.82678319e-040 3.34002699e-051 3.02857739e-064]
#     [1.44416416e-009 7.45975695e-011 2.10121048e-013 ...
#      6.26033801e-048 9.25738295e-060 2.03027732e-073]]]
#
#
#   [[[2.67203092e-229 6.01275305e-199 1.99562608e-170 ...
#      1.13752304e-059 1.00883188e-044 1.96998361e-032]
#     [1.96267758e-179 2.53737277e-154 8.05143166e-131 ...
#      1.54953238e-041 4.04189887e-030 4.20576872e-021]
#     [3.26227292e-140 2.89741093e-119 9.02266563e-100 ...
#      6.46142984e-028 2.01976060e-019 3.95704431e-013]
#     ...
#     [8.74627851e-037 2.64221262e-028 6.49872291e-021 ...
#      4.41884155e-003 6.40387663e-004 1.99673976e-006]
#     [1.34865725e-027 1.13026226e-020 8.39191199e-015 ...
#      6.89080168e-004 5.98904802e-006 1.28977313e-009]
#     [6.70193706e-021 2.39179167e-015 8.12109206e-011 ...
#      5.08800377e-006 3.63807683e-009 7.28361948e-014]]
#
#    [[1.04127767e-208 1.96831048e-179 4.44861074e-152 ...
#      1.78425739e-048 3.35214291e-035 1.17739519e-024]
#     [8.35781254e-163 1.30775935e-138 4.15997239e-116 ...
#      4.85879876e-033 4.21649903e-023 1.23722908e-015]
#     [1.15672902e-126 1.58934064e-106 6.45850077e-088 ...
#      1.29877847e-021 1.88591851e-014 1.45953553e-009]
#     ...
#     [4.64830561e-032 3.69617732e-024 2.13384440e-017 ...
#      1.62175482e-003 2.57941637e-005 7.72621507e-009]
#     [6.33812432e-024 1.46680267e-017 2.69972076e-012 ...
#      3.59159931e-005 3.75772884e-008 8.57143569e-013]
#     [3.81288794e-018 3.90874476e-013 3.44212697e-009 ...
#      4.77514471e-008 4.44722064e-012 1.02529837e-017]]
#
#    [[7.42432382e-189 1.00867735e-160 1.32892022e-134 ...
#      1.82446315e-038 6.42222478e-027 3.62547609e-018]
#     [8.68079560e-147 1.43318701e-123 3.97834374e-102 ...
#      1.43393804e-025 3.66052921e-017 2.69715816e-011]
#     [1.20770287e-113 2.27255327e-094 1.06414540e-076 ...
#      3.20657734e-016 1.91945560e-010 5.23240649e-007]
#     ...
#     [1.07388107e-027 2.07952018e-020 2.59826864e-014 ...
#      1.41380420e-004 2.24688382e-007 5.88539909e-012]
#     [1.33885708e-020 7.95606181e-015 3.36423142e-010 ...
#      4.76018482e-007 5.48174906e-011 1.21029694e-016]
#     [1.00195785e-015 2.75538532e-011 5.85803311e-008 ...
#      1.20710697e-010 1.34406996e-015 3.27267808e-022]]
#
#    ...
#
#    [[1.86492200e-102 4.85077920e-081 4.51056907e-062 ...
#      1.64282560e-007 2.92332749e-005 4.65605768e-006]
#     [1.78269942e-077 4.77377496e-060 8.39887244e-045 ...
#      5.88398181e-005 6.56502747e-005 1.10373791e-007]
#     [6.57002481e-058 9.00043566e-044 1.27714974e-031 ...
#      3.10211451e-004 4.32098295e-006 1.38923915e-010]
#     ...
#     [3.60801205e-012 1.70510820e-008 2.75937811e-006 ...
#      2.81990493e-020 1.10004202e-028 3.70466961e-039]
#     [5.44141930e-010 1.11117473e-007 8.85859704e-007 ...
#      2.39870684e-026 1.15875984e-035 5.71270483e-047]
#     [2.05026007e-009 2.57822961e-008 1.41617787e-008 ...
#      4.03589135e-033 2.99473790e-043 2.62888041e-055]]
#
#    [[4.21291039e-088 3.20196585e-068 7.26036421e-051 ...
#      2.38109426e-005 4.65697196e-005 7.55536505e-008]
#     [4.37630469e-066 5.39482137e-050 3.65487988e-036 ...
#      2.05449615e-004 3.74025617e-006 9.32037537e-011]
#     [6.40456990e-049 5.62115062e-036 4.30314966e-025 ...
#      4.52482726e-005 1.41303927e-008 9.14142837e-015]
#     ...
#     [1.65647076e-010 1.13598611e-007 2.33482178e-006 ...
#      1.05742419e-025 2.37519705e-035 4.08417103e-047]
#     [3.03202479e-009 9.77030040e-008 1.08242273e-007 ...
#      2.19322004e-032 6.84067448e-043 1.93314843e-055]
#     [1.79578626e-009 3.82424935e-009 3.15031609e-010 ...
#      1.05425980e-039 5.58183560e-051 3.10889075e-064]]
#
#    [[7.78598763e-075 1.51231498e-056 7.38034283e-041 ...
#      1.39090633e-004 2.84472479e-006 4.53587732e-011]
#     [1.26607034e-055 6.30129107e-041 1.45007536e-028 ...
#      3.97961336e-005 1.10630612e-008 3.87237755e-015]
#     [9.54526941e-041 4.73635998e-029 1.73205818e-019 ...
#      4.71844158e-007 3.06191619e-012 3.73504502e-020]
#     ...
#     [2.16193723e-009 1.96062992e-007 4.65832346e-007 ...
#      5.89153642e-032 7.00309172e-043 5.67814484e-056]
#     [5.10576293e-009 2.37748063e-008 3.34681727e-009 ...
#      3.24768161e-039 6.01761489e-051 9.00579313e-065]
#     [5.00270378e-010 1.65938154e-010 1.88229522e-012 ...
#      4.80583627e-047 1.67282897e-059 5.46556076e-074]]]
#
#
#   [[[6.84358711e-294 4.56065396e-254 6.29640277e-217 ...
#      2.89733026e-075 2.10966827e-056 6.99936340e-041]
#     [1.46243498e-230 6.15535789e-198 1.41698905e-167 ...
#      1.59286446e-053 5.68225979e-039 2.21229887e-027]
#     [2.00962323e-181 2.43832611e-154 3.10776874e-129 ...
#      4.20437563e-037 4.61245995e-026 1.05792463e-017]
#     ...
#     [4.62204527e-052 8.29285779e-041 6.74112580e-031 ...
#      2.05346708e-004 2.52539825e-004 3.61690432e-006]
#     [4.98718471e-040 1.10763321e-030 1.28220803e-022 ...
#      2.52517888e-004 1.21728134e-005 8.27373616e-009]
#     [6.65446124e-031 3.17511570e-023 8.87792669e-017 ...
#      1.09147806e-005 3.00039050e-008 1.37089632e-012]]
#
#    [[1.71860604e-266 2.51514468e-228 6.25652544e-193 ...
#      4.05032154e-061 2.05668487e-044 4.27472041e-031]
#     [1.07876091e-208 2.05694125e-177 1.77293145e-148 ...
#      1.02807526e-042 5.03407634e-030 2.35923869e-020]
#     [1.04049092e-163 9.12556071e-138 7.03566383e-114 ...
#      5.86041937e-029 1.43988046e-019 6.42394788e-013]
#     ...
#     [1.16395893e-045 3.96067726e-035 5.38973096e-026 ...
#      3.03785962e-004 2.83088436e-005 2.69093979e-008]
#     [6.31748966e-035 2.89363133e-026 6.14200330e-019 ...
#      3.89335499e-005 1.61508529e-007 8.30808885e-012]
#     [6.36761809e-027 6.70951910e-020 3.70687227e-014 ...
#      2.32861041e-007 6.13535967e-011 2.37247277e-016]]
#
#    [[2.88382384e-240 7.96182390e-204 3.08591556e-170 ...
#      1.56848820e-048 5.12392340e-034 6.24028270e-023]
#     [9.50115925e-188 7.11286438e-158 1.99481433e-130 ...
#      3.21144899e-033 1.95451410e-022 1.00910814e-014]
#     [9.25710118e-147 5.14718705e-122 2.10636684e-099 ...
#      5.86727871e-022 2.90453816e-014 2.28587569e-009]
#     ...
#     [1.03040309e-039 6.09978637e-030 1.27124652e-021 ...
#      8.28972151e-005 5.32410062e-007 3.05937458e-011]
#     [2.98402179e-030 2.60034215e-022 9.31040368e-016 ...
#      1.21679127e-006 3.96514041e-010 1.41024789e-015]
#     [2.38271055e-023 5.13984638e-017 5.18689307e-012 ...
#      1.08995294e-009 2.52128312e-014 7.56043031e-021]]
#
#    ...
#
#    [[1.71390898e-128 1.43625311e-101 7.46466809e-078 ...
#      1.04912843e-009 1.71005555e-006 8.06848550e-007]
#     [1.66582005e-098 1.49324523e-076 2.11686723e-057 ...
#      1.68663433e-006 9.54448637e-006 3.00677043e-008]
#     [5.52725287e-075 4.50575585e-057 1.15402560e-041 ...
#      3.04547375e-005 1.31623568e-006 5.39555299e-011]
#     ...
#     [9.44670837e-018 2.27697520e-012 9.92140967e-009 ...
#      1.10629719e-019 2.80300858e-028 3.44928543e-039]
#     [3.33989776e-014 2.01278687e-010 2.64354761e-008 ...
#      1.44484111e-025 3.70496747e-035 5.66637478e-047]
#     [1.93872232e-012 4.48626645e-010 2.65293624e-009 ...
#      3.49494257e-032 1.15208230e-042 2.71439696e-055]]
#
#    [[2.56138659e-110 1.87831218e-085 7.51272516e-064 ...
#      7.51958500e-007 6.25219995e-006 1.49195017e-008]
#     [4.59684881e-084 7.34472377e-064 1.59784795e-046 ...
#      1.84552773e-005 8.77837440e-007 2.22134725e-011]
#     [1.61734588e-063 3.90052627e-047 2.52821773e-033 ...
#      9.58971820e-006 5.19472012e-009 2.49025250e-015]
#     ...
#     [4.08606249e-015 9.82493094e-011 3.72677864e-008 ...
#      2.86944092e-025 2.94850233e-035 1.32081418e-047]
#     [1.20296973e-012 8.16468336e-010 1.05958267e-008 ...
# ...
#      3.28235412e-028 9.80301113e-033 6.27130448e-038]
#     ...
#     [3.49114638e-039 8.01274372e-042 7.29737035e-045 ...
#      3.06583075e-067 2.07175582e-073 3.04725833e-080]
#     [1.00981553e-046 1.34751325e-049 7.08419252e-053 ...
#      1.78865732e-076 6.87200299e-083 5.76666901e-090]
#     [8.99527766e-055 7.29903830e-058 2.31887774e-061 ...
#      4.47138652e-086 1.02604185e-092 5.16098968e-100]]
#
#    [[5.45362390e-007 2.16280918e-007 3.53892934e-008 ...
#      2.77264528e-019 2.91547576e-023 6.01853166e-028]
#     [4.08305317e-009 5.55802003e-010 3.07062793e-011 ...
#      9.04641069e-025 3.08926333e-029 2.08437319e-034]
#     [2.41535311e-012 1.25472634e-013 2.60737759e-015 ...
#      5.05352088e-031 6.27620810e-036 1.54908849e-041]
#     ...
#     [4.23584633e-041 5.82738781e-044 3.05124786e-047 ...
#      3.86123329e-071 1.09157940e-077 6.29101597e-085]
#     [8.66593067e-049 6.89741431e-052 2.07585693e-055 ...
#      1.56544472e-080 2.52037886e-087 8.31267595e-095]
#     [5.62977324e-057 2.71320279e-060 4.91658806e-064 ...
#      2.81398911e-090 2.71094833e-097 5.37628082e-105]]
#
#    [[2.01531436e-007 4.94817790e-008 4.76252502e-009 ...
#      1.04448737e-021 4.32056777e-026 3.22539747e-031]
#     [7.34278090e-010 6.11242085e-011 1.96493068e-012 ...
#      1.58212198e-027 2.13173114e-032 5.23323791e-038]
#     [2.28341501e-013 7.17648571e-015 8.59601296e-017 ...
#      4.46068926e-034 2.19179079e-039 1.97915653e-045]
#     ...
#     [3.74212999e-043 3.00494238e-046 8.79095545e-050 ...
#      2.80575838e-075 3.17831698e-082 6.85583284e-090]
#     [5.39952663e-051 2.49716614e-054 4.18308913e-058 ...
#      7.91744626e-085 5.12136603e-092 6.34830910e-100]
#     [2.55212711e-059 7.11932302e-063 7.15756128e-067 ...
#      1.02512533e-094 3.97866779e-102 2.97766537e-110]]
#
#    ...
#
#    [[9.90740682e-012 1.29052422e-013 4.86694932e-016 ...
#      4.49805770e-038 7.08992108e-045 1.25411569e-052]
#     [8.85409811e-016 3.74228007e-018 4.55716462e-021 ...
#      1.58712580e-045 8.58728425e-053 5.35995089e-061]
#     [1.00878554e-020 1.54938193e-023 6.82663301e-027 ...
#      1.57007309e-053 3.24550499e-061 7.93240448e-070]
#     ...
#     [8.85634290e-056 3.06783448e-060 3.00828696e-065 ...
#      4.95093972e-100 2.82822507e-109 2.09916776e-119]
#     [2.16056437e-064 4.24785935e-069 2.36149504e-074 ...
#      2.40041866e-110 8.07132965e-120 3.57971383e-130]
#     [2.02983483e-073 2.37855872e-078 7.87546374e-084 ...
#      6.33310300e-121 1.31562927e-130 3.65653543e-141]]
#
#    [[4.22936202e-013 2.70398817e-015 4.66259261e-018 ...
#      2.48803040e-042 1.05388949e-049 4.51039458e-058]
#     [1.77390061e-017 3.66454192e-020 2.03714125e-023 ...
#      4.26251887e-050 6.31573615e-058 9.75754677e-067]
#     [1.03005601e-022 7.70411244e-026 1.54743543e-029 ...
#      2.21458007e-058 1.27472788e-066 7.86908851e-076]
#     ...
#     [7.68768326e-059 1.28263764e-063 5.71764422e-069 ...
#      6.71806773e-106 1.13799958e-115 2.30167718e-126]
#     [1.30978612e-067 1.23919442e-072 3.13260340e-078 ...
#      2.32760301e-116 2.34400828e-126 2.86684520e-137]
#     [8.88551173e-077 5.00763625e-082 7.54360769e-088 ...
#      4.53738000e-127 2.84965055e-137 2.20866466e-148]]
#
#    [[1.14115012e-014 3.41496363e-017 2.55821034e-020 ...
#      5.77434813e-047 6.11330916e-055 5.87119450e-064]
#     [2.24128786e-019 2.16222341e-022 5.22461129e-026 ...
#      4.87554066e-055 1.84542833e-063 6.56496864e-073]
#     [6.62049720e-025 2.30772647e-028 2.01567103e-032 ...
#      1.34797072e-063 2.02080326e-072 2.93891007e-082]
#     ...
#     [4.18216441e-062 3.23502508e-067 6.29376408e-073 ...
#      4.13188160e-112 1.96012224e-122 1.01775119e-133]
#     [4.97614830e-071 2.18255162e-076 2.41086503e-082 ...
#      1.03092009e-122 2.94072318e-133 9.35772965e-145]
#     [2.43815960e-080 6.37136763e-086 4.19971800e-092 ...
#      1.49568486e-133 2.68936689e-144 5.49171338e-156]]]
#
#
#   ...
#
#
#   [[[7.84837492e-036 2.94155725e-030 1.44276117e-025 ...
#      6.12980735e-018 3.96606842e-020 9.52072432e-024]
#     [8.33767984e-030 1.79365145e-025 5.26702581e-022 ...
#      4.32800639e-020 2.56974539e-023 6.25427960e-028]
#     [5.89498053e-026 1.02101917e-022 2.50211473e-020 ...
#      1.83348251e-023 1.31143643e-027 4.19204917e-033]
#     ...
#     [2.62797867e-030 5.17968600e-031 1.63596676e-032 ...
#      6.65153003e-054 2.20909890e-061 4.44916471e-070]
#     [1.22336779e-034 6.45040759e-036 5.55110521e-038 ...
#      5.05931370e-062 5.51787622e-070 3.81568372e-079]
#     [7.93538596e-040 1.26146175e-041 3.32920437e-044 ...
#      1.19054608e-070 4.72814016e-079 1.24028842e-088]]
#
#    [[8.50668941e-033 1.07796890e-027 1.61251912e-023 ...
#      3.26848819e-019 3.16557544e-022 9.99007449e-027]
#     [1.26946393e-027 9.44169597e-024 8.69808554e-021 ...
#      4.31222425e-022 4.09279594e-026 1.40665722e-031]
#     [1.62414611e-024 9.90600705e-022 7.79655496e-020 ...
#      4.20180725e-026 5.08091351e-031 2.43834001e-037]
#     ...
#     [1.82804818e-031 1.34740967e-032 1.47641410e-034 ...
#      8.57337836e-059 5.82493599e-067 2.17254603e-076]
#     [3.66602840e-036 7.29088994e-038 2.20063234e-040 ...
#      3.14473528e-067 7.20789637e-076 9.50925783e-086]
#     [1.11303031e-041 6.72702021e-044 6.28969404e-047 ...
#      3.84051077e-076 3.28505057e-085 1.68925350e-095]]
#
#    [[4.66045255e-030 1.86299571e-025 7.89993727e-022 ...
#      5.04010525e-021 6.67308357e-025 2.52500578e-030]
#     [9.93288235e-026 2.39357228e-022 6.45941443e-020 ...
#      1.30593052e-024 1.81791502e-029 8.08291165e-036]
#     [2.33092908e-023 4.70919493e-021 1.11583567e-019 ...
#      3.05247744e-029 5.74910895e-035 3.80971445e-042]
#     ...
#     [6.91987128e-033 1.81625078e-034 6.55608344e-037 ...
#      4.03025136e-064 5.23732018e-073 3.37546807e-083]
#     [6.01544189e-038 4.30381403e-040 4.33384075e-043 ...
#      7.26894848e-073 3.28055583e-082 7.72090465e-093]
#     [8.59748644e-044 1.88703320e-046 5.95498492e-050 ...
#      4.68914587e-082 8.10947710e-092 7.65845738e-103]]
#
#    ...
#
#    [[1.38374187e-021 5.52242806e-020 1.29914250e-019 ...
#      3.54392992e-039 5.60564938e-048 1.31654688e-058]
#     [2.53735800e-021 7.49215375e-021 1.42177166e-021 ...
#      6.41592217e-046 1.61449737e-055 6.89406275e-067]
#     [1.67749724e-022 4.92811808e-023 1.00204078e-024 ...
#      2.49929392e-053 1.21594194e-063 1.12914500e-075]
#     ...
#     [1.70497664e-044 1.14346785e-048 6.85452052e-054 ...
#      4.54620019e-098 5.25901692e-111 1.77969677e-125]
#     [2.60013597e-051 5.14104243e-056 9.42444872e-062 ...
#      3.33677673e-108 1.59915643e-121 2.38859596e-136]
#     [9.73562006e-059 6.34339660e-064 3.96257482e-070 ...
#      1.21350110e-118 2.61736957e-132 1.86493171e-147]]
#
#    [[4.19514581e-021 3.28442169e-020 1.33548244e-020 ...
#      7.86912857e-045 9.80041258e-055 1.59809227e-066]
#     [1.30754317e-021 8.00896246e-022 2.79586840e-023 ...
#      4.05452769e-052 8.81519485e-063 2.87583265e-075]
#     [1.83133953e-023 1.16980013e-024 4.61245472e-027 ...
#      5.19951603e-060 2.36958405e-071 1.82783517e-084]
#     ...
#     [7.82961153e-048 1.33471868e-052 1.85087613e-058 ...
#      1.79050137e-106 2.58022336e-120 9.77246149e-136]
#     [5.51915932e-055 2.83443342e-060 1.23185204e-066 ...
#      7.50828888e-117 4.67086128e-131 8.15439863e-147]
#     [1.03151825e-062 1.78037480e-068 2.69608716e-075 ...
#      1.65281850e-127 4.80458429e-142 4.16319721e-158]]
#
#    [[4.36254945e-021 6.13753177e-021 3.94232343e-022 ...
#      3.16912639e-051 2.84618160e-062 2.96175511e-075]
#     [2.41121095e-022 2.82049197e-023 1.66349435e-025 ...
#      4.99164264e-059 8.60699138e-071 1.97482697e-084]
#     [7.41224812e-025 9.51877408e-027 6.71297328e-030 ...
#      2.24148411e-067 8.80332897e-080 5.20146243e-094]
#     ...
#     [1.49623988e-051 6.08600382e-057 1.82824010e-063 ...
#      1.80945485e-115 3.01903315e-130 1.19005783e-146]
#     [4.95265897e-059 6.21478185e-065 6.00921939e-072 ...
#      4.46847225e-126 3.35939190e-141 6.38411688e-158]
#     [4.68690026e-067 2.01966841e-073 6.97148948e-081 ...
#      6.12033586e-137 2.23594128e-152 2.19748636e-169]]]
#
#
#   [[[7.40556124e-050 3.97113209e-042 1.78659532e-035 ...
#      3.81662183e-021 1.19368336e-022 8.23114789e-026]
#     [1.94733535e-041 3.16544039e-035 4.66957396e-030 ...
#      1.69328859e-022 3.36293845e-025 1.69179130e-029]
#     [1.51611572e-035 1.15280751e-030 8.49863066e-027 ...
#      3.42845883e-025 5.97559909e-029 2.97308003e-034]
#     ...
#     [4.22854359e-033 5.96678426e-033 1.01890387e-033 ...
#      2.03894483e-053 5.61253437e-061 6.67896376e-070]
#     [1.58921267e-036 4.69141081e-037 1.72912737e-038 ...
#      2.97768922e-061 2.32170939e-069 8.30516432e-079]
#     [6.58312451e-041 4.70194467e-042 4.31432775e-044 ...
#      1.23717118e-069 3.07702409e-078 3.70690414e-088]]
#
#    [[1.59802525e-045 2.26489129e-038 2.39950186e-032 ...
#      5.73380447e-022 1.96218208e-024 1.29469344e-028]
#     [3.75342525e-038 1.68803192e-032 6.18153700e-028 ...
#      3.62374289e-024 8.64338901e-028 4.59248888e-033]
#     [3.61903139e-033 7.90382409e-029 1.51069001e-025 ...
#      1.34051042e-027 3.03620814e-032 1.73517979e-038]
#     ...
#     [7.52625470e-034 3.43346587e-034 1.74590797e-035 ...
#      2.10232305e-058 9.78624902e-067 1.77473926e-076]
#     [1.03976391e-037 1.00821745e-038 1.12735502e-040 ...
#      1.33972893e-066 1.83190860e-075 1.03865570e-085]
#     [1.75199424e-042 4.16988125e-044 1.18048460e-046 ...
#      2.64403892e-075 1.19185680e-084 2.35823833e-095]]
#
#    [[1.48381594e-041 5.13689517e-035 1.18028110e-029 ...
#      2.00865536e-023 6.84087387e-027 3.92847410e-032]
#     [3.21947794e-035 3.72200304e-030 3.13315519e-026 ...
#      1.94110397e-026 5.08079141e-031 2.60417046e-037]
#     [3.95049598e-031 2.31293025e-027 1.06628622e-024 ...
#      1.39212750e-030 3.75948688e-036 2.26267344e-043]
#     ...
#     [6.66406918e-035 9.31064654e-036 1.33182672e-037 ...
#      6.98865564e-064 5.12487244e-073 1.31747558e-083]
#     [3.42199836e-039 1.03451120e-040 3.32201639e-043 ...
#      1.99494642e-072 4.46633888e-082 3.74162299e-093]
#     [2.36908014e-044 1.78655856e-046 1.47989339e-049 ...
#      1.91482173e-081 1.46350423e-091 4.44235845e-103]]
#
#    ...
#
#    [[4.29769491e-028 3.62161892e-025 1.06976204e-023 ...
#      3.09568446e-041 2.51921632e-050 1.81181023e-061]
#     [1.20336721e-026 4.74876092e-025 7.46543958e-025 ...
#      8.16163523e-048 8.79421015e-058 9.89088362e-070]
#     [8.39285544e-027 2.22043096e-026 2.60988589e-027 ...
#      4.35329634e-055 7.71693838e-066 1.65274544e-078]
#     ...
#     [2.62245242e-045 4.07963617e-049 4.08293589e-054 ...
#      2.00891302e-099 4.77583401e-113 2.32438192e-128]
#     [1.18921602e-051 4.51853994e-056 1.16340792e-061 ...
#      1.62450381e-109 1.47563736e-123 2.96555525e-139]
#     [1.17393644e-058 1.24112883e-063 9.32152272e-070 ...
#      6.37495724e-120 2.42322788e-134 2.18815645e-150]]
#
#    [[7.26865673e-027 8.85390402e-025 3.30606267e-024 ...
#      4.12228177e-047 1.92298848e-057 7.03876178e-070]
#     [2.51460645e-026 1.56014963e-025 3.39454155e-026 ...
#      2.71889662e-054 1.88631366e-065 1.21420727e-078]
#     [2.83313765e-027 1.26431850e-027 2.21960702e-029 ...
#      4.26911842e-062 5.38965936e-074 7.31869429e-088]
#     ...
#     [1.51952541e-048 5.01464297e-053 9.63161880e-059 ...
#      2.54549624e-108 6.13339052e-123 2.71945766e-139]
#     [2.82725624e-055 2.35056603e-060 1.20177202e-066 ...
#      1.11682786e-118 1.08138559e-133 2.08613899e-150]
#     [1.25323719e-062 2.98124719e-068 4.58499637e-075 ...
#      2.53402241e-129 1.07495781e-144 9.77301356e-162]]
#
#    [[3.43012193e-026 5.49873814e-025 2.36066820e-025 ...
#      7.99534284e-054 1.96732110e-065 3.39030705e-079]
#     [1.56226806e-026 1.39468524e-026 3.83830017e-028 ...
#      1.44275805e-061 5.93638809e-074 2.02341632e-088]
#     [2.99706954e-028 2.07419329e-029 4.99231479e-032 ...
#      7.20255235e-070 5.97289368e-083 4.76075034e-098]
#     ...
#     [3.26413033e-052 2.13556506e-057 7.34154085e-064 ...
#      7.22699155e-118 1.64048691e-133 6.16848908e-151]
#     [2.54805601e-059 4.34197812e-065 4.12060217e-072 ...
#      1.78528821e-128 1.71524199e-144 2.96037067e-162]
#     [5.17427444e-067 2.59966315e-073 7.66910152e-081 ...
#      2.42196067e-139 1.06883721e-155 9.12919157e-174]]]
#
#
#   [[[1.65059179e-067 4.06864941e-057 4.76371136e-048 ...
#      1.72514630e-025 3.91626277e-026 1.07249918e-028]
#     [2.87313546e-056 9.65860233e-048 1.76075297e-040 ...
#      5.89562970e-026 5.56574787e-028 7.65540681e-032]
#     [5.45044097e-048 4.37814786e-041 2.12954272e-035 ...
#      6.72832371e-028 3.88284348e-031 3.83647027e-036]
#     ...
#     [1.00531321e-037 1.67215711e-036 2.41134892e-036 ...
#      1.06773551e-053 2.89130883e-061 2.32608819e-070]
#     [4.04862645e-040 1.05272142e-039 2.49179604e-040 ...
#      3.17066976e-061 2.06345038e-069 4.31134287e-079]
#     [1.36915074e-043 6.64445937e-044 3.06765835e-045 ...
#      2.44347809e-069 4.38038818e-078 2.70505407e-088]]
#
#    [[1.51459257e-061 7.15083455e-052 1.41340438e-043 ...
#      9.64907171e-026 1.65873349e-027 3.00971079e-031]
#     [1.32929602e-051 9.28506023e-044 3.12408485e-037 ...
#      3.42859277e-027 2.78785330e-030 2.90268952e-035]
#     [1.94565093e-044 3.46896065e-038 3.34916175e-033 ...
#      5.48391525e-030 3.03714686e-034 2.54204262e-040]
#     ...
#     [6.05858918e-038 2.73883508e-037 9.82042669e-038 ...
#      9.72284240e-059 3.60240900e-067 3.56326985e-077]
#     [7.42438349e-041 5.38515604e-041 3.26321899e-042 ...
#      1.12661904e-066 1.05249648e-075 2.84461785e-086]
#     [8.64796125e-045 1.19828470e-045 1.45370449e-047 ...
#      3.73664002e-075 1.00397757e-084 8.39552145e-096]]
#
#    [[4.83205962e-056 4.00221112e-047 1.21983401e-039 ...
#      9.74660454e-027 1.15293569e-029 1.26152932e-034]
#     [2.27029003e-047 3.03645348e-040 1.73285103e-034 ...
#      3.97330160e-029 2.53850396e-033 1.82695900e-039]
#     [2.68981801e-041 9.86082074e-036 1.74560251e-031 ...
#      9.66563646e-033 4.70380690e-038 3.05505015e-045]
#     ...
#     [1.63183741e-038 1.88947201e-038 1.58343383e-039 ...
#      2.48700724e-064 1.17135063e-073 1.32237177e-084]
#     [6.19519221e-042 1.18405290e-042 1.73062505e-044 ...
#      1.16401238e-072 1.45348801e-082 4.72716785e-094]
#     [2.52554073e-046 9.45740817e-048 2.84646006e-050 ...
#      1.71365614e-081 6.43877714e-092 6.79569442e-104]]
#
#    ...
#
#    [[2.16755948e-036 7.45494579e-032 4.81121925e-029 ...
#      6.45929315e-044 2.98050826e-053 6.91543710e-065]
#     [1.29992651e-033 1.22288361e-030 2.59256328e-029 ...
#      2.52601051e-050 1.26975808e-060 3.93653628e-073]
#     [1.26637447e-032 5.03699089e-031 5.27237111e-031 ...
#      1.87275730e-057 1.30515011e-068 6.70944986e-082]
#     ...
#     [2.93786837e-047 1.44059279e-050 3.12040050e-055 ...
#      2.29216694e-101 1.17145546e-115 8.38654971e-132]
#     [4.43068327e-053 4.28356068e-057 1.96463221e-062 ...
#      2.05270127e-111 3.68225786e-126 1.01615514e-142]
#     [1.27237153e-059 2.82494149e-064 3.17353614e-070 ...
#      8.73042163e-122 6.07243214e-137 7.07885446e-154]]
#
#    [[3.06793529e-034 1.05268922e-030 5.90891067e-029 ...
#      5.42798935e-050 1.01572408e-060 8.59271866e-074]
#     [1.55855335e-032 1.65249357e-030 3.46244551e-030 ...
#      4.62770083e-057 1.08855946e-068 1.41802553e-082]
#     [1.78382402e-032 8.84988361e-032 1.01872130e-032 ...
#      8.96734828e-065 3.31006375e-077 8.08978630e-092]
#     ...
#     [2.51853877e-050 2.13086406e-054 7.17128273e-060 ...
#      9.47237345e-111 3.94208746e-126 2.07165424e-143]
#     [1.36032972e-056 2.36865684e-061 1.76751319e-067 ...
#      4.35955136e-121 6.76811134e-137 1.45902672e-154]
#     [1.55527316e-063 6.46239629e-069 1.23097308e-075 ...
#      1.02177800e-131 6.50017954e-148 6.26407808e-166]]
#
#    [[9.41435341e-033 2.92436815e-030 1.29618514e-029 ...
#      5.22573535e-057 3.68137849e-069 1.06144796e-083]
#     [4.44197955e-032 4.83985145e-031 9.13750697e-032 ...
#      1.08460871e-064 1.10736038e-077 5.65582596e-093]
#     [6.44273128e-033 3.65111831e-033 4.23056996e-035 ...
#      6.03845852e-073 1.09488342e-086 1.18597685e-102]
#     ...
#     [7.01479201e-054 9.53431627e-059 4.63468196e-065 ...
#      7.59546793e-121 2.39660244e-137 8.62982697e-156]
#     [1.39913704e-060 4.09510810e-066 4.63284929e-073 ...
#      1.87860077e-131 2.35262592e-148 3.70084169e-167]
#     [6.54450778e-068 4.76032076e-074 1.43576485e-081 ...
#      2.52616982e-142 1.37150898e-159 1.02141968e-178]]]]]

# %%
# marginliks = np.zeros((n,n))

# for i, om in enumerate(oms):
#     for j, ol in enumerate(ols):
#         marginliks[i,j] = np.sum([np.sum([np.sum(likelihood[i,j,k,l,:]) for l, orr in enumerate(orrs)]) for k, wa in enumerate(was)])

marginliks_test = np.zeros((n,n))

for i, om in enumerate(oms):
    for j, ol in enumerate(ols):
          marginliks_test[i,j] = np.sum(likelihood[i,j,:])

# %%
# marginchi2=-2*np.log(marginliks)
# print(marginchi2-np.amin(marginchi2))

marginchi2_test = -2*np.log(marginliks_test)

# %%
# plt.contour(oms, ols, np.transpose(marginchi2 - np.amin(marginchi2)),cmap="winter", **{'levels':[2.3,6.18,11.83]}) #
# # 5.89,11.31,18.21
# # 2.3,6.18,11.83
# plt.plot(oms[ibest[0]], ols[ibest[1]],'x',color='black',label='(om,ol)=(%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]]) )
# plt.xlabel("$\Omega_m$", fontsize=12)
# plt.xlim(min(oms),max(oms))
# # plt.xlim(0,1)
# plt.ylabel("$\Omega_\Lambda$", fontsize=12)
# plt.ylim(min(ols),max(ols))
# # plt.ylim(0,1)
# # plt.plot([oms[0],oms[1]], [ols[0],ols[1]],'-',color='black',label='Step size indicator' ) # Delete this line after making step size smaller!
# plt.legend(frameon=False)
# #plt.savefig('plots/contours.png', bbox_inches="tight", transparent=True)
# plt.show()
# plt.close()

# %%
# mu_BestFit = dist_mod_test(zHDs,om=oms[ibest[0]], ol=ols[ibest[1]], wa=was[ibest[2]], orr=orrs[ibest[3]], w0=w0s[ibest[4]])
# mscr_BestFit = np.sum((mu_BestFit-mu)/muerr**2)/np.sum(1./muerr**2)
# mu_BestFit=mu_BestFit-mscr_BestFit

# empty = dist_mod_test(zHDs,om=0.0, ol=0.0, orr=0.0)
# mscrempty = np.sum((empty-mu)/muerr**2)/np.sum(1./muerr**2)
# empty=empty-mscrempty

# hubblediagram=plt.scatter(zHDs,mu-empty,marker='.',c=muerr,alpha=0.4)
# plt.xlabel('redshift')
# plt.ylabel('distance modulus ($\mu$)')
# cbar=plt.colorbar(hubblediagram)
# cbar.set_label('$\mu$ uncertainty', rotation=270)
# # plt.ylim(35,45)

# plt.plot(np.sort(zHDs),mu_BestFit[np.argsort(zHDs)] - empty[np.argsort(zHDs)],'-',color='black',label='(om, ol, wa, orr, w0)=(%.3f,%.3f,%.3f,%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]], was[ibest[2]], orrs[ibest[3]], w0s[ibest[4]] ))
# # plt.axhline(y=0.0,ls=':',color='black')
# plt.legend(frameon=False)
# plt.show()

# %% [markdown]
# Below is the best fit (contours and superimposed with real data)

# %%
plt.contour(oms, ols, np.transpose(marginchi2_test - np.amin(marginchi2_test)),cmap="winter", **{'levels':[2.3,6.18,11.83]}) #
# 5.89,11.31,18.21
# 2.3,6.18,11.83
# plt.plot(oms[ibest[0]], ols[ibest[1]],'x',color='black',label='(om,ol)=(%.3f,%.3f)'%( oms[ibest[0]], ols[ibest[1]]) )
plt.plot(0.289, 0.711,'x',color='black',label='(om,ol)=(%.3f,%.3f)'%( 0.289, 0.711) )
plt.plot(oms, 1 - oms, "--", label='$\Omega_{m_0} + \Omega_{\Lambda0} = 1.0$')
plt.xlabel("$\Omega_m$", fontsize=12)
plt.xlim(min(oms),max(oms))
# plt.xlim(0,1)
plt.ylabel("$\Omega_\Lambda$", fontsize=12)
plt.ylim(min(ols),max(ols))
# plt.ylim(0,1)
# plt.plot([oms[0],oms[1]], [ols[0],ols[1]],'-',color='black',label='Step size indicator' ) # Delete this line after making step size smaller!
plt.legend(frameon=False)
#plt.savefig('plots/contours.png', bbox_inches="tight", transparent=True)
plt.show()
plt.close()

# %%
mu_BestFit = dist_mod_test(zHDs,om=0.289, ol=0.711, wa=-1.0, orr=0.067, w0=-0.767)
mscr_BestFit = np.sum((mu_BestFit-mu)/muerr**2)/np.sum(1./muerr**2)
mu_BestFit=mu_BestFit-mscr_BestFit

empty = dist_mod_test(zHDs,om=0.0, ol=0.0, orr=0.0)
mscrempty = np.sum((empty-mu)/muerr**2)/np.sum(1./muerr**2)
empty=empty-mscrempty
plt.figure(figsize=(10,7))
hubblediagram=plt.scatter(zHDs,mu-empty,marker='.',c=muerr,alpha=0.4)
plt.xlabel('Redshift ($z_{rec}$)')
plt.ylabel('Distance modulus ($\mu$)')
cbar=plt.colorbar(hubblediagram)
cbar.set_label('$\mu$ uncertainty', rotation=90, labelpad=15)
# plt.ylim(35,45)
plt.xlim(0,1.125)



plt.plot(np.sort(zHDs),mu_BestFit[np.argsort(zHDs)] - empty[np.argsort(zHDs)],'-',color='orange',label='$(\Omega_{m_0},\Omega_{\Lambda_0}, w_a, \Omega_{r_0}, w_0)$=(%.3f,%.3f,%.3f,%.3f,%.3f)'%(0.289,0.711,-1.0, 0.067, 0.767 ))
# plt.axhline(y=0.0,ls=':',color='black')
plt.legend(frameon=False)
plt.show()

# %%
plt.figure(figsize=(10,7))
hubblediagram=plt.scatter(zHDs,mu,marker='.',c=muerr,alpha=0.4)
plt.xlabel('Redshift ($z_{rec}$)')
plt.ylabel('Distance modulus ($\mu$)')
cbar=plt.colorbar(hubblediagram)
cbar.set_label('$\mu$ uncertainty', rotation=90, labelpad=15)
# plt.ylim(35,45)
plt.xlim(0,1.125)



plt.plot(np.sort(zHDs),mu_BestFit[np.argsort(zHDs)],'-',color='orange',label='$(\Omega_{m_0},\Omega_{\Lambda_0}, w_a, \Omega_{r_0}, w_0)$=(%.3f,%.3f,%.3f,%.3f,%.3f)'%(0.289,0.711,-1.0, 0.067, 0.767 ))
# plt.axhline(y=0.0,ls=':',color='black')
plt.legend(frameon=False)
plt.show()
